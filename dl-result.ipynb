# %%
# Cài đặt Detectron2
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-gvy3eatl
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-gvy3eatl
#   Resolved https://github.com/facebookresearch/detectron2.git to commit fd27788985af0f4ca800bca563acdb700bb890e2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.7.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.0.10)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.2)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.18.0)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: black in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (25.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (25.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (8.3.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: pytokens>=0.1.10 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (0.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (6.33.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.1.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2024.2.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.4 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: detectron2, fvcore
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp311-cp311-linux_x86_64.whl size=6434768 sha256=384e905c588b08d5d2a4fe424574fda861ca6f3972e65f5790ebc708f03f1460
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xzfa1v1x/wheels/17/d9/40/60db98e485aa9455d653e29d1046601ce96fe23647f60c1c5a
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=8c9b4e6715cc079594521bf600ac7654cbb5f58eaa0f3d39a04a7e89c316b0da
#   Stored in directory: /root/.cache/pip/wheels/65/71/95/3b8fde5c65c6e4a806e0867c1651dcc71a1cb2f3430e8f355f
# Successfully built detectron2 fvcore
# Installing collected packages: yacs, portalocker, iopath, hydra-core, fvcore, detectron2
# Successfully installed detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 portalocker-3.2.0 yacs-0.1.8

# %%
# !git clone https://github.com/dikey4405/DS201_DeepLearning.git
# Out:
# Cloning into 'DS201_DeepLearning'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 357 (delta 87), reused 0 (delta 0), pack-reused 196 (from 1)
# Receiving objects: 100% (357/357), 397.05 KiB | 10.18 MiB/s, done.
# Resolving deltas: 100% (184/184), done.

# %%
# %cd DS201_DeepLearning/Extractor
# Out:
# /kaggle/working/DS201_DeepLearning/Extractor

# %%
# !python feature_extractor.py
# Out:
# Bắt đầu quá trình trích xuất đặc trưng...
# Đang khởi tạo Detectron2 Faster R-CNN (R101-C4)...
# model_final_298dad.pkl: 212MB [00:01, 188MB/s]
# Model loaded successfully.
#
# --- Đang xử lý tập: train ---
# Số lượng ảnh cần xử lý: 3512
# Extracting train:   0%|                                | 0/3512 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Extracting train: 100%|█████████████████████| 3512/3512 [40:24<00:00,  1.45it/s]
#
# --- Đang xử lý tập: dev ---
# Số lượng ảnh cần xử lý: 439
# Extracting dev: 100%|█████████████████████████| 439/439 [05:08<00:00,  1.42it/s]
#
# --- Đang xử lý tập: test ---
# Số lượng ảnh cần xử lý: 439
# Extracting test: 100%|████████████████████████| 439/439 [05:00<00:00,  1.46it/s]
#
# Hoàn thành! File lưu tại: /kaggle/working/coco_features_2048d/

# %%
# !pip install pyvi pycocoevalcap pycocotools
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (2.0.10)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pyvi) (1.2.2)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (4.67.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pycocotools) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pycocotools) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pycocotools) (2024.2.0)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 59.5 MB/s eta 0:00:00
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 18.4 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.5 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi, pycocoevalcap
# Successfully installed pycocoevalcap-1.2 python-crfsuite-0.9.11 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %%
# %cd ..
# Out:
# /kaggle/working/DS201_DeepLearning

# %%
# !python train.py
# Out:
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 1): 3975
# Vocab size: 3975
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 3512 images.
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 439 images.
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# === Starting Phase 1: XE Training (Corpus Eval) ===
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh đang ngồi trên một con sóng trên một con sóng .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh đang ngồi trên một người đàn_ông mặc áo sơ_mi xanh và quần short
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 153589.79 tokens per second.
# PTBTokenizer tokenized 8121 tokens at 64359.44 tokens per second.
# Epoch 1 | Loss: 5.0315 | Val CIDEr: 0.0959 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.0959)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh đang ngồi trên một chiếc xe trượt_tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh đang ngồi trên một chiếc xe trượt_tuyết .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 173997.29 tokens per second.
# PTBTokenizer tokenized 6057 tokens at 53088.49 tokens per second.
# Epoch 2 | Loss: 4.2170 | Val CIDEr: 0.2825 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.2825)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi trắng và quần bơi màu xanh đang đứng trên một con đường .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đi bộ trên một con đường .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 165589.70 tokens per second.
# PTBTokenizer tokenized 7401 tokens at 54290.54 tokens per second.
# Epoch 3 | Loss: 3.9445 | Val CIDEr: 0.2599 | LR: 3.00e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người phụ_nữ mặc áo sơ_mi trắng và quần đen đang đứng trên một con đường .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trên một con đường .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 171269.05 tokens per second.
# PTBTokenizer tokenized 6661 tokens at 45139.83 tokens per second.
# Epoch 4 | Loss: 3.7646 | Val CIDEr: 0.4050 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.4050)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh và quần đen đang đi bộ trên một con đường .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đi bộ trên một con đường .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 161823.77 tokens per second.
# PTBTokenizer tokenized 6457 tokens at 45474.67 tokens per second.
# Epoch 5 | Loss: 3.6154 | Val CIDEr: 0.4248 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.4248)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh và quần jeans đang đứng trên một tảng đá bên cạnh một người
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trước một toà nhà có một toà nhà màu xanh lá cây cầu gỗ .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 166575.49 tokens per second.
# PTBTokenizer tokenized 7062 tokens at 54525.78 tokens per second.
# Epoch 6 | Loss: 3.4821 | Val CIDEr: 0.4415 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.4415)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông và một người phụ_nữ đang đi bộ qua một cây cầu trong rừng .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trước một toà nhà lớn .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 176140.68 tokens per second.
# PTBTokenizer tokenized 7340 tokens at 58481.80 tokens per second.
# Epoch 7 | Loss: 3.3644 | Val CIDEr: 0.4775 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.4775)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông và một người phụ_nữ đang đứng trước một cây cầu đá lớn .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng bên ngoài một toà nhà lớn với một chiếc ô màu xanh và trắng và
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 173610.61 tokens per second.
# PTBTokenizer tokenized 7073 tokens at 52950.51 tokens per second.
# Epoch 8 | Loss: 3.2493 | Val CIDEr: 0.4532 | LR: 3.00e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo xanh và quần đen đang đi bộ trên một con đường dài với một con
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trên một con đường trong khi những người khác đi bộ khác đang xem .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 166704.90 tokens per second.
# PTBTokenizer tokenized 6602 tokens at 50805.37 tokens per second.
# Epoch 9 | Loss: 3.1442 | Val CIDEr: 0.5272 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.5272)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh và quần jeans đang đứng trước một tảng đá .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đứng trước một toà nhà màu vàng .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 158891.06 tokens per second.
# PTBTokenizer tokenized 7058 tokens at 55360.58 tokens per second.
# Epoch 10 | Loss: 3.0347 | Val CIDEr: 0.4741 | LR: 3.00e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh và quần jeans đang đi bộ qua một cánh đồng xanh .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trên một tảng đá lớn trong khi những người khác đang xem .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 168870.01 tokens per second.
# PTBTokenizer tokenized 6702 tokens at 51263.93 tokens per second.
# Epoch 11 | Loss: 2.9248 | Val CIDEr: 0.4834 | LR: 3.00e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác đen đang đứng trước một cái cây .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trên một cánh đồng xanh .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 159061.69 tokens per second.
# PTBTokenizer tokenized 6728 tokens at 49467.01 tokens per second.
# Epoch 12 | Loss: 2.8265 | Val CIDEr: 0.4968 | LR: 1.50e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đang leo núi và người đang đi qua một cánh đồng xanh .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trong một đài phun nước với một đám đông lớn đằng sau .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 161451.40 tokens per second.
# PTBTokenizer tokenized 7021 tokens at 56531.33 tokens per second.
# Epoch 13 | Loss: 2.6083 | Val CIDEr: 0.4832 | LR: 1.50e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông và một người phụ_nữ đang đi bộ trên một cánh đồng xanh với một cánh đồng xanh
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang leo lên một tảng đá trong khi những người khác đi bộ phía sau .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 166101.15 tokens per second.
# PTBTokenizer tokenized 7001 tokens at 53958.58 tokens per second.
# Epoch 14 | Loss: 2.4925 | Val CIDEr: 0.5137 | LR: 1.50e-04
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông và một người phụ_nữ đang ngồi trên một tảng đá với một cái cây ở phía sau
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trong một đài phun nước với một người đàn_ông khác .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 165769.38 tokens per second.
# PTBTokenizer tokenized 7055 tokens at 52191.03 tokens per second.
# Epoch 15 | Loss: 2.4041 | Val CIDEr: 0.5136 | LR: 7.50e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông và một người phụ_nữ đang đi bộ trong một khu_vực cỏ với một cánh đồng xanh và
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trong một đài phun nước với một người đàn_ông khác .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 161005.81 tokens per second.
# PTBTokenizer tokenized 7252 tokens at 60465.44 tokens per second.
# Epoch 16 | Loss: 2.2560 | Val CIDEr: 0.4738 | LR: 7.50e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đang đứng trước một tảng đá lớn .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang đứng trong một đài phun nước với một người đàn_ông khác .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 172530.26 tokens per second.
# PTBTokenizer tokenized 6962 tokens at 53013.12 tokens per second.
# Epoch 17 | Loss: 2.1928 | Val CIDEr: 0.4864 | LR: 7.50e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đang ngồi trên một tảng đá và nhìn ra xa .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang tận_hưởng một ngày nắng đẹp trong một ngày nắng đẹp .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 164569.10 tokens per second.
# PTBTokenizer tokenized 6942 tokens at 54266.53 tokens per second.
# Epoch 18 | Loss: 2.1302 | Val CIDEr: 0.5274 | LR: 7.50e-05
# --> Saved Best XE Model (CIDEr: 0.5274)
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đang đứng trước một tảng đá lớn .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang tận_hưởng một ngày nắng đẹp trong một ngày nắng đẹp .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 164921.01 tokens per second.
# PTBTokenizer tokenized 7019 tokens at 49747.74 tokens per second.
# Epoch 19 | Loss: 2.0806 | Val CIDEr: 0.4824 | LR: 7.50e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua những tảng đá .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang leo lên một bức tường đá lớn trong công_viên giải_trí .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 177356.05 tokens per second.
# PTBTokenizer tokenized 6906 tokens at 54535.68 tokens per second.
# Epoch 20 | Loss: 2.0305 | Val CIDEr: 0.5079 | LR: 7.50e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đang đứng trước một tảng đá lớn .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm trẻ_em đang chơi trong một đài phun nước với một đài phun nước ở phía sau .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 173349.38 tokens per second.
# PTBTokenizer tokenized 7274 tokens at 56042.28 tokens per second.
# Epoch 21 | Loss: 1.9791 | Val CIDEr: 0.4768 | LR: 3.75e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đang đi bộ qua một cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm trẻ_em đang chơi trong một đài phun nước với một đài phun nước ở phía sau .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 179029.84 tokens per second.
# PTBTokenizer tokenized 6969 tokens at 55797.35 tokens per second.
# Epoch 22 | Loss: 1.9102 | Val CIDEr: 0.4756 | LR: 3.75e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đang đứng trước một tảng đá lớn .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một bức tranh về phía máy quay trong một đài phun nước với một cậu
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 186955.60 tokens per second.
# PTBTokenizer tokenized 6950 tokens at 52556.94 tokens per second.
# Epoch 23 | Loss: 1.8792 | Val CIDEr: 0.4791 | LR: 3.75e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một đài phun nước với một cậu bé ở phía sau .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 161090.82 tokens per second.
# PTBTokenizer tokenized 6865 tokens at 51729.16 tokens per second.
# Epoch 24 | Loss: 1.8553 | Val CIDEr: 0.4896 | LR: 1.87e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang tận_hưởng một ngày nắng đẹp trời trong khi một đứa trẻ khác đang xem .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 166248.24 tokens per second.
# PTBTokenizer tokenized 6893 tokens at 52723.35 tokens per second.
# Epoch 25 | Loss: 1.8177 | Val CIDEr: 0.4811 | LR: 1.87e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một bức tranh về phía máy quay trong một đài phun nước với một cậu
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 158748.60 tokens per second.
# PTBTokenizer tokenized 6868 tokens at 45592.82 tokens per second.
# Epoch 26 | Loss: 1.8022 | Val CIDEr: 0.5048 | LR: 1.87e-05
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một bức tranh về phía máy quay trong một lâu đài phun nước với một
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 168952.15 tokens per second.
# PTBTokenizer tokenized 6938 tokens at 56248.35 tokens per second.
# Epoch 27 | Loss: 1.7913 | Val CIDEr: 0.4813 | LR: 9.37e-06
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một bức tranh về phía máy quay trong một lâu đài phun nước với một
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 163287.63 tokens per second.
# PTBTokenizer tokenized 6897 tokens at 50426.63 tokens per second.
# Epoch 28 | Loss: 1.7724 | Val CIDEr: 0.4876 | LR: 9.37e-06
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một đài phun nước với một cậu bé ở phía sau .
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 167865.86 tokens per second.
# PTBTokenizer tokenized 6904 tokens at 55915.92 tokens per second.
# Epoch 29 | Loss: 1.7658 | Val CIDEr: 0.4882 | LR: 9.37e-06
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một nhóm người đội mũ và mặc áo_khoác và đeo ba_lô đi bộ qua cánh đồng tuyết .
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
#   Pred: một nhóm người đang xem một bức tranh về phía máy quay trong một đài phun nước với một cậu
# Computing CIDEr for 439 images...
# PTBTokenizer tokenized 30309 tokens at 173497.32 tokens per second.
# PTBTokenizer tokenized 6913 tokens at 53776.19 tokens per second.
# Epoch 30 | Loss: 1.7578 | Val CIDEr: 0.4850 | LR: 4.69e-06

# %%
# !python train_scst.py
# Out:
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 1): 3975
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 3512 images.
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 439 images.
# --> Loading BEST XE Model from: /kaggle/working/get_model_best_xe.pth
# Freezing Encoder for SCST stability...
# Checking initial CIDEr...
# Evaluating CIDEr on Validation set...
# PTBTokenizer tokenized 572 tokens at 7033.98 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1779.54 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7711.29 tokens per second.
# PTBTokenizer tokenized 155 tokens at 2030.18 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6770.16 tokens per second.
# PTBTokenizer tokenized 143 tokens at 2136.29 tokens per second.
# PTBTokenizer tokenized 664 tokens at 8867.91 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2316.92 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7757.26 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2001.59 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7440.22 tokens per second.
# PTBTokenizer tokenized 148 tokens at 2238.11 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7134.40 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1948.01 tokens per second.
# PTBTokenizer tokenized 583 tokens at 7982.40 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1856.70 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7123.56 tokens per second.
# PTBTokenizer tokenized 155 tokens at 1987.15 tokens per second.
# PTBTokenizer tokenized 528 tokens at 7243.38 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1585.45 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6567.89 tokens per second.
# PTBTokenizer tokenized 134 tokens at 2003.96 tokens per second.
# PTBTokenizer tokenized 525 tokens at 7301.63 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1565.00 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6356.20 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1847.13 tokens per second.
# PTBTokenizer tokenized 533 tokens at 5418.26 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1795.16 tokens per second.
# PTBTokenizer tokenized 590 tokens at 8128.08 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1626.57 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6426.13 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1605.22 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5335.72 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1518.25 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6165.44 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1606.09 tokens per second.
# PTBTokenizer tokenized 529 tokens at 7295.69 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1345.02 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5916.92 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1219.29 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5915.33 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1472.33 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6010.14 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1178.56 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6051.40 tokens per second.
# PTBTokenizer tokenized 81 tokens at 1013.13 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5201.72 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1550.45 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6336.80 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1208.70 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5927.24 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1801.97 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6132.68 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1332.47 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6000.61 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1371.29 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6073.87 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1158.81 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7528.22 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1438.10 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6377.94 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1504.97 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6179.84 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1422.80 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6178.48 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1156.26 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6196.73 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1322.09 tokens per second.
# PTBTokenizer tokenized 501 tokens at 7133.90 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1327.15 tokens per second.
# PTBTokenizer tokenized 531 tokens at 7438.87 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1264.08 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5537.12 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1598.22 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5744.45 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1497.56 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5944.02 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1632.66 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6260.33 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1453.22 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7622.22 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1751.63 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7449.10 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1886.91 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7405.80 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1648.76 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7596.66 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1357.34 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7126.68 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1870.76 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7213.47 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1757.84 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6633.82 tokens per second.
# PTBTokenizer tokenized 149 tokens at 2094.81 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6843.56 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1806.98 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6836.48 tokens per second.
# PTBTokenizer tokenized 145 tokens at 2114.96 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7623.20 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1657.20 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6948.48 tokens per second.
# PTBTokenizer tokenized 138 tokens at 2002.40 tokens per second.
# PTBTokenizer tokenized 610 tokens at 8420.69 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1786.33 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7013.32 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1597.55 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6372.23 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1642.17 tokens per second.
# PTBTokenizer tokenized 542 tokens at 7127.01 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1403.51 tokens per second.
# Initial CIDEr: 0.6296
#
# === Starting Phase 2: SCST Training (Stable Greedy Baseline) ===
# PTBTokenizer tokenized 665 tokens at 7934.79 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1785.93 tokens per second.
# PTBTokenizer tokenized 3329 tokens at 31753.27 tokens per second.
# PTBTokenizer tokenized 632 tokens at 6938.87 tokens per second.
# PTBTokenizer tokenized 587 tokens at 7207.39 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1491.80 tokens per second.
# PTBTokenizer tokenized 2939 tokens at 30035.46 tokens per second.
# PTBTokenizer tokenized 596 tokens at 7379.25 tokens per second.
# PTBTokenizer tokenized 544 tokens at 6310.68 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1646.74 tokens per second.
# PTBTokenizer tokenized 2724 tokens at 31141.11 tokens per second.
# PTBTokenizer tokenized 651 tokens at 7803.37 tokens per second.
# PTBTokenizer tokenized 592 tokens at 6689.61 tokens per second.
# PTBTokenizer tokenized 138 tokens at 2045.17 tokens per second.
# PTBTokenizer tokenized 2964 tokens at 26901.98 tokens per second.
# PTBTokenizer tokenized 692 tokens at 7966.98 tokens per second.
# PTBTokenizer tokenized 608 tokens at 7216.79 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1832.85 tokens per second.
# PTBTokenizer tokenized 3044 tokens at 27555.91 tokens per second.
# PTBTokenizer tokenized 681 tokens at 8114.64 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6193.91 tokens per second.
# PTBTokenizer tokenized 145 tokens at 2152.90 tokens per second.
# PTBTokenizer tokenized 2734 tokens at 24660.60 tokens per second.
# PTBTokenizer tokenized 644 tokens at 7831.02 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6507.79 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1527.03 tokens per second.
# PTBTokenizer tokenized 2719 tokens at 31310.19 tokens per second.
# PTBTokenizer tokenized 565 tokens at 6817.58 tokens per second.
# PTBTokenizer tokenized 552 tokens at 6608.59 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1409.61 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 25806.49 tokens per second.
# PTBTokenizer tokenized 618 tokens at 7583.88 tokens per second.
# PTBTokenizer tokenized 502 tokens at 5982.71 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1419.03 tokens per second.
# PTBTokenizer tokenized 2514 tokens at 26371.32 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7913.08 tokens per second.
# PTBTokenizer tokenized 531 tokens at 5975.72 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1515.08 tokens per second.
# PTBTokenizer tokenized 2659 tokens at 25607.69 tokens per second.
# PTBTokenizer tokenized 656 tokens at 8419.17 tokens per second.
# PTBTokenizer tokenized 570 tokens at 6671.35 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1711.20 tokens per second.
# PTBTokenizer tokenized 2854 tokens at 30771.81 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7496.13 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6260.44 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1936.37 tokens per second.
# PTBTokenizer tokenized 2889 tokens at 29478.18 tokens per second.
# PTBTokenizer tokenized 678 tokens at 9459.23 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6509.44 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1391.41 tokens per second.
# PTBTokenizer tokenized 2649 tokens at 29359.34 tokens per second.
# PTBTokenizer tokenized 623 tokens at 8483.89 tokens per second.
# PTBTokenizer tokenized 484 tokens at 6115.03 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1854.88 tokens per second.
# PTBTokenizer tokenized 2424 tokens at 26170.02 tokens per second.
# PTBTokenizer tokenized 592 tokens at 6677.32 tokens per second.
# PTBTokenizer tokenized 586 tokens at 6856.45 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1754.38 tokens per second.
# PTBTokenizer tokenized 2934 tokens at 29665.28 tokens per second.
# PTBTokenizer tokenized 632 tokens at 8731.49 tokens per second.
# PTBTokenizer tokenized 640 tokens at 7707.20 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1614.91 tokens per second.
# PTBTokenizer tokenized 3204 tokens at 29249.52 tokens per second.
# PTBTokenizer tokenized 671 tokens at 8318.01 tokens per second.
# PTBTokenizer tokenized 560 tokens at 5986.66 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1414.53 tokens per second.
# PTBTokenizer tokenized 2804 tokens at 27919.14 tokens per second.
# PTBTokenizer tokenized 595 tokens at 7213.16 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6208.69 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1369.36 tokens per second.
# PTBTokenizer tokenized 2539 tokens at 26425.29 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7053.46 tokens per second.
# PTBTokenizer tokenized 596 tokens at 7271.20 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1800.18 tokens per second.
# PTBTokenizer tokenized 2984 tokens at 26071.76 tokens per second.
# PTBTokenizer tokenized 639 tokens at 7977.48 tokens per second.
# PTBTokenizer tokenized 505 tokens at 5676.89 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1767.26 tokens per second.
# PTBTokenizer tokenized 2529 tokens at 24652.30 tokens per second.
# PTBTokenizer tokenized 588 tokens at 6583.91 tokens per second.
# PTBTokenizer tokenized 473 tokens at 5659.32 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1577.64 tokens per second.
# PTBTokenizer tokenized 2369 tokens at 28084.37 tokens per second.
# PTBTokenizer tokenized 554 tokens at 7324.95 tokens per second.
# PTBTokenizer tokenized 506 tokens at 6078.66 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1595.37 tokens per second.
# PTBTokenizer tokenized 2534 tokens at 27436.73 tokens per second.
# PTBTokenizer tokenized 566 tokens at 6826.04 tokens per second.
# PTBTokenizer tokenized 557 tokens at 6044.37 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1604.87 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 26173.55 tokens per second.
# PTBTokenizer tokenized 673 tokens at 7651.35 tokens per second.
# PTBTokenizer tokenized 518 tokens at 5869.61 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1404.92 tokens per second.
# PTBTokenizer tokenized 2594 tokens at 27675.74 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7425.96 tokens per second.
# PTBTokenizer tokenized 541 tokens at 6590.06 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1605.48 tokens per second.
# PTBTokenizer tokenized 2709 tokens at 31030.98 tokens per second.
# PTBTokenizer tokenized 594 tokens at 7232.92 tokens per second.
# PTBTokenizer tokenized 561 tokens at 5864.25 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1604.39 tokens per second.
# PTBTokenizer tokenized 2809 tokens at 32857.04 tokens per second.
# PTBTokenizer tokenized 623 tokens at 7769.04 tokens per second.
# PTBTokenizer tokenized 574 tokens at 6564.93 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1837.11 tokens per second.
# PTBTokenizer tokenized 2874 tokens at 28679.86 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7625.42 tokens per second.
# PTBTokenizer tokenized 526 tokens at 6511.88 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1503.49 tokens per second.
# PTBTokenizer tokenized 2634 tokens at 24580.30 tokens per second.
# PTBTokenizer tokenized 553 tokens at 6592.99 tokens per second.
# PTBTokenizer tokenized 588 tokens at 6938.96 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1912.51 tokens per second.
# PTBTokenizer tokenized 2944 tokens at 30569.92 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7215.47 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6537.02 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1495.25 tokens per second.
# PTBTokenizer tokenized 2569 tokens at 26474.38 tokens per second.
# PTBTokenizer tokenized 618 tokens at 7342.79 tokens per second.
# PTBTokenizer tokenized 560 tokens at 6028.89 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1477.16 tokens per second.
# PTBTokenizer tokenized 2804 tokens at 26006.52 tokens per second.
# PTBTokenizer tokenized 664 tokens at 7764.04 tokens per second.
# PTBTokenizer tokenized 612 tokens at 6944.54 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1721.79 tokens per second.
# PTBTokenizer tokenized 3064 tokens at 32139.85 tokens per second.
# PTBTokenizer tokenized 678 tokens at 8476.92 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6389.60 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1488.95 tokens per second.
# PTBTokenizer tokenized 2654 tokens at 25964.11 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7332.07 tokens per second.
# PTBTokenizer tokenized 553 tokens at 6353.29 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1615.56 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 28705.70 tokens per second.
# PTBTokenizer tokenized 622 tokens at 7062.97 tokens per second.
# PTBTokenizer tokenized 557 tokens at 6456.33 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1752.83 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 26429.37 tokens per second.
# PTBTokenizer tokenized 657 tokens at 7815.15 tokens per second.
# PTBTokenizer tokenized 545 tokens at 6502.38 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1513.42 tokens per second.
# PTBTokenizer tokenized 2729 tokens at 31498.55 tokens per second.
# PTBTokenizer tokenized 639 tokens at 8796.52 tokens per second.
# PTBTokenizer tokenized 585 tokens at 7069.41 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1667.02 tokens per second.
# PTBTokenizer tokenized 2929 tokens at 32493.60 tokens per second.
# PTBTokenizer tokenized 597 tokens at 6208.69 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5727.58 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1509.33 tokens per second.
# PTBTokenizer tokenized 2384 tokens at 23244.10 tokens per second.
# PTBTokenizer tokenized 588 tokens at 7277.90 tokens per second.
# PTBTokenizer tokenized 558 tokens at 7006.40 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1595.76 tokens per second.
# PTBTokenizer tokenized 2794 tokens at 23351.05 tokens per second.
# PTBTokenizer tokenized 600 tokens at 8374.07 tokens per second.
# PTBTokenizer tokenized 546 tokens at 5881.14 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1585.14 tokens per second.
# PTBTokenizer tokenized 2734 tokens at 25791.48 tokens per second.
# PTBTokenizer tokenized 596 tokens at 8439.33 tokens per second.
# PTBTokenizer tokenized 539 tokens at 7171.04 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1506.98 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 26791.14 tokens per second.
# PTBTokenizer tokenized 628 tokens at 7396.46 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6720.35 tokens per second.
# PTBTokenizer tokenized 137 tokens at 2018.52 tokens per second.
# PTBTokenizer tokenized 2774 tokens at 28309.19 tokens per second.
# PTBTokenizer tokenized 641 tokens at 7681.80 tokens per second.
# PTBTokenizer tokenized 553 tokens at 6653.30 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1519.72 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 27749.98 tokens per second.
# PTBTokenizer tokenized 618 tokens at 7645.34 tokens per second.
# PTBTokenizer tokenized 506 tokens at 5821.08 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1505.03 tokens per second.
# PTBTokenizer tokenized 2534 tokens at 25679.83 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6816.48 tokens per second.
# PTBTokenizer tokenized 599 tokens at 6914.18 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1899.78 tokens per second.
# PTBTokenizer tokenized 2999 tokens at 29420.85 tokens per second.
# PTBTokenizer tokenized 661 tokens at 9128.03 tokens per second.
# PTBTokenizer tokenized 506 tokens at 6119.22 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1714.12 tokens per second.
# PTBTokenizer tokenized 2534 tokens at 21524.24 tokens per second.
# PTBTokenizer tokenized 645 tokens at 6772.27 tokens per second.
# PTBTokenizer tokenized 540 tokens at 7445.96 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1756.66 tokens per second.
# PTBTokenizer tokenized 2704 tokens at 31447.30 tokens per second.
# PTBTokenizer tokenized 644 tokens at 7709.85 tokens per second.
# PTBTokenizer tokenized 555 tokens at 7567.74 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1681.98 tokens per second.
# PTBTokenizer tokenized 2779 tokens at 26686.82 tokens per second.
# PTBTokenizer tokenized 619 tokens at 7715.89 tokens per second.
# PTBTokenizer tokenized 540 tokens at 6109.92 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1766.04 tokens per second.
# PTBTokenizer tokenized 2704 tokens at 32154.57 tokens per second.
# PTBTokenizer tokenized 608 tokens at 7370.75 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7582.44 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1635.34 tokens per second.
# PTBTokenizer tokenized 3174 tokens at 28186.04 tokens per second.
# PTBTokenizer tokenized 633 tokens at 8771.18 tokens per second.
# PTBTokenizer tokenized 557 tokens at 5865.82 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1782.30 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 25841.26 tokens per second.
# PTBTokenizer tokenized 635 tokens at 7118.24 tokens per second.
# PTBTokenizer tokenized 504 tokens at 5151.52 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1574.51 tokens per second.
# PTBTokenizer tokenized 2524 tokens at 21337.46 tokens per second.
# PTBTokenizer tokenized 630 tokens at 7807.25 tokens per second.
# PTBTokenizer tokenized 540 tokens at 6457.96 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1524.29 tokens per second.
# PTBTokenizer tokenized 2704 tokens at 25924.14 tokens per second.
# PTBTokenizer tokenized 676 tokens at 8097.59 tokens per second.
# PTBTokenizer tokenized 585 tokens at 7945.69 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1532.66 tokens per second.
# PTBTokenizer tokenized 2929 tokens at 27659.57 tokens per second.
# PTBTokenizer tokenized 644 tokens at 7593.94 tokens per second.
# PTBTokenizer tokenized 505 tokens at 5953.83 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1543.36 tokens per second.
# PTBTokenizer tokenized 2529 tokens at 24193.70 tokens per second.
# PTBTokenizer tokenized 641 tokens at 7657.19 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6416.96 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1372.28 tokens per second.
# PTBTokenizer tokenized 2869 tokens at 28454.49 tokens per second.
# PTBTokenizer tokenized 547 tokens at 6566.12 tokens per second.
# PTBTokenizer tokenized 514 tokens at 6243.46 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1634.70 tokens per second.
# PTBTokenizer tokenized 2574 tokens at 24896.20 tokens per second.
# PTBTokenizer tokenized 573 tokens at 8005.81 tokens per second.
# PTBTokenizer tokenized 648 tokens at 7040.65 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1470.77 tokens per second.
# PTBTokenizer tokenized 3244 tokens at 32274.02 tokens per second.
# PTBTokenizer tokenized 660 tokens at 7898.52 tokens per second.
# PTBTokenizer tokenized 530 tokens at 7265.02 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1746.86 tokens per second.
# PTBTokenizer tokenized 2654 tokens at 23554.07 tokens per second.
# PTBTokenizer tokenized 628 tokens at 7333.07 tokens per second.
# PTBTokenizer tokenized 570 tokens at 6864.87 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1483.93 tokens per second.
# PTBTokenizer tokenized 2854 tokens at 26628.01 tokens per second.
# PTBTokenizer tokenized 617 tokens at 8436.42 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6798.07 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1667.90 tokens per second.
# PTBTokenizer tokenized 2759 tokens at 25575.18 tokens per second.
# PTBTokenizer tokenized 544 tokens at 6406.29 tokens per second.
# PTBTokenizer tokenized 539 tokens at 6035.54 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1695.55 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 27465.59 tokens per second.
# PTBTokenizer tokenized 623 tokens at 8700.61 tokens per second.
# PTBTokenizer tokenized 552 tokens at 5885.55 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1932.35 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 28591.74 tokens per second.
# PTBTokenizer tokenized 608 tokens at 7430.48 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6717.45 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1584.38 tokens per second.
# PTBTokenizer tokenized 2839 tokens at 29552.43 tokens per second.
# PTBTokenizer tokenized 621 tokens at 7354.31 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6502.41 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1570.05 tokens per second.
# PTBTokenizer tokenized 2759 tokens at 28396.77 tokens per second.
# PTBTokenizer tokenized 618 tokens at 6579.50 tokens per second.
# PTBTokenizer tokenized 532 tokens at 5427.20 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1690.84 tokens per second.
# PTBTokenizer tokenized 2664 tokens at 25899.44 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8470.12 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6748.05 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1792.78 tokens per second.
# PTBTokenizer tokenized 2734 tokens at 26470.56 tokens per second.
# PTBTokenizer tokenized 631 tokens at 6582.88 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7042.20 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1779.49 tokens per second.
# PTBTokenizer tokenized 3049 tokens at 34702.88 tokens per second.
# PTBTokenizer tokenized 598 tokens at 6867.30 tokens per second.
# PTBTokenizer tokenized 549 tokens at 6149.66 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1694.67 tokens per second.
# PTBTokenizer tokenized 2749 tokens at 25829.91 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7189.01 tokens per second.
# PTBTokenizer tokenized 594 tokens at 7176.04 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1901.27 tokens per second.
# PTBTokenizer tokenized 2974 tokens at 27702.30 tokens per second.
# PTBTokenizer tokenized 649 tokens at 8676.85 tokens per second.
# PTBTokenizer tokenized 580 tokens at 7488.50 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1621.79 tokens per second.
# PTBTokenizer tokenized 2904 tokens at 29081.49 tokens per second.
# PTBTokenizer tokenized 628 tokens at 7413.02 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7355.34 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1448.54 tokens per second.
# PTBTokenizer tokenized 3079 tokens at 31551.83 tokens per second.
# PTBTokenizer tokenized 609 tokens at 8483.10 tokens per second.
# PTBTokenizer tokenized 556 tokens at 6547.34 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1655.44 tokens per second.
# PTBTokenizer tokenized 2784 tokens at 25923.64 tokens per second.
# PTBTokenizer tokenized 578 tokens at 6421.10 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6662.99 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1510.14 tokens per second.
# PTBTokenizer tokenized 2839 tokens at 32773.69 tokens per second.
# PTBTokenizer tokenized 635 tokens at 8854.74 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6923.13 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1184.82 tokens per second.
# PTBTokenizer tokenized 2589 tokens at 28534.44 tokens per second.
# PTBTokenizer tokenized 556 tokens at 7820.03 tokens per second.
# PTBTokenizer tokenized 519 tokens at 5768.04 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1946.89 tokens per second.
# PTBTokenizer tokenized 2599 tokens at 26391.89 tokens per second.
# PTBTokenizer tokenized 613 tokens at 7339.77 tokens per second.
# PTBTokenizer tokenized 596 tokens at 7918.53 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1923.38 tokens per second.
# PTBTokenizer tokenized 2984 tokens at 33939.99 tokens per second.
# PTBTokenizer tokenized 671 tokens at 8130.89 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6522.06 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1581.57 tokens per second.
# PTBTokenizer tokenized 2659 tokens at 23370.19 tokens per second.
# PTBTokenizer tokenized 649 tokens at 9041.38 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7412.77 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1807.18 tokens per second.
# PTBTokenizer tokenized 3134 tokens at 35553.31 tokens per second.
# PTBTokenizer tokenized 612 tokens at 7292.27 tokens per second.
# PTBTokenizer tokenized 610 tokens at 8028.43 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1672.49 tokens per second.
# PTBTokenizer tokenized 3054 tokens at 26574.53 tokens per second.
# PTBTokenizer tokenized 664 tokens at 9142.82 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6907.52 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1501.22 tokens per second.
# PTBTokenizer tokenized 2669 tokens at 28277.07 tokens per second.
# PTBTokenizer tokenized 552 tokens at 6741.46 tokens per second.
# PTBTokenizer tokenized 619 tokens at 7910.96 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1318.94 tokens per second.
# PTBTokenizer tokenized 3099 tokens at 28628.21 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7424.71 tokens per second.
# PTBTokenizer tokenized 628 tokens at 7488.63 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1517.76 tokens per second.
# PTBTokenizer tokenized 3144 tokens at 28633.88 tokens per second.
# PTBTokenizer tokenized 624 tokens at 8429.66 tokens per second.
# PTBTokenizer tokenized 608 tokens at 7228.93 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1582.27 tokens per second.
# PTBTokenizer tokenized 3044 tokens at 27795.01 tokens per second.
# PTBTokenizer tokenized 617 tokens at 8461.69 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6034.76 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1468.77 tokens per second.
# PTBTokenizer tokenized 2644 tokens at 24156.65 tokens per second.
# PTBTokenizer tokenized 605 tokens at 7216.65 tokens per second.
# PTBTokenizer tokenized 571 tokens at 6694.13 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1768.10 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 30334.93 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7364.60 tokens per second.
# PTBTokenizer tokenized 550 tokens at 5767.65 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1653.04 tokens per second.
# PTBTokenizer tokenized 2754 tokens at 30839.93 tokens per second.
# PTBTokenizer tokenized 639 tokens at 7554.11 tokens per second.
# PTBTokenizer tokenized 654 tokens at 7965.01 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1719.58 tokens per second.
# PTBTokenizer tokenized 3274 tokens at 29396.78 tokens per second.
# PTBTokenizer tokenized 694 tokens at 9624.03 tokens per second.
# PTBTokenizer tokenized 564 tokens at 6925.06 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1501.92 tokens per second.
# PTBTokenizer tokenized 2824 tokens at 32205.37 tokens per second.
# PTBTokenizer tokenized 563 tokens at 6478.41 tokens per second.
# PTBTokenizer tokenized 596 tokens at 6919.87 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1743.40 tokens per second.
# PTBTokenizer tokenized 2984 tokens at 28203.39 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7933.49 tokens per second.
# PTBTokenizer tokenized 552 tokens at 5861.70 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1562.84 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 29111.58 tokens per second.
# PTBTokenizer tokenized 592 tokens at 8243.44 tokens per second.
# PTBTokenizer tokenized 533 tokens at 7385.92 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1431.58 tokens per second.
# PTBTokenizer tokenized 2669 tokens at 24939.45 tokens per second.
# PTBTokenizer tokenized 578 tokens at 6647.46 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7652.53 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1474.91 tokens per second.
# PTBTokenizer tokenized 2889 tokens at 33435.98 tokens per second.
# PTBTokenizer tokenized 635 tokens at 8752.31 tokens per second.
# PTBTokenizer tokenized 510 tokens at 5415.91 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1129.84 tokens per second.
# PTBTokenizer tokenized 2554 tokens at 25194.00 tokens per second.
# PTBTokenizer tokenized 553 tokens at 7720.27 tokens per second.
# PTBTokenizer tokenized 498 tokens at 6924.00 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1984.86 tokens per second.
# PTBTokenizer tokenized 2494 tokens at 25861.50 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7788.24 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6128.91 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1501.31 tokens per second.
# PTBTokenizer tokenized 2814 tokens at 25062.68 tokens per second.
# PTBTokenizer tokenized 618 tokens at 7519.55 tokens per second.
# PTBTokenizer tokenized 535 tokens at 6726.43 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1435.02 tokens per second.
# PTBTokenizer tokenized 2679 tokens at 24941.74 tokens per second.
# PTBTokenizer tokenized 581 tokens at 6997.22 tokens per second.
# PTBTokenizer tokenized 538 tokens at 6959.92 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1446.22 tokens per second.
# PTBTokenizer tokenized 2694 tokens at 26005.25 tokens per second.
# PTBTokenizer tokenized 621 tokens at 7294.89 tokens per second.
# PTBTokenizer tokenized 572 tokens at 6667.90 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1834.67 tokens per second.
# PTBTokenizer tokenized 2864 tokens at 23823.34 tokens per second.
# PTBTokenizer tokenized 660 tokens at 7825.83 tokens per second.
# PTBTokenizer tokenized 485 tokens at 6585.95 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1883.43 tokens per second.
# PTBTokenizer tokenized 2429 tokens at 28654.65 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7578.82 tokens per second.
# PTBTokenizer tokenized 580 tokens at 7071.63 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1672.69 tokens per second.
# PTBTokenizer tokenized 2904 tokens at 26905.81 tokens per second.
# PTBTokenizer tokenized 646 tokens at 8692.82 tokens per second.
# PTBTokenizer tokenized 553 tokens at 6145.19 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1446.91 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 28235.20 tokens per second.
# PTBTokenizer tokenized 601 tokens at 7350.90 tokens per second.
# PTBTokenizer tokenized 549 tokens at 6876.93 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1486.78 tokens per second.
# PTBTokenizer tokenized 2749 tokens at 25939.18 tokens per second.
# PTBTokenizer tokenized 602 tokens at 6956.24 tokens per second.
# PTBTokenizer tokenized 569 tokens at 6366.18 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1990.12 tokens per second.
# PTBTokenizer tokenized 2849 tokens at 27517.43 tokens per second.
# PTBTokenizer tokenized 630 tokens at 7092.42 tokens per second.
# PTBTokenizer tokenized 573 tokens at 7788.00 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1769.35 tokens per second.
# PTBTokenizer tokenized 2869 tokens at 32780.79 tokens per second.
# PTBTokenizer tokenized 601 tokens at 8342.98 tokens per second.
# PTBTokenizer tokenized 586 tokens at 5655.14 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1899.71 tokens per second.
# PTBTokenizer tokenized 2934 tokens at 27027.14 tokens per second.
# PTBTokenizer tokenized 666 tokens at 8784.17 tokens per second.
# PTBTokenizer tokenized 544 tokens at 6361.23 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1489.44 tokens per second.
# PTBTokenizer tokenized 2724 tokens at 23393.33 tokens per second.
# PTBTokenizer tokenized 618 tokens at 7108.51 tokens per second.
# PTBTokenizer tokenized 478 tokens at 6776.03 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1460.24 tokens per second.
# PTBTokenizer tokenized 2394 tokens at 27579.02 tokens per second.
# PTBTokenizer tokenized 623 tokens at 8077.54 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7098.46 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1770.83 tokens per second.
# PTBTokenizer tokenized 3159 tokens at 28211.97 tokens per second.
# PTBTokenizer tokenized 642 tokens at 7451.90 tokens per second.
# PTBTokenizer tokenized 574 tokens at 6915.04 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1664.15 tokens per second.
# PTBTokenizer tokenized 2874 tokens at 25377.85 tokens per second.
# PTBTokenizer tokenized 607 tokens at 7554.58 tokens per second.
# PTBTokenizer tokenized 559 tokens at 7403.72 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1970.19 tokens per second.
# PTBTokenizer tokenized 2799 tokens at 26695.30 tokens per second.
# PTBTokenizer tokenized 633 tokens at 7459.94 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6262.21 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1254.72 tokens per second.
# PTBTokenizer tokenized 2559 tokens at 25256.30 tokens per second.
# PTBTokenizer tokenized 566 tokens at 6579.78 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6338.46 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1662.09 tokens per second.
# PTBTokenizer tokenized 2589 tokens at 22232.29 tokens per second.
# PTBTokenizer tokenized 670 tokens at 8128.47 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6380.29 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1676.06 tokens per second.
# PTBTokenizer tokenized 2559 tokens at 23843.65 tokens per second.
# PTBTokenizer tokenized 594 tokens at 7283.45 tokens per second.
# PTBTokenizer tokenized 596 tokens at 7069.48 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1685.90 tokens per second.
# PTBTokenizer tokenized 2984 tokens at 27317.99 tokens per second.
# PTBTokenizer tokenized 628 tokens at 6482.91 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6940.38 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1462.61 tokens per second.
# PTBTokenizer tokenized 2624 tokens at 29459.72 tokens per second.
# PTBTokenizer tokenized 557 tokens at 7532.44 tokens per second.
# PTBTokenizer tokenized 548 tokens at 6526.61 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1590.87 tokens per second.
# PTBTokenizer tokenized 2744 tokens at 24598.70 tokens per second.
# PTBTokenizer tokenized 647 tokens at 7630.68 tokens per second.
# PTBTokenizer tokenized 525 tokens at 7490.70 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1719.60 tokens per second.
# PTBTokenizer tokenized 2629 tokens at 24580.38 tokens per second.
# PTBTokenizer tokenized 667 tokens at 8088.94 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6389.26 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1419.74 tokens per second.
# PTBTokenizer tokenized 2569 tokens at 24607.69 tokens per second.
# PTBTokenizer tokenized 618 tokens at 7019.65 tokens per second.
# PTBTokenizer tokenized 535 tokens at 7548.73 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1729.52 tokens per second.
# PTBTokenizer tokenized 2679 tokens at 26797.35 tokens per second.
# PTBTokenizer tokenized 620 tokens at 7476.97 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6675.36 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1631.84 tokens per second.
# PTBTokenizer tokenized 2954 tokens at 28030.27 tokens per second.
# PTBTokenizer tokenized 649 tokens at 7503.83 tokens per second.
# PTBTokenizer tokenized 539 tokens at 7604.58 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1489.74 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 28537.66 tokens per second.
# PTBTokenizer tokenized 650 tokens at 8641.54 tokens per second.
# PTBTokenizer tokenized 552 tokens at 7284.17 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1587.30 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 24326.84 tokens per second.
# PTBTokenizer tokenized 602 tokens at 6359.27 tokens per second.
# PTBTokenizer tokenized 544 tokens at 6600.25 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1616.22 tokens per second.
# PTBTokenizer tokenized 2724 tokens at 26022.29 tokens per second.
# PTBTokenizer tokenized 592 tokens at 7123.41 tokens per second.
# PTBTokenizer tokenized 549 tokens at 6469.97 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1662.23 tokens per second.
# PTBTokenizer tokenized 2749 tokens at 27819.72 tokens per second.
# PTBTokenizer tokenized 697 tokens at 8296.34 tokens per second.
# PTBTokenizer tokenized 612 tokens at 6754.14 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1778.22 tokens per second.
# PTBTokenizer tokenized 3064 tokens at 28420.36 tokens per second.
# PTBTokenizer tokenized 625 tokens at 8687.43 tokens per second.
# PTBTokenizer tokenized 537 tokens at 5624.74 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1634.96 tokens per second.
# PTBTokenizer tokenized 2689 tokens at 25979.99 tokens per second.
# PTBTokenizer tokenized 586 tokens at 7158.70 tokens per second.
# PTBTokenizer tokenized 540 tokens at 7228.37 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1684.70 tokens per second.
# PTBTokenizer tokenized 2704 tokens at 25960.99 tokens per second.
# PTBTokenizer tokenized 615 tokens at 8656.63 tokens per second.
# PTBTokenizer tokenized 551 tokens at 5874.05 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1410.89 tokens per second.
# PTBTokenizer tokenized 2759 tokens at 29224.30 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7249.82 tokens per second.
# PTBTokenizer tokenized 565 tokens at 6682.42 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1508.68 tokens per second.
# PTBTokenizer tokenized 2829 tokens at 27069.27 tokens per second.
# PTBTokenizer tokenized 594 tokens at 7269.12 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7089.36 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1653.74 tokens per second.
# PTBTokenizer tokenized 2839 tokens at 33585.01 tokens per second.
# PTBTokenizer tokenized 643 tokens at 6642.96 tokens per second.
# PTBTokenizer tokenized 548 tokens at 7625.66 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1452.75 tokens per second.
# PTBTokenizer tokenized 2744 tokens at 31678.46 tokens per second.
# PTBTokenizer tokenized 607 tokens at 8473.32 tokens per second.
# PTBTokenizer tokenized 553 tokens at 6252.28 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1496.36 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 25140.29 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7570.22 tokens per second.
# PTBTokenizer tokenized 558 tokens at 7728.99 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1714.93 tokens per second.
# PTBTokenizer tokenized 2794 tokens at 29621.34 tokens per second.
# PTBTokenizer tokenized 561 tokens at 6155.06 tokens per second.
# PTBTokenizer tokenized 561 tokens at 6901.45 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1508.25 tokens per second.
# PTBTokenizer tokenized 2809 tokens at 29848.54 tokens per second.
# PTBTokenizer tokenized 676 tokens at 8023.67 tokens per second.
# PTBTokenizer tokenized 554 tokens at 5948.52 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1494.46 tokens per second.
# PTBTokenizer tokenized 2774 tokens at 31463.86 tokens per second.
# PTBTokenizer tokenized 569 tokens at 6850.38 tokens per second.
# PTBTokenizer tokenized 536 tokens at 7439.62 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1558.80 tokens per second.
# PTBTokenizer tokenized 2684 tokens at 27508.68 tokens per second.
# PTBTokenizer tokenized 598 tokens at 6803.60 tokens per second.
# PTBTokenizer tokenized 569 tokens at 6705.24 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1710.01 tokens per second.
# PTBTokenizer tokenized 2849 tokens at 29637.58 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7860.14 tokens per second.
# PTBTokenizer tokenized 505 tokens at 5583.43 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1752.76 tokens per second.
# PTBTokenizer tokenized 2529 tokens at 23948.64 tokens per second.
# PTBTokenizer tokenized 552 tokens at 6090.13 tokens per second.
# PTBTokenizer tokenized 619 tokens at 7054.74 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1495.48 tokens per second.
# PTBTokenizer tokenized 3099 tokens at 34429.87 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7390.82 tokens per second.
# PTBTokenizer tokenized 559 tokens at 7828.52 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1577.12 tokens per second.
# PTBTokenizer tokenized 2799 tokens at 25246.07 tokens per second.
# PTBTokenizer tokenized 651 tokens at 7737.20 tokens per second.
# PTBTokenizer tokenized 540 tokens at 7308.98 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1598.87 tokens per second.
# PTBTokenizer tokenized 2704 tokens at 30934.08 tokens per second.
# PTBTokenizer tokenized 605 tokens at 7892.44 tokens per second.
# PTBTokenizer tokenized 586 tokens at 7899.72 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1482.27 tokens per second.
# PTBTokenizer tokenized 2934 tokens at 29466.28 tokens per second.
# PTBTokenizer tokenized 594 tokens at 7108.40 tokens per second.
# PTBTokenizer tokenized 641 tokens at 6970.38 tokens per second.
# PTBTokenizer tokenized 154 tokens at 2243.75 tokens per second.
# PTBTokenizer tokenized 3209 tokens at 31227.58 tokens per second.
# PTBTokenizer tokenized 658 tokens at 7841.95 tokens per second.
# PTBTokenizer tokenized 561 tokens at 7738.74 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1789.45 tokens per second.
# PTBTokenizer tokenized 2809 tokens at 26020.77 tokens per second.
# PTBTokenizer tokenized 667 tokens at 7219.42 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7430.36 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1726.61 tokens per second.
# PTBTokenizer tokenized 3054 tokens at 26931.70 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7459.12 tokens per second.
# PTBTokenizer tokenized 482 tokens at 5966.19 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1296.61 tokens per second.
# PTBTokenizer tokenized 2414 tokens at 20755.37 tokens per second.
# PTBTokenizer tokenized 557 tokens at 6361.92 tokens per second.
# PTBTokenizer tokenized 674 tokens at 7025.39 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1639.32 tokens per second.
# PTBTokenizer tokenized 3374 tokens at 30063.13 tokens per second.
# PTBTokenizer tokenized 661 tokens at 7768.67 tokens per second.
# PTBTokenizer tokenized 517 tokens at 7208.06 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1563.61 tokens per second.
# PTBTokenizer tokenized 2589 tokens at 24771.17 tokens per second.
# PTBTokenizer tokenized 642 tokens at 7525.61 tokens per second.
# PTBTokenizer tokenized 536 tokens at 6097.18 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1491.32 tokens per second.
# PTBTokenizer tokenized 2684 tokens at 31125.46 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7337.54 tokens per second.
# PTBTokenizer tokenized 557 tokens at 7242.23 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1684.87 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 27703.02 tokens per second.
# PTBTokenizer tokenized 652 tokens at 7888.76 tokens per second.
# PTBTokenizer tokenized 572 tokens at 6463.07 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1782.64 tokens per second.
# PTBTokenizer tokenized 2864 tokens at 24831.41 tokens per second.
# PTBTokenizer tokenized 665 tokens at 9105.03 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7123.45 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1603.71 tokens per second.
# PTBTokenizer tokenized 2994 tokens at 33962.16 tokens per second.
# PTBTokenizer tokenized 605 tokens at 7034.40 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6165.20 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1448.33 tokens per second.
# PTBTokenizer tokenized 2589 tokens at 22225.14 tokens per second.
# PTBTokenizer tokenized 647 tokens at 7809.35 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6179.45 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1536.69 tokens per second.
# PTBTokenizer tokenized 2734 tokens at 24266.03 tokens per second.
# PTBTokenizer tokenized 625 tokens at 7404.19 tokens per second.
# PTBTokenizer tokenized 594 tokens at 6951.11 tokens per second.
# PTBTokenizer tokenized 140 tokens at 2049.76 tokens per second.
# PTBTokenizer tokenized 2974 tokens at 33414.18 tokens per second.
# PTBTokenizer tokenized 660 tokens at 8161.99 tokens per second.
# PTBTokenizer tokenized 592 tokens at 8330.42 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1621.65 tokens per second.
# PTBTokenizer tokenized 2964 tokens at 26800.90 tokens per second.
# ...
# PTBTokenizer tokenized 538 tokens at 6806.73 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6003.49 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1478.93 tokens per second.
# PTBTokenizer tokenized 2644 tokens at 30625.86 tokens per second.
# PTBTokenizer tokenized 641 tokens at 7803.07 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6210.24 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1512.14 tokens per second.
# PTBTokenizer tokenized 2489 tokens at 25242.64 tokens per second.
# PTBTokenizer tokenized 568 tokens at 5994.46 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5993.85 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1637.25 tokens per second.
# PTBTokenizer tokenized 2474 tokens at 25839.58 tokens per second.
# PTBTokenizer tokenized 574 tokens at 6959.35 tokens per second.
# PTBTokenizer tokenized 590 tokens at 8196.16 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1539.15 tokens per second.
# PTBTokenizer tokenized 2954 tokens at 32000.24 tokens per second.
# PTBTokenizer tokenized 644 tokens at 8515.88 tokens per second.
# PTBTokenizer tokenized 641 tokens at 7458.29 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1588.24 tokens per second.
# PTBTokenizer tokenized 3209 tokens at 28409.30 tokens per second.
# PTBTokenizer tokenized 667 tokens at 7711.94 tokens per second.
# PTBTokenizer tokenized 550 tokens at 7714.10 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1524.56 tokens per second.
# PTBTokenizer tokenized 2754 tokens at 23902.49 tokens per second.
# PTBTokenizer tokenized 627 tokens at 8448.09 tokens per second.
# PTBTokenizer tokenized 538 tokens at 6297.75 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1670.37 tokens per second.
# PTBTokenizer tokenized 2694 tokens at 23224.04 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7092.80 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6480.09 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1420.59 tokens per second.
# PTBTokenizer tokenized 2839 tokens at 21872.57 tokens per second.
# PTBTokenizer tokenized 600 tokens at 7245.08 tokens per second.
# PTBTokenizer tokenized 538 tokens at 6078.34 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1748.70 tokens per second.
# PTBTokenizer tokenized 2694 tokens at 31188.25 tokens per second.
# PTBTokenizer tokenized 637 tokens at 7711.46 tokens per second.
# PTBTokenizer tokenized 550 tokens at 6582.18 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1501.16 tokens per second.
# PTBTokenizer tokenized 2754 tokens at 24705.82 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7454.05 tokens per second.
# PTBTokenizer tokenized 564 tokens at 6455.42 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1422.71 tokens per second.
# PTBTokenizer tokenized 2824 tokens at 26370.97 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7838.16 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7281.86 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1630.66 tokens per second.
# PTBTokenizer tokenized 3054 tokens at 29697.85 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7972.42 tokens per second.
# PTBTokenizer tokenized 576 tokens at 6994.71 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1874.75 tokens per second.
# PTBTokenizer tokenized 2884 tokens at 26675.23 tokens per second.
# PTBTokenizer tokenized 623 tokens at 7402.21 tokens per second.
# PTBTokenizer tokenized 593 tokens at 6952.71 tokens per second.
# PTBTokenizer tokenized 143 tokens at 2093.70 tokens per second.
# PTBTokenizer tokenized 2969 tokens at 27977.36 tokens per second.
# PTBTokenizer tokenized 654 tokens at 7582.22 tokens per second.
# PTBTokenizer tokenized 536 tokens at 6308.75 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1137.16 tokens per second.
# PTBTokenizer tokenized 2684 tokens at 30371.05 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6392.40 tokens per second.
# PTBTokenizer tokenized 557 tokens at 7140.22 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1201.93 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 25287.45 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6252.03 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6243.54 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1639.71 tokens per second.
# PTBTokenizer tokenized 2814 tokens at 25167.07 tokens per second.
# PTBTokenizer tokenized 643 tokens at 7283.34 tokens per second.
# PTBTokenizer tokenized 600 tokens at 7284.96 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1816.23 tokens per second.
# PTBTokenizer tokenized 3004 tokens at 27778.18 tokens per second.
# PTBTokenizer tokenized 599 tokens at 7175.63 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6356.03 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1493.49 tokens per second.
# PTBTokenizer tokenized 2644 tokens at 21870.84 tokens per second.
# PTBTokenizer tokenized 596 tokens at 7225.69 tokens per second.
# PTBTokenizer tokenized 582 tokens at 8085.08 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1585.21 tokens per second.
# PTBTokenizer tokenized 2914 tokens at 30525.34 tokens per second.
# PTBTokenizer tokenized 587 tokens at 7212.91 tokens per second.
# PTBTokenizer tokenized 495 tokens at 5245.74 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1042.74 tokens per second.
# PTBTokenizer tokenized 2479 tokens at 29247.78 tokens per second.
# PTBTokenizer tokenized 524 tokens at 7329.33 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6635.65 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1980.26 tokens per second.
# PTBTokenizer tokenized 2869 tokens at 32157.30 tokens per second.
# PTBTokenizer tokenized 569 tokens at 7158.77 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6735.08 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1479.46 tokens per second.
# PTBTokenizer tokenized 2659 tokens at 22934.34 tokens per second.
# PTBTokenizer tokenized 565 tokens at 6726.29 tokens per second.
# PTBTokenizer tokenized 649 tokens at 7275.28 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1980.94 tokens per second.
# PTBTokenizer tokenized 3249 tokens at 34707.75 tokens per second.
# PTBTokenizer tokenized 658 tokens at 8857.37 tokens per second.
# PTBTokenizer tokenized 502 tokens at 5952.44 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1452.26 tokens per second.
# PTBTokenizer tokenized 2514 tokens at 26765.95 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6348.78 tokens per second.
# PTBTokenizer tokenized 564 tokens at 6976.36 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1653.02 tokens per second.
# PTBTokenizer tokenized 2824 tokens at 26619.07 tokens per second.
# PTBTokenizer tokenized 620 tokens at 7103.26 tokens per second.
# PTBTokenizer tokenized 561 tokens at 6682.41 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1627.23 tokens per second.
# PTBTokenizer tokenized 2809 tokens at 30437.65 tokens per second.
# PTBTokenizer tokenized 605 tokens at 8002.54 tokens per second.
# PTBTokenizer tokenized 449 tokens at 5687.82 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1477.98 tokens per second.
# PTBTokenizer tokenized 2249 tokens at 24047.78 tokens per second.
# PTBTokenizer tokenized 554 tokens at 7633.56 tokens per second.
# PTBTokenizer tokenized 547 tokens at 6122.03 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1187.01 tokens per second.
# PTBTokenizer tokenized 2739 tokens at 31052.37 tokens per second.
# PTBTokenizer tokenized 604 tokens at 6442.31 tokens per second.
# PTBTokenizer tokenized 548 tokens at 6318.65 tokens per second.
# PTBTokenizer tokenized 92 tokens at 1336.37 tokens per second.
# PTBTokenizer tokenized 2744 tokens at 25129.79 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6808.38 tokens per second.
# PTBTokenizer tokenized 490 tokens at 5998.39 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1711.92 tokens per second.
# PTBTokenizer tokenized 2454 tokens at 26253.96 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6089.56 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6876.32 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1670.37 tokens per second.
# PTBTokenizer tokenized 2814 tokens at 23474.24 tokens per second.
# PTBTokenizer tokenized 565 tokens at 6736.14 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6267.87 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1338.08 tokens per second.
# PTBTokenizer tokenized 2654 tokens at 24636.42 tokens per second.
# PTBTokenizer tokenized 569 tokens at 6746.50 tokens per second.
# PTBTokenizer tokenized 564 tokens at 6864.99 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1439.22 tokens per second.
# PTBTokenizer tokenized 2824 tokens at 27875.53 tokens per second.
# PTBTokenizer tokenized 620 tokens at 7344.79 tokens per second.
# Evaluating CIDEr on Validation set...
# PTBTokenizer tokenized 572 tokens at 7861.16 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1631.29 tokens per second.
# PTBTokenizer tokenized 655 tokens at 8016.07 tokens per second.
# PTBTokenizer tokenized 162 tokens at 1764.97 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6556.80 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1799.33 tokens per second.
# PTBTokenizer tokenized 664 tokens at 7997.70 tokens per second.
# PTBTokenizer tokenized 149 tokens at 2141.35 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7901.84 tokens per second.
# PTBTokenizer tokenized 153 tokens at 2002.90 tokens per second.
# PTBTokenizer tokenized 551 tokens at 5644.10 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1977.88 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7589.44 tokens per second.
# PTBTokenizer tokenized 139 tokens at 2074.46 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6256.78 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1788.38 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7026.20 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1726.64 tokens per second.
# PTBTokenizer tokenized 528 tokens at 7372.39 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1810.75 tokens per second.
# PTBTokenizer tokenized 546 tokens at 5880.96 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1569.24 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6289.02 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1680.92 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6340.44 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1846.94 tokens per second.
# PTBTokenizer tokenized 533 tokens at 5602.58 tokens per second.
# PTBTokenizer tokenized 138 tokens at 2032.71 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7057.70 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1702.33 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6541.98 tokens per second.
# PTBTokenizer tokenized 94 tokens at 1124.95 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6510.07 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1349.44 tokens per second.
# PTBTokenizer tokenized 511 tokens at 7202.29 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1128.86 tokens per second.
# PTBTokenizer tokenized 529 tokens at 5928.83 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1517.60 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5594.85 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1243.66 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5273.71 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1298.92 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6903.41 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1291.98 tokens per second.
# PTBTokenizer tokenized 487 tokens at 5865.18 tokens per second.
# PTBTokenizer tokenized 78 tokens at 995.66 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5510.54 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1240.89 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6998.67 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1381.41 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6245.43 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1467.69 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6021.06 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1618.45 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5251.56 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1210.37 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6450.55 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1213.56 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6012.27 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1339.39 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6247.38 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1364.41 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6795.54 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1404.79 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5992.46 tokens per second.
# PTBTokenizer tokenized 90 tokens at 1121.09 tokens per second.
# PTBTokenizer tokenized 524 tokens at 5790.61 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1357.20 tokens per second.
# PTBTokenizer tokenized 501 tokens at 5837.22 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1260.62 tokens per second.
# PTBTokenizer tokenized 531 tokens at 7400.80 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1148.95 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6388.88 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1293.89 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5157.89 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1568.27 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5929.44 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1545.02 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6202.53 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1201.41 tokens per second.
# PTBTokenizer tokenized 666 tokens at 8064.77 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1796.55 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7025.90 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1554.97 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6537.25 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1691.79 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7671.42 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1564.78 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7538.67 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1602.96 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7782.05 tokens per second.
# PTBTokenizer tokenized 139 tokens at 2070.39 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7569.95 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1647.80 tokens per second.
# PTBTokenizer tokenized 562 tokens at 7819.11 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1222.01 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6653.17 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1549.62 tokens per second.
# PTBTokenizer tokenized 543 tokens at 5986.98 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1606.33 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6234.34 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1990.51 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7609.76 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1483.22 tokens per second.
# PTBTokenizer tokenized 615 tokens at 6706.46 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1752.87 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6729.21 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1453.60 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6106.07 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1323.72 tokens per second.
# Epoch 10 | Loss: -1.2573 | Val CIDEr: 0.6654
# --> Saved Best SCST Model (CIDEr: 0.6654)

# %%
# !python generate.py
# Out:
# Running Inference on: cuda
# Loading vocab from /kaggle/input/data-dl/Captions/train.json...
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 1): 3975
# Vocab size: 3975
# Initializing Test Dataloader...
# Loading annotations from: /kaggle/input/data-dl/Captions/test.json
# Loaded 439 images.
# Loading Model...
# Loading weights from: /kaggle/working/get_model_best_scst.pth
# Bắt đầu sinh caption với Beam Size = 3...
#   0%|                                                   | 0/439 [00:00<?, ?it/s]
# [Img 2054125670.jpg]: một người đàn_ông mặc quần_đùi đen và đầu_gối đang đậu trên bãi biển .
#   0%|                                           | 1/439 [00:00<04:52,  1.50it/s]
# [Img 2065300784.jpg]: một người đàn_ông mặc áo_khoác xanh và một người phụ_nữ mặc áo_khoác nâu và đội mũ bảo_hiểm đang chụp ảnh
#   0%|▏                                          | 2/439 [00:00<02:27,  2.96it/s]
# [Img 2088120475.jpg]: phút_giây cột mở hành_lý và một chú hề mặc áo sơ_mi màu cam đang chụp ảnh một con đền .
# 100%|█████████████████████████████████████████| 439/439 [00:46<00:00,  9.53it/s]
# Saving results to /kaggle/working/caption_results.json...
# Hoàn thành! Đã sinh caption cho 439 ảnh.

# %%
# !python Evaluate.py
# Out:
# Đang tạo file Ground Truth chuẩn COCO từ: /kaggle/input/data-dl/Captions/test.json
# Formatting GT: 100%|██████████████████████| 439/439 [00:00<00:00, 399587.56it/s]
# Đang định dạng file dự đoán: caption_readable.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 34453 tokens at 201084.63 tokens per second.
# PTBTokenizer tokenized 6599 tokens at 55050.77 tokens per second.
# setting up scorers...
# Downloading stanford-corenlp-3.6.0 for SPICE ...
#
# Extracting stanford-corenlp-3.6.0 ...
# Done.
# computing Bleu score...
# {'testlen': 5757, 'reflen': 5687, 'guess': [5757, 5318, 4879, 4440], 'correct': [2408, 826, 247, 49]}
# ratio: 1.0123087743975712
# Bleu_1: 0.418
# Bleu_2: 0.255
# Bleu_3: 0.149
# Bleu_4: 0.078
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.311
# computing CIDEr score...
# CIDEr: 0.180
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/usr/local/lib/python3.11/dist-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.6 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.3 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.7 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.7 sec].
# Threads( StanfordCoreNLP ) [01:25.903 minutes]
# Parsing test captions
# Threads( StanfordCoreNLP ) [13.316 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 1.804 min
# SPICE: 0.035
#
# ========================================
#    KẾT QUẢ ĐÁNH GIÁ (SCST + Faster R-CNN)
# ========================================
# | Bleu_1     |  41.83% |
# | Bleu_2     |  25.49% |
# | Bleu_3     |  14.87% |
# | Bleu_4     |   7.76% |
# | METEOR     |  25.94% |
# | ROUGE_L    |  31.07% |
# | CIDEr      |  18.03% |
# | SPICE      |   3.46% |
# ========================================
