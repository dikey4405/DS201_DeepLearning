# %%
# !git clone https://github.com/dikey4405/DS201_DeepLearning.git
# Out:
# Cloning into 'DS201_DeepLearning'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (183/183), done.
# remote: Total 189 (delta 95), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (189/189), 88.46 KiB | 3.16 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# %cd DS201_DeepLearning/Extractor
# Out:
# /kaggle/working/DS201_DeepLearning/Extractor

# %%
# !python feature_extractor.py
# Out:
# Bắt đầu quá trình trích xuất đặc trưng...
# Khởi tạo SUPER Feature Extractor: ConvNeXt-Large trên cuda...
# Downloading: "https://download.pytorch.org/models/convnext_large-ea097f82.pth" to /root/.cache/torch/hub/checkpoints/convnext_large-ea097f82.pth
# 100%|█████████████████████████████████████████| 755M/755M [00:03<00:00, 201MB/s]
# Đã khởi tạo model ResNet-101 thành công.
#
# --- Đang xử lý tập: train ---
# Số lượng ảnh cần xử lý: 3512
# Extracting train: 100%|█████████████████████| 3512/3512 [03:29<00:00, 16.80it/s]
#
# --- Đang xử lý tập: dev ---
# Số lượng ảnh cần xử lý: 439
# Extracting dev: 100%|█████████████████████████| 439/439 [00:27<00:00, 16.16it/s]
#
# --- Đang xử lý tập: test ---
# Số lượng ảnh cần xử lý: 439
# Extracting test: 100%|████████████████████████| 439/439 [00:27<00:00, 15.88it/s]
#
# Hoàn thành! File lưu tại: /kaggle/working/coco_features_2048d/

# %%
# !pip install pyvi pycocoevalcap pycocotools
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (2.0.10)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pyvi) (1.2.2)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (4.67.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pycocotools) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pycocotools) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pycocotools) (2024.2.0)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 57.3 MB/s eta 0:00:0000:0100:01
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 18.4 MB/s eta 0:00:0000:0100:01
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.9 MB/s eta 0:00:00:00:01
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi, pycocoevalcap
# Successfully installed pycocoevalcap-1.2 python-crfsuite-0.9.11 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %%
# %cd ..
# Out:
# /kaggle/working/DS201_DeepLearning

# %%
# !python train.py
# Out:
# Loading vocab from: /kaggle/input/data-dl/Captions/train.json
# Found 17562 valid captions.
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 2): 2719
# Vocab size: 2719
# Initializing Dataloaders...
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 3512 images.
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 439 images.
# === Starting Phase 1: XE Training (With Label Smoothing 0.1) ===
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 5053.37 tokens per second.
# PTBTokenizer tokenized 304 tokens at 4369.65 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7153.74 tokens per second.
# PTBTokenizer tokenized 244 tokens at 2816.83 tokens per second.
# PTBTokenizer tokenized 584 tokens at 8099.89 tokens per second.
# PTBTokenizer tokenized 180 tokens at 2047.96 tokens per second.
# PTBTokenizer tokenized 664 tokens at 9170.24 tokens per second.
# PTBTokenizer tokenized 280 tokens at 3430.32 tokens per second.
# PTBTokenizer tokenized 662 tokens at 9196.00 tokens per second.
# PTBTokenizer tokenized 338 tokens at 4465.33 tokens per second.
# PTBTokenizer tokenized 551 tokens at 5924.05 tokens per second.
# PTBTokenizer tokenized 329 tokens at 4771.46 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7099.75 tokens per second.
# PTBTokenizer tokenized 317 tokens at 4209.30 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6899.03 tokens per second.
# PTBTokenizer tokenized 356 tokens at 5171.93 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7380.28 tokens per second.
# PTBTokenizer tokenized 327 tokens at 4006.39 tokens per second.
# PTBTokenizer tokenized 528 tokens at 7438.96 tokens per second.
# PTBTokenizer tokenized 202 tokens at 2455.57 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6972.58 tokens per second.
# PTBTokenizer tokenized 227 tokens at 3360.22 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6225.76 tokens per second.
# PTBTokenizer tokenized 215 tokens at 2726.05 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6126.10 tokens per second.
# PTBTokenizer tokenized 264 tokens at 3118.07 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6773.99 tokens per second.
# PTBTokenizer tokenized 277 tokens at 3594.67 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6419.13 tokens per second.
# PTBTokenizer tokenized 292 tokens at 3697.16 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7639.81 tokens per second.
# PTBTokenizer tokenized 183 tokens at 2349.20 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6365.11 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1872.83 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6025.68 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2535.54 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6351.01 tokens per second.
# PTBTokenizer tokenized 229 tokens at 2394.86 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5884.72 tokens per second.
# PTBTokenizer tokenized 233 tokens at 3227.74 tokens per second.
# PTBTokenizer tokenized 491 tokens at 6831.23 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1869.84 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5849.54 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2050.58 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6727.72 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1994.09 tokens per second.
# PTBTokenizer tokenized 485 tokens at 6852.05 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1979.74 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6146.85 tokens per second.
# PTBTokenizer tokenized 264 tokens at 3008.89 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5832.16 tokens per second.
# PTBTokenizer tokenized 183 tokens at 2599.66 tokens per second.
# PTBTokenizer tokenized 503 tokens at 7078.16 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1608.91 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6774.49 tokens per second.
# PTBTokenizer tokenized 215 tokens at 2803.77 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5875.12 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1980.46 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6440.95 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1725.84 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7428.09 tokens per second.
# PTBTokenizer tokenized 220 tokens at 3088.45 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6395.05 tokens per second.
# PTBTokenizer tokenized 250 tokens at 3118.81 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6346.14 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1325.16 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6564.23 tokens per second.
# PTBTokenizer tokenized 252 tokens at 3553.38 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6439.28 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2062.83 tokens per second.
# PTBTokenizer tokenized 531 tokens at 7337.71 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2292.64 tokens per second.
# PTBTokenizer tokenized 517 tokens at 4762.34 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1627.76 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5904.71 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2310.32 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6381.82 tokens per second.
# PTBTokenizer tokenized 166 tokens at 1967.95 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7322.66 tokens per second.
# PTBTokenizer tokenized 160 tokens at 1846.78 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7815.01 tokens per second.
# PTBTokenizer tokenized 275 tokens at 3428.48 tokens per second.
# PTBTokenizer tokenized 626 tokens at 8020.34 tokens per second.
# PTBTokenizer tokenized 221 tokens at 2980.08 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6863.09 tokens per second.
# PTBTokenizer tokenized 296 tokens at 3117.55 tokens per second.
# PTBTokenizer tokenized 653 tokens at 8003.04 tokens per second.
# PTBTokenizer tokenized 239 tokens at 2824.82 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8611.45 tokens per second.
# PTBTokenizer tokenized 333 tokens at 4201.10 tokens per second.
# PTBTokenizer tokenized 653 tokens at 6939.75 tokens per second.
# PTBTokenizer tokenized 377 tokens at 4616.02 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7341.83 tokens per second.
# PTBTokenizer tokenized 309 tokens at 3473.96 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6812.61 tokens per second.
# PTBTokenizer tokenized 334 tokens at 3747.50 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6609.83 tokens per second.
# PTBTokenizer tokenized 277 tokens at 3422.20 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6545.65 tokens per second.
# PTBTokenizer tokenized 269 tokens at 3462.90 tokens per second.
# PTBTokenizer tokenized 579 tokens at 7136.17 tokens per second.
# PTBTokenizer tokenized 311 tokens at 4034.57 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7218.94 tokens per second.
# PTBTokenizer tokenized 264 tokens at 3280.28 tokens per second.
# PTBTokenizer tokenized 615 tokens at 8130.87 tokens per second.
# PTBTokenizer tokenized 254 tokens at 3030.39 tokens per second.
# PTBTokenizer tokenized 530 tokens at 5802.95 tokens per second.
# PTBTokenizer tokenized 190 tokens at 2316.83 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6549.12 tokens per second.
# PTBTokenizer tokenized 293 tokens at 3819.75 tokens per second.
# Epoch 1/30 | Loss: 5.3751 | Val CIDEr: 0.1675
# --> Saved Best XE Model (CIDEr: 0.1675)
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 7298.62 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1686.96 tokens per second.
# PTBTokenizer tokenized 655 tokens at 6997.71 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2202.00 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6464.17 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1496.53 tokens per second.
# PTBTokenizer tokenized 664 tokens at 9071.98 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1927.14 tokens per second.
# PTBTokenizer tokenized 662 tokens at 6774.06 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1712.43 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6500.25 tokens per second.
# PTBTokenizer tokenized 161 tokens at 2011.43 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6875.15 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1741.62 tokens per second.
# PTBTokenizer tokenized 583 tokens at 7153.41 tokens per second.
# PTBTokenizer tokenized 166 tokens at 2125.16 tokens per second.
# PTBTokenizer tokenized 609 tokens at 8559.90 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1900.89 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6363.65 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1355.87 tokens per second.
# PTBTokenizer tokenized 546 tokens at 5843.98 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1766.44 tokens per second.
# PTBTokenizer tokenized 525 tokens at 5902.23 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1224.41 tokens per second.
# PTBTokenizer tokenized 519 tokens at 5560.08 tokens per second.
# PTBTokenizer tokenized 157 tokens at 1935.13 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6349.65 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1221.70 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7041.15 tokens per second.
# PTBTokenizer tokenized 172 tokens at 2341.01 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6162.71 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1213.94 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6066.37 tokens per second.
# PTBTokenizer tokenized 92 tokens at 1271.96 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6013.68 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1540.65 tokens per second.
# PTBTokenizer tokenized 529 tokens at 5948.05 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1412.69 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6007.13 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1595.31 tokens per second.
# PTBTokenizer tokenized 491 tokens at 6759.40 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1458.97 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6934.44 tokens per second.
# PTBTokenizer tokenized 86 tokens at 1284.09 tokens per second.
# PTBTokenizer tokenized 487 tokens at 5656.38 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1149.00 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5235.55 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1220.07 tokens per second.
# PTBTokenizer tokenized 502 tokens at 5862.80 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1501.40 tokens per second.
# PTBTokenizer tokenized 493 tokens at 7102.03 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1358.03 tokens per second.
# PTBTokenizer tokenized 503 tokens at 7187.17 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1487.49 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6016.95 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1485.53 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6170.26 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1303.37 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7469.21 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1274.96 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6983.70 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1375.93 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6053.68 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1856.18 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5818.32 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1234.68 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6123.81 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1861.09 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6078.58 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1505.53 tokens per second.
# PTBTokenizer tokenized 531 tokens at 7472.19 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1438.45 tokens per second.
# PTBTokenizer tokenized 517 tokens at 7235.58 tokens per second.
# PTBTokenizer tokenized 94 tokens at 1060.60 tokens per second.
# PTBTokenizer tokenized 476 tokens at 6198.57 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1063.07 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6587.20 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1303.23 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6306.11 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1859.25 tokens per second.
# PTBTokenizer tokenized 666 tokens at 9024.77 tokens per second.
# PTBTokenizer tokenized 167 tokens at 1789.20 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7571.92 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1576.87 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6175.12 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1586.44 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7259.42 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1754.96 tokens per second.
# PTBTokenizer tokenized 611 tokens at 6936.41 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1607.43 tokens per second.
# PTBTokenizer tokenized 653 tokens at 6634.45 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2176.87 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6709.39 tokens per second.
# PTBTokenizer tokenized 162 tokens at 1786.88 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6363.47 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1658.66 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6140.03 tokens per second.
# PTBTokenizer tokenized 195 tokens at 2757.75 tokens per second.
# PTBTokenizer tokenized 543 tokens at 5860.85 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1581.50 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6115.10 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1778.65 tokens per second.
# PTBTokenizer tokenized 610 tokens at 8358.18 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1752.92 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7002.46 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1726.54 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6323.46 tokens per second.
# PTBTokenizer tokenized 90 tokens at 1323.65 tokens per second.
# PTBTokenizer tokenized 542 tokens at 7058.21 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1810.60 tokens per second.
# Epoch 2/30 | Loss: 4.4238 | Val CIDEr: 0.3640
# --> Saved Best XE Model (CIDEr: 0.3640)
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 6637.13 tokens per second.
# PTBTokenizer tokenized 188 tokens at 2328.01 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7759.62 tokens per second.
# PTBTokenizer tokenized 202 tokens at 2749.30 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6961.19 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1766.37 tokens per second.
# PTBTokenizer tokenized 664 tokens at 9005.17 tokens per second.
# PTBTokenizer tokenized 230 tokens at 2861.97 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7734.33 tokens per second.
# PTBTokenizer tokenized 231 tokens at 2884.05 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6863.90 tokens per second.
# PTBTokenizer tokenized 182 tokens at 2470.20 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6193.01 tokens per second.
# PTBTokenizer tokenized 202 tokens at 3020.65 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6760.15 tokens per second.
# PTBTokenizer tokenized 264 tokens at 3206.77 tokens per second.
# PTBTokenizer tokenized 609 tokens at 5692.58 tokens per second.
# PTBTokenizer tokenized 271 tokens at 2367.95 tokens per second.
# PTBTokenizer tokenized 528 tokens at 5143.82 tokens per second.
# PTBTokenizer tokenized 166 tokens at 1985.23 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6042.95 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1853.86 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6561.74 tokens per second.
# PTBTokenizer tokenized 142 tokens at 2097.10 tokens per second.
# PTBTokenizer tokenized 519 tokens at 7022.23 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2107.79 tokens per second.
# PTBTokenizer tokenized 533 tokens at 7134.55 tokens per second.
# PTBTokenizer tokenized 195 tokens at 2553.87 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6721.02 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2502.32 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6337.97 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1486.03 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5889.09 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1594.54 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6278.19 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1114.74 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6309.85 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1887.96 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5924.50 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1825.89 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5855.33 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1373.15 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5270.93 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1469.28 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6911.13 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1893.71 tokens per second.
# PTBTokenizer tokenized 485 tokens at 4383.86 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1639.75 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6201.12 tokens per second.
# PTBTokenizer tokenized 145 tokens at 2086.20 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6144.92 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1195.91 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6259.11 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1373.14 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6874.49 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1482.56 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6016.50 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1325.01 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6377.42 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1635.12 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7157.66 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1454.76 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6393.23 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1649.39 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6330.42 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1394.18 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6341.06 tokens per second.
# PTBTokenizer tokenized 148 tokens at 2133.40 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6082.24 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1453.14 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6927.39 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1532.78 tokens per second.
# PTBTokenizer tokenized 517 tokens at 7225.14 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1578.12 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5787.75 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1409.32 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5970.29 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1413.18 tokens per second.
# PTBTokenizer tokenized 527 tokens at 5358.74 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1655.92 tokens per second.
# PTBTokenizer tokenized 666 tokens at 8072.65 tokens per second.
# PTBTokenizer tokenized 228 tokens at 3368.00 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7685.93 tokens per second.
# PTBTokenizer tokenized 228 tokens at 3253.25 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6702.08 tokens per second.
# PTBTokenizer tokenized 176 tokens at 1984.85 tokens per second.
# PTBTokenizer tokenized 653 tokens at 9077.00 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1717.01 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7752.26 tokens per second.
# PTBTokenizer tokenized 247 tokens at 3071.12 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7675.92 tokens per second.
# PTBTokenizer tokenized 242 tokens at 3011.27 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6729.84 tokens per second.
# PTBTokenizer tokenized 219 tokens at 2742.30 tokens per second.
# PTBTokenizer tokenized 562 tokens at 7729.03 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1788.53 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6612.04 tokens per second.
# PTBTokenizer tokenized 189 tokens at 2413.17 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6645.39 tokens per second.
# PTBTokenizer tokenized 195 tokens at 2835.94 tokens per second.
# PTBTokenizer tokenized 579 tokens at 8115.66 tokens per second.
# PTBTokenizer tokenized 165 tokens at 1804.22 tokens per second.
# PTBTokenizer tokenized 610 tokens at 6542.02 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2391.24 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7433.50 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1830.20 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6502.51 tokens per second.
# PTBTokenizer tokenized 151 tokens at 2142.64 tokens per second.
# PTBTokenizer tokenized 542 tokens at 7214.74 tokens per second.
# PTBTokenizer tokenized 222 tokens at 3048.91 tokens per second.
# Epoch 3/30 | Loss: 4.1081 | Val CIDEr: 0.3992
# --> Saved Best XE Model (CIDEr: 0.3992)
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 5931.60 tokens per second.
# PTBTokenizer tokenized 200 tokens at 2407.83 tokens per second.
# PTBTokenizer tokenized 655 tokens at 8677.47 tokens per second.
# PTBTokenizer tokenized 251 tokens at 3550.64 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6511.06 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2457.58 tokens per second.
# PTBTokenizer tokenized 664 tokens at 6713.26 tokens per second.
# PTBTokenizer tokenized 243 tokens at 3599.09 tokens per second.
# PTBTokenizer tokenized 662 tokens at 8675.58 tokens per second.
# PTBTokenizer tokenized 255 tokens at 2825.26 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7508.26 tokens per second.
# PTBTokenizer tokenized 239 tokens at 3571.53 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6984.33 tokens per second.
# PTBTokenizer tokenized 200 tokens at 2626.94 tokens per second.
# PTBTokenizer tokenized 583 tokens at 7101.07 tokens per second.
# PTBTokenizer tokenized 221 tokens at 2643.50 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7073.89 tokens per second.
# PTBTokenizer tokenized 245 tokens at 3560.87 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6106.10 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1853.32 tokens per second.
# PTBTokenizer tokenized 546 tokens at 5472.93 tokens per second.
# PTBTokenizer tokenized 192 tokens at 2430.09 tokens per second.
# PTBTokenizer tokenized 525 tokens at 5968.42 tokens per second.
# PTBTokenizer tokenized 172 tokens at 2203.51 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6472.45 tokens per second.
# PTBTokenizer tokenized 237 tokens at 2918.63 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6469.27 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1682.69 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7644.16 tokens per second.
# PTBTokenizer tokenized 207 tokens at 3066.64 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6936.09 tokens per second.
# PTBTokenizer tokenized 181 tokens at 2320.56 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5880.98 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1955.04 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6325.70 tokens per second.
# PTBTokenizer tokenized 153 tokens at 2232.32 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6353.59 tokens per second.
# PTBTokenizer tokenized 174 tokens at 2190.23 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5857.02 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1823.95 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5837.02 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1644.40 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5565.25 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1628.30 tokens per second.
# PTBTokenizer tokenized 487 tokens at 5939.10 tokens per second.
# PTBTokenizer tokenized 153 tokens at 2300.87 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5643.40 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1924.09 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6129.15 tokens per second.
# PTBTokenizer tokenized 215 tokens at 3136.81 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6738.15 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2061.59 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6089.72 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1554.64 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5422.19 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1832.59 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5878.73 tokens per second.
# PTBTokenizer tokenized 154 tokens at 1494.67 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6022.03 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2131.57 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7000.77 tokens per second.
# PTBTokenizer tokenized 157 tokens at 1996.70 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6107.20 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2032.84 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6041.69 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1729.76 tokens per second.
# PTBTokenizer tokenized 524 tokens at 7374.90 tokens per second.
# PTBTokenizer tokenized 152 tokens at 2025.37 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6193.70 tokens per second.
# PTBTokenizer tokenized 155 tokens at 2068.48 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6576.38 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1937.37 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6000.91 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1635.15 tokens per second.
# PTBTokenizer tokenized 476 tokens at 6740.80 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2083.85 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5922.37 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1853.90 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6590.42 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1757.10 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7569.84 tokens per second.
# PTBTokenizer tokenized 159 tokens at 1970.63 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7174.90 tokens per second.
# PTBTokenizer tokenized 238 tokens at 3338.02 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7348.09 tokens per second.
# PTBTokenizer tokenized 179 tokens at 2260.51 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7680.24 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2044.52 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7554.54 tokens per second.
# PTBTokenizer tokenized 221 tokens at 2828.28 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7884.46 tokens per second.
# PTBTokenizer tokenized 227 tokens at 2859.69 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7452.22 tokens per second.
# PTBTokenizer tokenized 230 tokens at 2631.40 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6478.43 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1721.73 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6664.88 tokens per second.
# PTBTokenizer tokenized 235 tokens at 3047.52 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6514.44 tokens per second.
# PTBTokenizer tokenized 235 tokens at 3416.61 tokens per second.
# PTBTokenizer tokenized 579 tokens at 8095.03 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2419.29 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7193.75 tokens per second.
# PTBTokenizer tokenized 177 tokens at 2224.80 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7575.80 tokens per second.
# PTBTokenizer tokenized 181 tokens at 2296.07 tokens per second.
# PTBTokenizer tokenized 530 tokens at 7099.64 tokens per second.
# PTBTokenizer tokenized 195 tokens at 2415.35 tokens per second.
# PTBTokenizer tokenized 542 tokens at 7406.74 tokens per second.
# PTBTokenizer tokenized 245 tokens at 2840.58 tokens per second.
# Epoch 4/30 | Loss: 3.9111 | Val CIDEr: 0.2926
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 6902.62 tokens per second.
# PTBTokenizer tokenized 189 tokens at 2651.92 tokens per second.
# PTBTokenizer tokenized 655 tokens at 9082.57 tokens per second.
# PTBTokenizer tokenized 194 tokens at 2476.17 tokens per second.
# PTBTokenizer tokenized 584 tokens at 8061.91 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1879.90 tokens per second.
# PTBTokenizer tokenized 664 tokens at 7574.97 tokens per second.
# PTBTokenizer tokenized 205 tokens at 2596.90 tokens per second.
# PTBTokenizer tokenized 662 tokens at 6588.27 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2272.62 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6659.56 tokens per second.
# PTBTokenizer tokenized 263 tokens at 3330.74 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7082.99 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2076.19 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6277.45 tokens per second.
# PTBTokenizer tokenized 155 tokens at 1949.97 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6539.66 tokens per second.
# PTBTokenizer tokenized 216 tokens at 2783.84 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6222.17 tokens per second.
# PTBTokenizer tokenized 144 tokens at 2193.02 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6152.58 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1857.76 tokens per second.
# PTBTokenizer tokenized 525 tokens at 7345.58 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1659.96 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6931.94 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2377.24 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6443.78 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1561.87 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7497.59 tokens per second.
# PTBTokenizer tokenized 233 tokens at 2616.48 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6797.08 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1697.77 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6998.12 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1748.79 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6125.57 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1498.85 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6333.81 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1450.02 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6179.32 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1427.53 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5746.75 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1525.38 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5852.88 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1231.29 tokens per second.
# PTBTokenizer tokenized 487 tokens at 5926.89 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1474.81 tokens per second.
# PTBTokenizer tokenized 485 tokens at 6007.99 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1178.90 tokens per second.
# PTBTokenizer tokenized 502 tokens at 7242.87 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2608.51 tokens per second.
# PTBTokenizer tokenized 493 tokens at 7034.08 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1361.62 tokens per second.
# PTBTokenizer tokenized 503 tokens at 7068.90 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1378.30 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6918.70 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1802.55 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5878.03 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1292.16 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7387.56 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1676.93 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6670.47 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1612.56 tokens per second.
# PTBTokenizer tokenized 500 tokens at 5408.66 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1409.79 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5108.89 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1425.40 tokens per second.
# PTBTokenizer tokenized 524 tokens at 5996.29 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1365.21 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6929.74 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1344.72 tokens per second.
# PTBTokenizer tokenized 531 tokens at 7343.34 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1285.17 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6479.56 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1369.32 tokens per second.
# PTBTokenizer tokenized 476 tokens at 6535.13 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1491.31 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5309.39 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1400.13 tokens per second.
# PTBTokenizer tokenized 527 tokens at 5668.67 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1351.00 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7968.84 tokens per second.
# PTBTokenizer tokenized 174 tokens at 2079.55 tokens per second.
# PTBTokenizer tokenized 626 tokens at 6565.99 tokens per second.
# PTBTokenizer tokenized 187 tokens at 2334.66 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7103.75 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2211.47 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7887.87 tokens per second.
# PTBTokenizer tokenized 169 tokens at 2533.33 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8468.13 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2126.12 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7560.45 tokens per second.
# PTBTokenizer tokenized 292 tokens at 3663.63 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7164.39 tokens per second.
# PTBTokenizer tokenized 199 tokens at 2324.46 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6763.21 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2044.55 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7365.29 tokens per second.
# PTBTokenizer tokenized 187 tokens at 2110.64 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6793.62 tokens per second.
# PTBTokenizer tokenized 180 tokens at 2166.43 tokens per second.
# PTBTokenizer tokenized 579 tokens at 8208.28 tokens per second.
# PTBTokenizer tokenized 208 tokens at 2532.79 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7155.15 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1570.99 tokens per second.
# PTBTokenizer tokenized 615 tokens at 6650.57 tokens per second.
# PTBTokenizer tokenized 181 tokens at 2584.76 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6285.33 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2305.34 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6725.83 tokens per second.
# PTBTokenizer tokenized 219 tokens at 2667.58 tokens per second.
# Epoch 5/30 | Loss: 3.7501 | Val CIDEr: 0.5391
# --> Saved Best XE Model (CIDEr: 0.5391)
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 7793.09 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2279.65 tokens per second.
# PTBTokenizer tokenized 655 tokens at 6302.45 tokens per second.
# PTBTokenizer tokenized 212 tokens at 2775.88 tokens per second.
# PTBTokenizer tokenized 584 tokens at 8178.49 tokens per second.
# PTBTokenizer tokenized 176 tokens at 1769.85 tokens per second.
# PTBTokenizer tokenized 664 tokens at 8115.13 tokens per second.
# PTBTokenizer tokenized 203 tokens at 2755.81 tokens per second.
# PTBTokenizer tokenized 662 tokens at 8972.70 tokens per second.
# PTBTokenizer tokenized 166 tokens at 1922.89 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7792.10 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2150.00 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6905.65 tokens per second.
# PTBTokenizer tokenized 162 tokens at 2072.51 tokens per second.
# PTBTokenizer tokenized 583 tokens at 7033.54 tokens per second.
# PTBTokenizer tokenized 159 tokens at 2026.11 tokens per second.
# PTBTokenizer tokenized 609 tokens at 8179.02 tokens per second.
# PTBTokenizer tokenized 190 tokens at 2474.12 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6308.54 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1715.19 tokens per second.
# PTBTokenizer tokenized 546 tokens at 7503.71 tokens per second.
# PTBTokenizer tokenized 149 tokens at 1895.16 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6398.48 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1724.37 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6482.56 tokens per second.
# PTBTokenizer tokenized 149 tokens at 2242.74 tokens per second.
# PTBTokenizer tokenized 533 tokens at 5746.27 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1655.81 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6956.02 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2193.27 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7730.42 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1418.35 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5711.49 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1812.91 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6208.55 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1584.42 tokens per second.
# PTBTokenizer tokenized 529 tokens at 5091.19 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1900.73 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5885.47 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1829.63 tokens per second.
# PTBTokenizer tokenized 491 tokens at 6815.28 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1296.05 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6247.77 tokens per second.
# PTBTokenizer tokenized 162 tokens at 1964.17 tokens per second.
# PTBTokenizer tokenized 487 tokens at 5883.99 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1509.37 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5787.71 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1325.67 tokens per second.
# PTBTokenizer tokenized 502 tokens at 5846.47 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1521.18 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5719.29 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1520.42 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6025.66 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1544.06 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5579.25 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1629.06 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5847.10 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1800.99 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7307.55 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1983.11 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7312.25 tokens per second.
# PTBTokenizer tokenized 177 tokens at 2154.58 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6969.73 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1523.05 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5939.65 tokens per second.
# PTBTokenizer tokenized 181 tokens at 1752.51 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6040.73 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1896.42 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6122.67 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1740.01 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6316.97 tokens per second.
# PTBTokenizer tokenized 173 tokens at 2169.62 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5767.71 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1411.28 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5818.49 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1633.72 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5919.95 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1475.63 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6520.58 tokens per second.
# PTBTokenizer tokenized 150 tokens at 2098.57 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7732.31 tokens per second.
# PTBTokenizer tokenized 158 tokens at 1924.63 tokens per second.
# PTBTokenizer tokenized 626 tokens at 6862.71 tokens per second.
# PTBTokenizer tokenized 180 tokens at 2150.71 tokens per second.
# PTBTokenizer tokenized 543 tokens at 5716.64 tokens per second.
# PTBTokenizer tokenized 159 tokens at 1937.51 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7684.90 tokens per second.
# PTBTokenizer tokenized 157 tokens at 1926.14 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7233.74 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2568.22 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7376.93 tokens per second.
# PTBTokenizer tokenized 218 tokens at 2762.25 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7120.22 tokens per second.
# PTBTokenizer tokenized 205 tokens at 2616.95 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6664.65 tokens per second.
# PTBTokenizer tokenized 173 tokens at 1987.30 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6845.22 tokens per second.
# PTBTokenizer tokenized 207 tokens at 2413.18 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7623.58 tokens per second.
# PTBTokenizer tokenized 177 tokens at 2186.24 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6921.55 tokens per second.
# PTBTokenizer tokenized 179 tokens at 2284.67 tokens per second.
# PTBTokenizer tokenized 610 tokens at 8465.90 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1772.74 tokens per second.
# PTBTokenizer tokenized 615 tokens at 8245.00 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1876.11 tokens per second.
# PTBTokenizer tokenized 530 tokens at 7486.92 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2043.17 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6610.01 tokens per second.
# PTBTokenizer tokenized 187 tokens at 2318.56 tokens per second.
# Epoch 6/30 | Loss: 3.6169 | Val CIDEr: 0.4505
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 6946.11 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1948.50 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7841.54 tokens per second.
# PTBTokenizer tokenized 177 tokens at 2284.17 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6822.21 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1546.50 tokens per second.
# PTBTokenizer tokenized 664 tokens at 8125.62 tokens per second.
# PTBTokenizer tokenized 178 tokens at 1886.39 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7045.08 tokens per second.
# PTBTokenizer tokenized 169 tokens at 2512.04 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6758.52 tokens per second.
# PTBTokenizer tokenized 187 tokens at 2446.39 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6890.49 tokens per second.
# PTBTokenizer tokenized 177 tokens at 2136.29 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6208.73 tokens per second.
# PTBTokenizer tokenized 197 tokens at 2398.47 tokens per second.
# PTBTokenizer tokenized 609 tokens at 8304.88 tokens per second.
# PTBTokenizer tokenized 176 tokens at 2271.01 tokens per second.
# PTBTokenizer tokenized 528 tokens at 5970.30 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1605.09 tokens per second.
# PTBTokenizer tokenized 546 tokens at 7688.85 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1700.53 tokens per second.
# PTBTokenizer tokenized 525 tokens at 7385.05 tokens per second.
# PTBTokenizer tokenized 140 tokens at 2073.26 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6318.18 tokens per second.
# PTBTokenizer tokenized 189 tokens at 2268.29 tokens per second.
# PTBTokenizer tokenized 533 tokens at 7630.85 tokens per second.
# PTBTokenizer tokenized 187 tokens at 2059.65 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7009.27 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2036.53 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6620.42 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1606.90 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6087.98 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1817.52 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6217.40 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1999.25 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6620.00 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1731.82 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5355.28 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1659.57 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5377.63 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1016.03 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6165.99 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1556.96 tokens per second.
# PTBTokenizer tokenized 487 tokens at 5361.82 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1361.51 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5532.30 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1286.59 tokens per second.
# PTBTokenizer tokenized 502 tokens at 7134.21 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1671.60 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6093.65 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1544.10 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6105.78 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1632.41 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6048.01 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1751.07 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6161.52 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1550.27 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6391.88 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1822.76 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6143.56 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1574.84 tokens per second.
# PTBTokenizer tokenized 500 tokens at 5910.42 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1600.02 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6039.45 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1706.62 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6190.12 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1288.49 tokens per second.
# PTBTokenizer tokenized 501 tokens at 5346.75 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1719.85 tokens per second.
# PTBTokenizer tokenized 531 tokens at 5747.35 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1756.13 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5338.56 tokens per second.
# ...
# PTBTokenizer tokenized 146 tokens at 1484.52 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6208.46 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1614.73 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7461.84 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1804.89 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7457.56 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1679.95 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7641.72 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2044.74 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6503.94 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1791.27 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6479.06 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1630.77 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6733.35 tokens per second.
# PTBTokenizer tokenized 182 tokens at 2282.82 tokens per second.
# PTBTokenizer tokenized 543 tokens at 5410.55 tokens per second.
# PTBTokenizer tokenized 154 tokens at 2294.80 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6895.55 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1792.00 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7347.79 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1577.82 tokens per second.
# PTBTokenizer tokenized 615 tokens at 8613.25 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1739.74 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6928.14 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1760.67 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6416.48 tokens per second.
# PTBTokenizer tokenized 157 tokens at 2123.35 tokens per second.
# Epoch 28/30 | Loss: 1.5955 | Val CIDEr: 0.5338
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 7936.93 tokens per second.
# PTBTokenizer tokenized 159 tokens at 2369.65 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7023.26 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1987.42 tokens per second.
# PTBTokenizer tokenized 584 tokens at 8074.83 tokens per second.
# PTBTokenizer tokenized 149 tokens at 2146.84 tokens per second.
# PTBTokenizer tokenized 664 tokens at 7742.04 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2452.11 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7882.03 tokens per second.
# PTBTokenizer tokenized 139 tokens at 2005.64 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6558.91 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2242.10 tokens per second.
# PTBTokenizer tokenized 577 tokens at 8119.03 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1928.81 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6931.01 tokens per second.
# PTBTokenizer tokenized 155 tokens at 2089.98 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6386.97 tokens per second.
# PTBTokenizer tokenized 159 tokens at 2089.58 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6326.65 tokens per second.
# PTBTokenizer tokenized 142 tokens at 2122.41 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6013.70 tokens per second.
# PTBTokenizer tokenized 161 tokens at 2022.51 tokens per second.
# PTBTokenizer tokenized 525 tokens at 5657.86 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1943.69 tokens per second.
# PTBTokenizer tokenized 519 tokens at 7340.48 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1418.47 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6429.59 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1994.13 tokens per second.
# PTBTokenizer tokenized 590 tokens at 8253.92 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1881.58 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6559.23 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1565.66 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5682.48 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1936.54 tokens per second.
# PTBTokenizer tokenized 511 tokens at 5929.51 tokens per second.
# PTBTokenizer tokenized 89 tokens at 1309.96 tokens per second.
# PTBTokenizer tokenized 529 tokens at 7368.65 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1238.60 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5210.71 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1406.06 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5883.44 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1180.82 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5822.07 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1498.31 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6158.85 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1268.09 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5848.08 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1452.22 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6367.51 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1550.85 tokens per second.
# PTBTokenizer tokenized 493 tokens at 7004.58 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1266.93 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6465.58 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1728.95 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6137.53 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1522.94 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6311.22 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1417.90 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6477.18 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1603.20 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6257.79 tokens per second.
# PTBTokenizer tokenized 136 tokens at 2006.27 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6738.89 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1375.62 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5581.87 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1616.08 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6333.09 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1568.46 tokens per second.
# PTBTokenizer tokenized 501 tokens at 5985.65 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1527.98 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6368.81 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1578.20 tokens per second.
# PTBTokenizer tokenized 517 tokens at 5512.63 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1421.50 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5936.63 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1665.14 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5838.78 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1513.26 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6941.34 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1574.99 tokens per second.
# PTBTokenizer tokenized 666 tokens at 8169.73 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1796.87 tokens per second.
# PTBTokenizer tokenized 626 tokens at 7484.82 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1597.56 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6547.01 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1978.55 tokens per second.
# PTBTokenizer tokenized 653 tokens at 6916.91 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1878.29 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8381.40 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2315.73 tokens per second.
# PTBTokenizer tokenized 653 tokens at 8603.12 tokens per second.
# PTBTokenizer tokenized 169 tokens at 2105.57 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7067.10 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2106.69 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6806.41 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1815.79 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6585.85 tokens per second.
# PTBTokenizer tokenized 192 tokens at 2407.61 tokens per second.
# PTBTokenizer tokenized 543 tokens at 5804.44 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2533.78 tokens per second.
# PTBTokenizer tokenized 579 tokens at 8141.48 tokens per second.
# PTBTokenizer tokenized 169 tokens at 2145.36 tokens per second.
# PTBTokenizer tokenized 610 tokens at 8086.35 tokens per second.
# PTBTokenizer tokenized 158 tokens at 1986.78 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7287.74 tokens per second.
# PTBTokenizer tokenized 136 tokens at 2044.79 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6335.03 tokens per second.
# PTBTokenizer tokenized 157 tokens at 2159.55 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6474.55 tokens per second.
# PTBTokenizer tokenized 155 tokens at 2141.19 tokens per second.
# Epoch 29/30 | Loss: 1.5654 | Val CIDEr: 0.5145
# Evaluating CIDEr (Greedy)...
# PTBTokenizer tokenized 572 tokens at 6840.53 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1849.05 tokens per second.
# PTBTokenizer tokenized 655 tokens at 7169.66 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1726.77 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6954.91 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1905.72 tokens per second.
# PTBTokenizer tokenized 664 tokens at 8853.32 tokens per second.
# PTBTokenizer tokenized 144 tokens at 2089.86 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7759.56 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1668.27 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7701.11 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2146.28 tokens per second.
# PTBTokenizer tokenized 577 tokens at 5681.00 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1653.52 tokens per second.
# PTBTokenizer tokenized 583 tokens at 6190.68 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1666.31 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6480.02 tokens per second.
# PTBTokenizer tokenized 143 tokens at 2104.65 tokens per second.
# PTBTokenizer tokenized 528 tokens at 7571.20 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1380.17 tokens per second.
# PTBTokenizer tokenized 546 tokens at 5769.67 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1662.53 tokens per second.
# PTBTokenizer tokenized 525 tokens at 7212.78 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1745.96 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6302.40 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1971.29 tokens per second.
# PTBTokenizer tokenized 533 tokens at 7128.85 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1580.34 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7149.27 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1550.14 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6986.60 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1549.57 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5639.16 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1693.57 tokens per second.
# PTBTokenizer tokenized 511 tokens at 7033.33 tokens per second.
# PTBTokenizer tokenized 94 tokens at 1358.70 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6400.42 tokens per second.
# PTBTokenizer tokenized 92 tokens at 1145.06 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6084.37 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1277.49 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5451.35 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1077.82 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6139.93 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1315.91 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6886.41 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1188.95 tokens per second.
# PTBTokenizer tokenized 485 tokens at 6652.97 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1220.14 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6568.37 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1455.69 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6192.27 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1284.77 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5894.33 tokens per second.
# PTBTokenizer tokenized 94 tokens at 1182.90 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5334.78 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1591.98 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7246.29 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1365.80 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6648.29 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1743.57 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7263.86 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1554.99 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6056.94 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1198.13 tokens per second.
# PTBTokenizer tokenized 517 tokens at 7191.63 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1688.63 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6661.55 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1586.35 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6240.53 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1549.02 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6477.77 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1902.87 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6037.13 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1343.71 tokens per second.
# PTBTokenizer tokenized 476 tokens at 6684.25 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1819.83 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6209.25 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1439.37 tokens per second.
# PTBTokenizer tokenized 527 tokens at 5302.97 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1913.97 tokens per second.
# PTBTokenizer tokenized 666 tokens at 8897.40 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1500.95 tokens per second.
# PTBTokenizer tokenized 626 tokens at 8809.26 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1729.46 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6658.52 tokens per second.
# PTBTokenizer tokenized 149 tokens at 1902.03 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7269.11 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1324.53 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7376.96 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1677.60 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7722.32 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2287.51 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7782.74 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1684.31 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6651.43 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1492.73 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6403.99 tokens per second.
# PTBTokenizer tokenized 169 tokens at 1973.14 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7549.65 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1703.37 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6637.69 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1981.96 tokens per second.
# PTBTokenizer tokenized 610 tokens at 6744.70 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1934.15 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7817.45 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1973.16 tokens per second.
# PTBTokenizer tokenized 530 tokens at 7020.01 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1884.33 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6584.76 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1782.48 tokens per second.
# Epoch 30/30 | Loss: 1.5375 | Val CIDEr: 0.5726

# %%
# !python train_scst.py
# Out:
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 2): 2719
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 3512 images.
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 439 images.
# --> Loading BEST XE Model from: /kaggle/working/get_model_best_xe.pth
# Checking initial CIDEr...
# Evaluating CIDEr on Validation set...
# PTBTokenizer tokenized 572 tokens at 7950.54 tokens per second.
# PTBTokenizer tokenized 151 tokens at 2098.92 tokens per second.
# PTBTokenizer tokenized 655 tokens at 9030.99 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1306.10 tokens per second.
# PTBTokenizer tokenized 584 tokens at 7973.72 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1540.16 tokens per second.
# PTBTokenizer tokenized 664 tokens at 7805.77 tokens per second.
# PTBTokenizer tokenized 166 tokens at 2135.82 tokens per second.
# PTBTokenizer tokenized 662 tokens at 7848.22 tokens per second.
# PTBTokenizer tokenized 141 tokens at 2099.45 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6496.38 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1752.47 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7284.03 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1757.28 tokens per second.
# PTBTokenizer tokenized 583 tokens at 7218.58 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1911.71 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7366.19 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1819.43 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6103.98 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1399.66 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6628.33 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1945.47 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6428.49 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1747.55 tokens per second.
# PTBTokenizer tokenized 519 tokens at 7003.25 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2127.00 tokens per second.
# PTBTokenizer tokenized 533 tokens at 5750.86 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1808.33 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7007.53 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1829.71 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7452.23 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1363.02 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5272.27 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1699.77 tokens per second.
# PTBTokenizer tokenized 511 tokens at 5489.50 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1490.69 tokens per second.
# PTBTokenizer tokenized 529 tokens at 5882.74 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1194.76 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6093.05 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1146.37 tokens per second.
# PTBTokenizer tokenized 491 tokens at 6097.61 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1212.37 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6116.83 tokens per second.
# PTBTokenizer tokenized 88 tokens at 1133.62 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6345.50 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1418.14 tokens per second.
# PTBTokenizer tokenized 485 tokens at 5949.21 tokens per second.
# PTBTokenizer tokenized 89 tokens at 1288.53 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6184.70 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1914.64 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6807.51 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1443.28 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6126.38 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1215.68 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5620.87 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1810.64 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7201.79 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1418.30 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6308.04 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1246.15 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6361.19 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1366.64 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6037.73 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1581.81 tokens per second.
# PTBTokenizer tokenized 517 tokens at 7187.95 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1417.00 tokens per second.
# PTBTokenizer tokenized 524 tokens at 7305.53 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1431.94 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6020.34 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1467.16 tokens per second.
# PTBTokenizer tokenized 531 tokens at 5854.30 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1385.61 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6505.81 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1535.56 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5781.47 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1905.91 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5910.59 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1461.79 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7579.72 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1283.82 tokens per second.
# PTBTokenizer tokenized 666 tokens at 8717.82 tokens per second.
# PTBTokenizer tokenized 149 tokens at 1890.48 tokens per second.
# PTBTokenizer tokenized 626 tokens at 8203.72 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1523.94 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6400.56 tokens per second.
# PTBTokenizer tokenized 143 tokens at 2015.15 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7702.27 tokens per second.
# PTBTokenizer tokenized 150 tokens at 2113.85 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7814.17 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2156.49 tokens per second.
# PTBTokenizer tokenized 653 tokens at 8615.26 tokens per second.
# PTBTokenizer tokenized 152 tokens at 2187.68 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7193.17 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2062.04 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6283.38 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1609.38 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6810.77 tokens per second.
# PTBTokenizer tokenized 194 tokens at 2517.01 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6720.04 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1666.20 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6858.41 tokens per second.
# PTBTokenizer tokenized 164 tokens at 1888.54 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7641.58 tokens per second.
# PTBTokenizer tokenized 154 tokens at 1973.27 tokens per second.
# PTBTokenizer tokenized 615 tokens at 6968.77 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1964.98 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6610.90 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1325.83 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6317.29 tokens per second.
# PTBTokenizer tokenized 176 tokens at 2107.20 tokens per second.
# Initial CIDEr: 0.6439
#
# === Starting Phase 2: SCST Training (Stable Greedy Baseline) ===
# PTBTokenizer tokenized 618 tokens at 8351.92 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1546.90 tokens per second.
# PTBTokenizer tokenized 3094 tokens at 28802.44 tokens per second.
# PTBTokenizer tokenized 664 tokens at 9269.16 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7384.93 tokens per second.
# PTBTokenizer tokenized 183 tokens at 1981.28 tokens per second.
# PTBTokenizer tokenized 3159 tokens at 34963.06 tokens per second.
# PTBTokenizer tokenized 911 tokens at 10474.64 tokens per second.
# PTBTokenizer tokenized 545 tokens at 6618.53 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1733.39 tokens per second.
# PTBTokenizer tokenized 2729 tokens at 26216.10 tokens per second.
# PTBTokenizer tokenized 677 tokens at 8188.44 tokens per second.
# PTBTokenizer tokenized 537 tokens at 6985.29 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1409.23 tokens per second.
# PTBTokenizer tokenized 2689 tokens at 25959.42 tokens per second.
# PTBTokenizer tokenized 612 tokens at 7800.91 tokens per second.
# PTBTokenizer tokenized 502 tokens at 6710.60 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1243.21 tokens per second.
# PTBTokenizer tokenized 2514 tokens at 26509.37 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5578.23 tokens per second.
# PTBTokenizer tokenized 553 tokens at 7737.18 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1483.41 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 28137.66 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7311.80 tokens per second.
# PTBTokenizer tokenized 595 tokens at 7288.23 tokens per second.
# PTBTokenizer tokenized 143 tokens at 2011.58 tokens per second.
# PTBTokenizer tokenized 2979 tokens at 27219.56 tokens per second.
# PTBTokenizer tokenized 718 tokens at 9813.46 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6458.70 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1479.10 tokens per second.
# PTBTokenizer tokenized 2719 tokens at 32228.74 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6624.05 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6163.75 tokens per second.
# PTBTokenizer tokenized 143 tokens at 2087.54 tokens per second.
# PTBTokenizer tokenized 2519 tokens at 26881.90 tokens per second.
# PTBTokenizer tokenized 701 tokens at 8234.11 tokens per second.
# PTBTokenizer tokenized 641 tokens at 7179.85 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1995.33 tokens per second.
# PTBTokenizer tokenized 3209 tokens at 34567.33 tokens per second.
# PTBTokenizer tokenized 670 tokens at 9267.78 tokens per second.
# PTBTokenizer tokenized 621 tokens at 7547.76 tokens per second.
# PTBTokenizer tokenized 168 tokens at 2496.19 tokens per second.
# PTBTokenizer tokenized 3109 tokens at 28127.00 tokens per second.
# PTBTokenizer tokenized 784 tokens at 9361.80 tokens per second.
# PTBTokenizer tokenized 568 tokens at 8008.91 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1632.71 tokens per second.
# PTBTokenizer tokenized 2844 tokens at 26852.14 tokens per second.
# PTBTokenizer tokenized 693 tokens at 9708.71 tokens per second.
# PTBTokenizer tokenized 572 tokens at 6837.90 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1898.00 tokens per second.
# PTBTokenizer tokenized 2864 tokens at 26787.78 tokens per second.
# PTBTokenizer tokenized 732 tokens at 9015.14 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6280.37 tokens per second.
# PTBTokenizer tokenized 172 tokens at 2179.71 tokens per second.
# PTBTokenizer tokenized 2624 tokens at 26874.29 tokens per second.
# PTBTokenizer tokenized 853 tokens at 9600.92 tokens per second.
# PTBTokenizer tokenized 550 tokens at 6777.18 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1562.80 tokens per second.
# PTBTokenizer tokenized 2754 tokens at 28788.79 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7632.79 tokens per second.
# PTBTokenizer tokenized 545 tokens at 7611.79 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1691.53 tokens per second.
# PTBTokenizer tokenized 2729 tokens at 29366.83 tokens per second.
# PTBTokenizer tokenized 702 tokens at 9239.63 tokens per second.
# PTBTokenizer tokenized 558 tokens at 7354.39 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1889.09 tokens per second.
# PTBTokenizer tokenized 2794 tokens at 26592.65 tokens per second.
# PTBTokenizer tokenized 747 tokens at 8326.59 tokens per second.
# PTBTokenizer tokenized 563 tokens at 6148.47 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1996.48 tokens per second.
# PTBTokenizer tokenized 2819 tokens at 26674.40 tokens per second.
# PTBTokenizer tokenized 719 tokens at 7577.93 tokens per second.
# PTBTokenizer tokenized 607 tokens at 7465.85 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2181.51 tokens per second.
# PTBTokenizer tokenized 3039 tokens at 28685.82 tokens per second.
# PTBTokenizer tokenized 927 tokens at 11150.03 tokens per second.
# PTBTokenizer tokenized 580 tokens at 8007.52 tokens per second.
# PTBTokenizer tokenized 164 tokens at 1967.95 tokens per second.
# PTBTokenizer tokenized 2904 tokens at 29370.09 tokens per second.
# PTBTokenizer tokenized 809 tokens at 9389.85 tokens per second.
# PTBTokenizer tokenized 537 tokens at 5963.83 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1593.32 tokens per second.
# PTBTokenizer tokenized 2689 tokens at 25535.33 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7632.47 tokens per second.
# PTBTokenizer tokenized 465 tokens at 5489.06 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1679.57 tokens per second.
# PTBTokenizer tokenized 2329 tokens at 27988.91 tokens per second.
# PTBTokenizer tokenized 651 tokens at 7774.32 tokens per second.
# PTBTokenizer tokenized 568 tokens at 7894.68 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1768.96 tokens per second.
# PTBTokenizer tokenized 2844 tokens at 26061.20 tokens per second.
# PTBTokenizer tokenized 710 tokens at 7890.86 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6543.62 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1867.92 tokens per second.
# PTBTokenizer tokenized 2624 tokens at 26248.65 tokens per second.
# PTBTokenizer tokenized 703 tokens at 8113.53 tokens per second.
# PTBTokenizer tokenized 528 tokens at 6025.97 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1476.77 tokens per second.
# PTBTokenizer tokenized 2644 tokens at 27524.34 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7423.41 tokens per second.
# PTBTokenizer tokenized 593 tokens at 6078.87 tokens per second.
# PTBTokenizer tokenized 153 tokens at 2008.40 tokens per second.
# PTBTokenizer tokenized 2969 tokens at 25706.41 tokens per second.
# PTBTokenizer tokenized 718 tokens at 8649.85 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6344.83 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1804.49 tokens per second.
# PTBTokenizer tokenized 2734 tokens at 25450.65 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7695.18 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7526.28 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1366.15 tokens per second.
# PTBTokenizer tokenized 2719 tokens at 30179.79 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5967.24 tokens per second.
# PTBTokenizer tokenized 576 tokens at 8184.53 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1792.92 tokens per second.
# PTBTokenizer tokenized 2884 tokens at 27401.02 tokens per second.
# PTBTokenizer tokenized 627 tokens at 7332.93 tokens per second.
# PTBTokenizer tokenized 568 tokens at 6614.76 tokens per second.
# PTBTokenizer tokenized 189 tokens at 2428.20 tokens per second.
# PTBTokenizer tokenized 2844 tokens at 26527.10 tokens per second.
# PTBTokenizer tokenized 964 tokens at 13076.00 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6290.17 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1499.86 tokens per second.
# PTBTokenizer tokenized 2674 tokens at 31714.11 tokens per second.
# PTBTokenizer tokenized 595 tokens at 7394.17 tokens per second.
# PTBTokenizer tokenized 535 tokens at 6313.22 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1412.13 tokens per second.
# PTBTokenizer tokenized 2679 tokens at 24267.89 tokens per second.
# PTBTokenizer tokenized 554 tokens at 7019.31 tokens per second.
# PTBTokenizer tokenized 571 tokens at 7210.08 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1422.46 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 29342.02 tokens per second.
# PTBTokenizer tokenized 621 tokens at 7769.34 tokens per second.
# PTBTokenizer tokenized 547 tokens at 5845.49 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1654.27 tokens per second.
# PTBTokenizer tokenized 2739 tokens at 26036.83 tokens per second.
# PTBTokenizer tokenized 686 tokens at 8292.62 tokens per second.
# PTBTokenizer tokenized 581 tokens at 7311.26 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1667.52 tokens per second.
# PTBTokenizer tokenized 2909 tokens at 32667.61 tokens per second.
# PTBTokenizer tokenized 657 tokens at 9087.69 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5040.39 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1171.65 tokens per second.
# PTBTokenizer tokenized 2384 tokens at 23726.47 tokens per second.
# PTBTokenizer tokenized 454 tokens at 5512.62 tokens per second.
# PTBTokenizer tokenized 539 tokens at 6572.36 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1471.77 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 27863.01 tokens per second.
# PTBTokenizer tokenized 582 tokens at 6410.63 tokens per second.
# PTBTokenizer tokenized 545 tokens at 6197.10 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1953.00 tokens per second.
# PTBTokenizer tokenized 2729 tokens at 25873.95 tokens per second.
# PTBTokenizer tokenized 675 tokens at 8444.93 tokens per second.
# PTBTokenizer tokenized 643 tokens at 7607.49 tokens per second.
# PTBTokenizer tokenized 213 tokens at 2554.90 tokens per second.
# PTBTokenizer tokenized 3219 tokens at 25981.30 tokens per second.
# PTBTokenizer tokenized 1051 tokens at 14220.32 tokens per second.
# PTBTokenizer tokenized 584 tokens at 6085.33 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2087.26 tokens per second.
# PTBTokenizer tokenized 2924 tokens at 34078.02 tokens per second.
# PTBTokenizer tokenized 782 tokens at 9246.42 tokens per second.
# PTBTokenizer tokenized 518 tokens at 7296.62 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1417.59 tokens per second.
# PTBTokenizer tokenized 2594 tokens at 30803.96 tokens per second.
# PTBTokenizer tokenized 624 tokens at 7262.86 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7519.40 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1780.09 tokens per second.
# PTBTokenizer tokenized 3014 tokens at 30778.62 tokens per second.
# PTBTokenizer tokenized 681 tokens at 8122.23 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7832.46 tokens per second.
# PTBTokenizer tokenized 176 tokens at 2605.28 tokens per second.
# PTBTokenizer tokenized 3089 tokens at 28706.48 tokens per second.
# PTBTokenizer tokenized 863 tokens at 10179.35 tokens per second.
# PTBTokenizer tokenized 601 tokens at 7504.80 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1745.16 tokens per second.
# PTBTokenizer tokenized 3009 tokens at 29031.36 tokens per second.
# PTBTokenizer tokenized 708 tokens at 8555.42 tokens per second.
# PTBTokenizer tokenized 575 tokens at 7765.74 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1588.95 tokens per second.
# PTBTokenizer tokenized 2879 tokens at 30028.69 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7722.21 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6063.80 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1314.52 tokens per second.
# PTBTokenizer tokenized 2589 tokens at 30382.14 tokens per second.
# PTBTokenizer tokenized 500 tokens at 5901.47 tokens per second.
# PTBTokenizer tokenized 639 tokens at 8942.54 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1717.62 tokens per second.
# PTBTokenizer tokenized 3199 tokens at 29478.64 tokens per second.
# PTBTokenizer tokenized 700 tokens at 9418.77 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6417.60 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1515.91 tokens per second.
# PTBTokenizer tokenized 2669 tokens at 23664.99 tokens per second.
# PTBTokenizer tokenized 582 tokens at 6437.99 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7315.97 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2147.89 tokens per second.
# PTBTokenizer tokenized 3049 tokens at 33004.30 tokens per second.
# PTBTokenizer tokenized 796 tokens at 10980.46 tokens per second.
# PTBTokenizer tokenized 483 tokens at 5962.72 tokens per second.
# PTBTokenizer tokenized 89 tokens at 1142.71 tokens per second.
# PTBTokenizer tokenized 2419 tokens at 28012.89 tokens per second.
# PTBTokenizer tokenized 449 tokens at 5462.62 tokens per second.
# PTBTokenizer tokenized 703 tokens at 8924.21 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2371.67 tokens per second.
# PTBTokenizer tokenized 3519 tokens at 37564.16 tokens per second.
# PTBTokenizer tokenized 784 tokens at 9358.36 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6219.64 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1687.77 tokens per second.
# PTBTokenizer tokenized 2719 tokens at 25181.46 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7775.44 tokens per second.
# PTBTokenizer tokenized 549 tokens at 6540.41 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1767.57 tokens per second.
# PTBTokenizer tokenized 2749 tokens at 26208.28 tokens per second.
# PTBTokenizer tokenized 647 tokens at 7841.45 tokens per second.
# PTBTokenizer tokenized 558 tokens at 6172.11 tokens per second.
# PTBTokenizer tokenized 141 tokens at 2004.73 tokens per second.
# PTBTokenizer tokenized 2794 tokens at 29255.76 tokens per second.
# PTBTokenizer tokenized 714 tokens at 8314.52 tokens per second.
# PTBTokenizer tokenized 524 tokens at 7275.64 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1312.27 tokens per second.
# PTBTokenizer tokenized 2624 tokens at 25822.11 tokens per second.
# PTBTokenizer tokenized 574 tokens at 6807.76 tokens per second.
# PTBTokenizer tokenized 571 tokens at 7377.95 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1855.10 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 29379.26 tokens per second.
# PTBTokenizer tokenized 681 tokens at 8203.74 tokens per second.
# PTBTokenizer tokenized 587 tokens at 6024.03 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2003.83 tokens per second.
# PTBTokenizer tokenized 2939 tokens at 25868.68 tokens per second.
# PTBTokenizer tokenized 796 tokens at 10921.36 tokens per second.
# PTBTokenizer tokenized 539 tokens at 7247.00 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1732.07 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 24293.33 tokens per second.
# PTBTokenizer tokenized 606 tokens at 7266.93 tokens per second.
# PTBTokenizer tokenized 515 tokens at 6222.47 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1693.72 tokens per second.
# PTBTokenizer tokenized 2579 tokens at 24838.82 tokens per second.
# PTBTokenizer tokenized 632 tokens at 7566.82 tokens per second.
# PTBTokenizer tokenized 541 tokens at 6592.95 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1413.54 tokens per second.
# PTBTokenizer tokenized 2709 tokens at 28409.82 tokens per second.
# PTBTokenizer tokenized 597 tokens at 8118.45 tokens per second.
# PTBTokenizer tokenized 570 tokens at 6577.41 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1390.33 tokens per second.
# PTBTokenizer tokenized 2854 tokens at 22966.32 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6779.54 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6774.33 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1652.61 tokens per second.
# PTBTokenizer tokenized 2444 tokens at 26255.34 tokens per second.
# PTBTokenizer tokenized 574 tokens at 6733.62 tokens per second.
# PTBTokenizer tokenized 566 tokens at 6990.01 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1495.34 tokens per second.
# PTBTokenizer tokenized 2834 tokens at 26090.09 tokens per second.
# PTBTokenizer tokenized 590 tokens at 8344.13 tokens per second.
# PTBTokenizer tokenized 619 tokens at 8758.72 tokens per second.
# PTBTokenizer tokenized 138 tokens at 2020.81 tokens per second.
# PTBTokenizer tokenized 3099 tokens at 28825.22 tokens per second.
# PTBTokenizer tokenized 705 tokens at 7949.43 tokens per second.
# PTBTokenizer tokenized 558 tokens at 6716.78 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1950.16 tokens per second.
# PTBTokenizer tokenized 2794 tokens at 25845.07 tokens per second.
# PTBTokenizer tokenized 627 tokens at 8727.12 tokens per second.
# PTBTokenizer tokenized 563 tokens at 6674.61 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1888.65 tokens per second.
# PTBTokenizer tokenized 2819 tokens at 28089.01 tokens per second.
# PTBTokenizer tokenized 663 tokens at 9366.30 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6466.71 tokens per second.
# PTBTokenizer tokenized 157 tokens at 1995.27 tokens per second.
# PTBTokenizer tokenized 2759 tokens at 27280.28 tokens per second.
# PTBTokenizer tokenized 799 tokens at 9511.55 tokens per second.
# PTBTokenizer tokenized 523 tokens at 7177.45 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1716.08 tokens per second.
# PTBTokenizer tokenized 2619 tokens at 27566.83 tokens per second.
# PTBTokenizer tokenized 689 tokens at 8240.30 tokens per second.
# PTBTokenizer tokenized 606 tokens at 7303.56 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1733.58 tokens per second.
# PTBTokenizer tokenized 3034 tokens at 27597.05 tokens per second.
# PTBTokenizer tokenized 676 tokens at 7861.41 tokens per second.
# PTBTokenizer tokenized 546 tokens at 5878.36 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1616.03 tokens per second.
# PTBTokenizer tokenized 2734 tokens at 28354.73 tokens per second.
# PTBTokenizer tokenized 647 tokens at 8015.47 tokens per second.
# PTBTokenizer tokenized 539 tokens at 6287.88 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1506.85 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 25305.81 tokens per second.
# PTBTokenizer tokenized 632 tokens at 7614.41 tokens per second.
# PTBTokenizer tokenized 544 tokens at 6461.33 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1984.34 tokens per second.
# PTBTokenizer tokenized 2724 tokens at 30660.56 tokens per second.
# PTBTokenizer tokenized 675 tokens at 8154.45 tokens per second.
# PTBTokenizer tokenized 539 tokens at 6500.28 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1616.90 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 28317.37 tokens per second.
# PTBTokenizer tokenized 585 tokens at 6989.46 tokens per second.
# PTBTokenizer tokenized 590 tokens at 6720.57 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1646.38 tokens per second.
# PTBTokenizer tokenized 2954 tokens at 27507.73 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7699.76 tokens per second.
# PTBTokenizer tokenized 547 tokens at 6662.71 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1689.40 tokens per second.
# PTBTokenizer tokenized 2739 tokens at 31872.51 tokens per second.
# PTBTokenizer tokenized 563 tokens at 6811.09 tokens per second.
# PTBTokenizer tokenized 520 tokens at 5551.04 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2585.71 tokens per second.
# PTBTokenizer tokenized 2604 tokens at 27099.03 tokens per second.
# PTBTokenizer tokenized 880 tokens at 10307.21 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7756.08 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2032.78 tokens per second.
# PTBTokenizer tokenized 2839 tokens at 32691.29 tokens per second.
# PTBTokenizer tokenized 775 tokens at 10494.54 tokens per second.
# PTBTokenizer tokenized 539 tokens at 6965.06 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1635.70 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 22308.96 tokens per second.
# PTBTokenizer tokenized 613 tokens at 8560.04 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6260.78 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1434.40 tokens per second.
# PTBTokenizer tokenized 2599 tokens at 25133.74 tokens per second.
# PTBTokenizer tokenized 602 tokens at 8418.79 tokens per second.
# PTBTokenizer tokenized 480 tokens at 5493.91 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1409.25 tokens per second.
# PTBTokenizer tokenized 2404 tokens at 26805.33 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6444.51 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6362.11 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1510.51 tokens per second.
# PTBTokenizer tokenized 2659 tokens at 23079.05 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7603.66 tokens per second.
# PTBTokenizer tokenized 535 tokens at 6637.98 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1636.33 tokens per second.
# PTBTokenizer tokenized 2679 tokens at 23066.85 tokens per second.
# PTBTokenizer tokenized 646 tokens at 9018.89 tokens per second.
# PTBTokenizer tokenized 565 tokens at 6666.79 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1716.82 tokens per second.
# PTBTokenizer tokenized 2829 tokens at 26732.27 tokens per second.
# PTBTokenizer tokenized 691 tokens at 7558.75 tokens per second.
# PTBTokenizer tokenized 653 tokens at 8441.56 tokens per second.
# PTBTokenizer tokenized 151 tokens at 2184.02 tokens per second.
# PTBTokenizer tokenized 3269 tokens at 35277.33 tokens per second.
# PTBTokenizer tokenized 713 tokens at 7854.01 tokens per second.
# PTBTokenizer tokenized 619 tokens at 8302.67 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1644.52 tokens per second.
# PTBTokenizer tokenized 3099 tokens at 28913.95 tokens per second.
# PTBTokenizer tokenized 685 tokens at 8336.40 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6250.04 tokens per second.
# PTBTokenizer tokenized 141 tokens at 2112.58 tokens per second.
# PTBTokenizer tokenized 2649 tokens at 28994.88 tokens per second.
# PTBTokenizer tokenized 730 tokens at 7704.82 tokens per second.
# PTBTokenizer tokenized 549 tokens at 6719.72 tokens per second.
# PTBTokenizer tokenized 167 tokens at 1913.37 tokens per second.
# PTBTokenizer tokenized 2749 tokens at 28597.18 tokens per second.
# PTBTokenizer tokenized 813 tokens at 9663.48 tokens per second.
# PTBTokenizer tokenized 628 tokens at 7200.50 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2031.30 tokens per second.
# PTBTokenizer tokenized 3144 tokens at 31476.04 tokens per second.
# PTBTokenizer tokenized 813 tokens at 9922.04 tokens per second.
# PTBTokenizer tokenized 585 tokens at 7410.43 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2331.76 tokens per second.
# PTBTokenizer tokenized 2929 tokens at 29494.78 tokens per second.
# PTBTokenizer tokenized 911 tokens at 12413.25 tokens per second.
# PTBTokenizer tokenized 558 tokens at 5313.25 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1725.20 tokens per second.
# PTBTokenizer tokenized 2794 tokens at 27512.34 tokens per second.
# PTBTokenizer tokenized 613 tokens at 6767.84 tokens per second.
# PTBTokenizer tokenized 571 tokens at 6550.97 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1620.46 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 30940.53 tokens per second.
# PTBTokenizer tokenized 642 tokens at 9110.70 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7147.58 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1872.87 tokens per second.
# PTBTokenizer tokenized 2839 tokens at 26630.11 tokens per second.
# PTBTokenizer tokenized 710 tokens at 9563.93 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7397.26 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1898.15 tokens per second.
# PTBTokenizer tokenized 3054 tokens at 28604.71 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7886.16 tokens per second.
# PTBTokenizer tokenized 570 tokens at 6788.27 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2153.45 tokens per second.
# PTBTokenizer tokenized 2854 tokens at 29133.76 tokens per second.
# PTBTokenizer tokenized 905 tokens at 10891.36 tokens per second.
# PTBTokenizer tokenized 635 tokens at 7420.71 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1905.29 tokens per second.
# PTBTokenizer tokenized 3179 tokens at 29437.20 tokens per second.
# PTBTokenizer tokenized 762 tokens at 10383.45 tokens per second.
# PTBTokenizer tokenized 595 tokens at 7931.61 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1591.53 tokens per second.
# PTBTokenizer tokenized 2979 tokens at 33839.41 tokens per second.
# PTBTokenizer tokenized 640 tokens at 8322.83 tokens per second.
# PTBTokenizer tokenized 571 tokens at 7303.04 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1726.46 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 24673.09 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7558.27 tokens per second.
# PTBTokenizer tokenized 638 tokens at 7556.12 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1642.31 tokens per second.
# PTBTokenizer tokenized 3194 tokens at 28096.23 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7292.56 tokens per second.
# PTBTokenizer tokenized 577 tokens at 6164.49 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1681.71 tokens per second.
# PTBTokenizer tokenized 2889 tokens at 27043.51 tokens per second.
# PTBTokenizer tokenized 629 tokens at 7240.95 tokens per second.
# PTBTokenizer tokenized 532 tokens at 5605.22 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1289.96 tokens per second.
# PTBTokenizer tokenized 2664 tokens at 25699.99 tokens per second.
# PTBTokenizer tokenized 533 tokens at 7569.81 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6060.80 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1289.91 tokens per second.
# PTBTokenizer tokenized 2559 tokens at 24623.20 tokens per second.
# PTBTokenizer tokenized 483 tokens at 5984.70 tokens per second.
# PTBTokenizer tokenized 545 tokens at 6263.21 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1670.73 tokens per second.
# PTBTokenizer tokenized 2729 tokens at 26234.26 tokens per second.
# PTBTokenizer tokenized 695 tokens at 8429.30 tokens per second.
# PTBTokenizer tokenized 511 tokens at 5969.01 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1502.00 tokens per second.
# PTBTokenizer tokenized 2559 tokens at 25193.37 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7333.54 tokens per second.
# PTBTokenizer tokenized 583 tokens at 8057.12 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1664.63 tokens per second.
# PTBTokenizer tokenized 2919 tokens at 27806.23 tokens per second.
# PTBTokenizer tokenized 616 tokens at 7501.54 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7272.76 tokens per second.
# PTBTokenizer tokenized 155 tokens at 1965.09 tokens per second.
# PTBTokenizer tokenized 3059 tokens at 24592.78 tokens per second.
# PTBTokenizer tokenized 795 tokens at 10799.68 tokens per second.
# PTBTokenizer tokenized 549 tokens at 6797.14 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1561.15 tokens per second.
# PTBTokenizer tokenized 2749 tokens at 30575.36 tokens per second.
# PTBTokenizer tokenized 671 tokens at 8837.43 tokens per second.
# PTBTokenizer tokenized 547 tokens at 6822.78 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1112.12 tokens per second.
# PTBTokenizer tokenized 2739 tokens at 27133.55 tokens per second.
# PTBTokenizer tokenized 485 tokens at 6550.60 tokens per second.
# PTBTokenizer tokenized 553 tokens at 7706.30 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1498.51 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 24962.08 tokens per second.
# PTBTokenizer tokenized 679 tokens at 8144.81 tokens per second.
# PTBTokenizer tokenized 515 tokens at 6136.05 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1421.67 tokens per second.
# PTBTokenizer tokenized 2579 tokens at 25069.98 tokens per second.
# PTBTokenizer tokenized 631 tokens at 7732.01 tokens per second.
# PTBTokenizer tokenized 515 tokens at 6291.83 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1752.04 tokens per second.
# PTBTokenizer tokenized 2579 tokens at 25202.75 tokens per second.
# PTBTokenizer tokenized 717 tokens at 9683.39 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6980.51 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1290.79 tokens per second.
# PTBTokenizer tokenized 2444 tokens at 24042.38 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6498.19 tokens per second.
# PTBTokenizer tokenized 515 tokens at 5668.64 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1272.28 tokens per second.
# PTBTokenizer tokenized 2579 tokens at 30116.65 tokens per second.
# PTBTokenizer tokenized 524 tokens at 5632.37 tokens per second.
# PTBTokenizer tokenized 574 tokens at 7398.13 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1496.96 tokens per second.
# PTBTokenizer tokenized 2874 tokens at 23786.47 tokens per second.
# PTBTokenizer tokenized 608 tokens at 7482.84 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6388.49 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1477.98 tokens per second.
# PTBTokenizer tokenized 2629 tokens at 25365.66 tokens per second.
# PTBTokenizer tokenized 587 tokens at 8386.55 tokens per second.
# PTBTokenizer tokenized 585 tokens at 7097.95 tokens per second.
# PTBTokenizer tokenized 162 tokens at 2013.26 tokens per second.
# PTBTokenizer tokenized 2929 tokens at 26773.85 tokens per second.
# PTBTokenizer tokenized 849 tokens at 10389.50 tokens per second.
# PTBTokenizer tokenized 535 tokens at 7377.21 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1588.73 tokens per second.
# PTBTokenizer tokenized 2679 tokens at 28473.35 tokens per second.
# PTBTokenizer tokenized 542 tokens at 7284.79 tokens per second.
# PTBTokenizer tokenized 531 tokens at 7460.58 tokens per second.
# PTBTokenizer tokenized 94 tokens at 1209.76 tokens per second.
# PTBTokenizer tokenized 2659 tokens at 20645.35 tokens per second.
# PTBTokenizer tokenized 552 tokens at 5085.25 tokens per second.
# PTBTokenizer tokenized 583 tokens at 8199.74 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1694.82 tokens per second.
# PTBTokenizer tokenized 2919 tokens at 26617.80 tokens per second.
# PTBTokenizer tokenized 672 tokens at 7924.70 tokens per second.
# PTBTokenizer tokenized 571 tokens at 7662.96 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2060.64 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 29781.08 tokens per second.
# PTBTokenizer tokenized 807 tokens at 9549.91 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6333.83 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1516.76 tokens per second.
# PTBTokenizer tokenized 2669 tokens at 25299.24 tokens per second.
# PTBTokenizer tokenized 587 tokens at 7742.30 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6306.24 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1866.39 tokens per second.
# PTBTokenizer tokenized 2669 tokens at 22539.90 tokens per second.
# PTBTokenizer tokenized 765 tokens at 9040.35 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6699.56 tokens per second.
# PTBTokenizer tokenized 162 tokens at 2146.13 tokens per second.
# PTBTokenizer tokenized 2714 tokens at 31586.29 tokens per second.
# PTBTokenizer tokenized 781 tokens at 9042.75 tokens per second.
# PTBTokenizer tokenized 570 tokens at 7914.36 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1755.97 tokens per second.
# PTBTokenizer tokenized 2854 tokens at 31334.56 tokens per second.
# PTBTokenizer tokenized 688 tokens at 8041.10 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6133.01 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1968.08 tokens per second.
# PTBTokenizer tokenized 2899 tokens at 32379.54 tokens per second.
# PTBTokenizer tokenized 764 tokens at 8920.43 tokens per second.
# PTBTokenizer tokenized 562 tokens at 7091.89 tokens per second.
# PTBTokenizer tokenized 199 tokens at 2454.39 tokens per second.
# PTBTokenizer tokenized 2814 tokens at 30380.28 tokens per second.
# PTBTokenizer tokenized 926 tokens at 10972.92 tokens per second.
# PTBTokenizer tokenized 605 tokens at 7065.99 tokens per second.
# PTBTokenizer tokenized 142 tokens at 2086.36 tokens per second.
# PTBTokenizer tokenized 3029 tokens at 34814.81 tokens per second.
# PTBTokenizer tokenized 693 tokens at 8264.75 tokens per second.
# PTBTokenizer tokenized 505 tokens at 5836.51 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1394.35 tokens per second.
# PTBTokenizer tokenized 2529 tokens at 24652.81 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8641.15 tokens per second.
# PTBTokenizer tokenized 511 tokens at 7199.91 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1793.98 tokens per second.
# PTBTokenizer tokenized 2559 tokens at 22605.47 tokens per second.
# PTBTokenizer tokenized 665 tokens at 7711.83 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6627.90 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1661.97 tokens per second.
# PTBTokenizer tokenized 2759 tokens at 23785.04 tokens per second.
# PTBTokenizer tokenized 677 tokens at 8459.44 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7455.67 tokens per second.
# PTBTokenizer tokenized 172 tokens at 2010.06 tokens per second.
# PTBTokenizer tokenized 3079 tokens at 28551.93 tokens per second.
# PTBTokenizer tokenized 861 tokens at 10483.72 tokens per second.
# PTBTokenizer tokenized 496 tokens at 5744.89 tokens per second.
# PTBTokenizer tokenized 80 tokens at 1018.25 tokens per second.
# PTBTokenizer tokenized 2484 tokens at 24303.95 tokens per second.
# PTBTokenizer tokenized 409 tokens at 5074.20 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5579.74 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1421.16 tokens per second.
# PTBTokenizer tokenized 2569 tokens at 25006.29 tokens per second.
# PTBTokenizer tokenized 572 tokens at 6869.71 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6530.68 tokens per second.
# PTBTokenizer tokenized 153 tokens at 2057.39 tokens per second.
# PTBTokenizer tokenized 2879 tokens at 26781.90 tokens per second.
# PTBTokenizer tokenized 750 tokens at 8481.45 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7441.76 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1648.85 tokens per second.
# PTBTokenizer tokenized 3024 tokens at 27977.34 tokens per second.
# PTBTokenizer tokenized 689 tokens at 8031.82 tokens per second.
# PTBTokenizer tokenized 504 tokens at 7104.12 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1600.36 tokens per second.
# PTBTokenizer tokenized 2524 tokens at 26010.22 tokens per second.
# PTBTokenizer tokenized 575 tokens at 7181.51 tokens per second.
# PTBTokenizer tokenized 480 tokens at 6347.74 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1792.45 tokens per second.
# PTBTokenizer tokenized 2404 tokens at 28107.73 tokens per second.
# PTBTokenizer tokenized 713 tokens at 8398.60 tokens per second.
# PTBTokenizer tokenized 553 tokens at 6471.61 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1495.71 tokens per second.
# PTBTokenizer tokenized 2769 tokens at 28081.43 tokens per second.
# PTBTokenizer tokenized 621 tokens at 7109.18 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6944.37 tokens per second.
# PTBTokenizer tokenized 183 tokens at 2717.77 tokens per second.
# PTBTokenizer tokenized 2569 tokens at 30026.80 tokens per second.
# PTBTokenizer tokenized 889 tokens at 10727.10 tokens per second.
# PTBTokenizer tokenized 585 tokens at 7324.76 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2390.70 tokens per second.
# PTBTokenizer tokenized 2929 tokens at 29806.93 tokens per second.
# PTBTokenizer tokenized 840 tokens at 8896.06 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6557.19 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1522.96 tokens per second.
# PTBTokenizer tokenized 2714 tokens at 25779.00 tokens per second.
# PTBTokenizer tokenized 618 tokens at 8591.58 tokens per second.
# PTBTokenizer tokenized 571 tokens at 6945.79 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2056.85 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 26354.28 tokens per second.
# PTBTokenizer tokenized 814 tokens at 11168.09 tokens per second.
# PTBTokenizer tokenized 465 tokens at 6431.00 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1692.42 tokens per second.
# PTBTokenizer tokenized 2329 tokens at 24843.43 tokens per second.
# PTBTokenizer tokenized 558 tokens at 7285.61 tokens per second.
# PTBTokenizer tokenized 511 tokens at 7236.47 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1630.00 tokens per second.
# PTBTokenizer tokenized 2559 tokens at 26472.50 tokens per second.
# PTBTokenizer tokenized 620 tokens at 7633.08 tokens per second.
# PTBTokenizer tokenized 552 tokens at 7706.15 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2362.98 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 25661.33 tokens per second.
# PTBTokenizer tokenized 731 tokens at 10057.20 tokens per second.
# PTBTokenizer tokenized 559 tokens at 6637.72 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1291.26 tokens per second.
# PTBTokenizer tokenized 2799 tokens at 28247.61 tokens per second.
# PTBTokenizer tokenized 491 tokens at 6034.84 tokens per second.
# PTBTokenizer tokenized 482 tokens at 6664.46 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1590.43 tokens per second.
# PTBTokenizer tokenized 2414 tokens at 23334.11 tokens per second.
# PTBTokenizer tokenized 623 tokens at 7119.95 tokens per second.
# PTBTokenizer tokenized 538 tokens at 6455.49 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1630.83 tokens per second.
# PTBTokenizer tokenized 2694 tokens at 27920.25 tokens per second.
# PTBTokenizer tokenized 656 tokens at 8013.87 tokens per second.
# PTBTokenizer tokenized 572 tokens at 6978.85 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1464.16 tokens per second.
# PTBTokenizer tokenized 2864 tokens at 31577.47 tokens per second.
# PTBTokenizer tokenized 591 tokens at 7994.70 tokens per second.
# PTBTokenizer tokenized 557 tokens at 7315.70 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1995.45 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 25770.82 tokens per second.
# PTBTokenizer tokenized 761 tokens at 9133.07 tokens per second.
# PTBTokenizer tokenized 650 tokens at 7874.92 tokens per second.
# PTBTokenizer tokenized 180 tokens at 2241.07 tokens per second.
# PTBTokenizer tokenized 3254 tokens at 31531.94 tokens per second.
# PTBTokenizer tokenized 911 tokens at 12122.65 tokens per second.
# PTBTokenizer tokenized 539 tokens at 6509.61 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1368.44 tokens per second.
# PTBTokenizer tokenized 2699 tokens at 28658.79 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6558.66 tokens per second.
# PTBTokenizer tokenized 501 tokens at 7078.85 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1734.78 tokens per second.
# PTBTokenizer tokenized 2509 tokens at 23603.19 tokens per second.
# PTBTokenizer tokenized 558 tokens at 7789.10 tokens per second.
# PTBTokenizer tokenized 578 tokens at 6571.75 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1465.02 tokens per second.
# PTBTokenizer tokenized 2894 tokens at 25746.10 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7235.66 tokens per second.
# PTBTokenizer tokenized 520 tokens at 5782.66 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1713.59 tokens per second.
# PTBTokenizer tokenized 2604 tokens at 29412.04 tokens per second.
# PTBTokenizer tokenized 669 tokens at 7902.53 tokens per second.
# PTBTokenizer tokenized 534 tokens at 5168.23 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1666.58 tokens per second.
# PTBTokenizer tokenized 2674 tokens at 24869.89 tokens per second.
# PTBTokenizer tokenized 666 tokens at 9159.60 tokens per second.
# PTBTokenizer tokenized 509 tokens at 6224.31 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1810.88 tokens per second.
# PTBTokenizer tokenized 2549 tokens at 27207.49 tokens per second.
# PTBTokenizer tokenized 627 tokens at 8627.25 tokens per second.
# PTBTokenizer tokenized 552 tokens at 6684.50 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1736.43 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 25921.88 tokens per second.
# ...
# PTBTokenizer tokenized 758 tokens at 10321.36 tokens per second.
# PTBTokenizer tokenized 534 tokens at 5738.83 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1754.98 tokens per second.
# PTBTokenizer tokenized 2674 tokens at 30906.02 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6396.04 tokens per second.
# PTBTokenizer tokenized 522 tokens at 7435.67 tokens per second.
# PTBTokenizer tokenized 154 tokens at 2040.37 tokens per second.
# PTBTokenizer tokenized 2614 tokens at 25582.27 tokens per second.
# PTBTokenizer tokenized 736 tokens at 8622.64 tokens per second.
# PTBTokenizer tokenized 532 tokens at 7386.46 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1229.68 tokens per second.
# PTBTokenizer tokenized 2664 tokens at 25841.31 tokens per second.
# PTBTokenizer tokenized 466 tokens at 6559.87 tokens per second.
# PTBTokenizer tokenized 530 tokens at 6693.30 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1383.17 tokens per second.
# PTBTokenizer tokenized 2654 tokens at 25315.97 tokens per second.
# PTBTokenizer tokenized 655 tokens at 8228.81 tokens per second.
# PTBTokenizer tokenized 522 tokens at 5785.91 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1273.28 tokens per second.
# PTBTokenizer tokenized 2614 tokens at 25171.99 tokens per second.
# PTBTokenizer tokenized 505 tokens at 7252.38 tokens per second.
# PTBTokenizer tokenized 564 tokens at 6753.55 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1365.63 tokens per second.
# PTBTokenizer tokenized 2824 tokens at 26465.76 tokens per second.
# PTBTokenizer tokenized 568 tokens at 6605.12 tokens per second.
# PTBTokenizer tokenized 604 tokens at 7239.32 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1790.68 tokens per second.
# PTBTokenizer tokenized 3024 tokens at 34234.55 tokens per second.
# PTBTokenizer tokenized 705 tokens at 6930.95 tokens per second.
# PTBTokenizer tokenized 607 tokens at 7279.44 tokens per second.
# PTBTokenizer tokenized 161 tokens at 2353.83 tokens per second.
# PTBTokenizer tokenized 3039 tokens at 28251.53 tokens per second.
# PTBTokenizer tokenized 815 tokens at 9630.12 tokens per second.
# PTBTokenizer tokenized 617 tokens at 6921.27 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2643.21 tokens per second.
# PTBTokenizer tokenized 3089 tokens at 28641.89 tokens per second.
# PTBTokenizer tokenized 886 tokens at 12006.13 tokens per second.
# PTBTokenizer tokenized 543 tokens at 7309.78 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1338.14 tokens per second.
# PTBTokenizer tokenized 2719 tokens at 25992.28 tokens per second.
# PTBTokenizer tokenized 483 tokens at 6068.65 tokens per second.
# PTBTokenizer tokenized 569 tokens at 7048.97 tokens per second.
# PTBTokenizer tokenized 232 tokens at 2998.67 tokens per second.
# PTBTokenizer tokenized 2849 tokens at 24695.05 tokens per second.
# PTBTokenizer tokenized 1165 tokens at 12840.13 tokens per second.
# PTBTokenizer tokenized 587 tokens at 7031.63 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1613.27 tokens per second.
# PTBTokenizer tokenized 2939 tokens at 32739.35 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7350.08 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6793.10 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1253.18 tokens per second.
# PTBTokenizer tokenized 2814 tokens at 21952.57 tokens per second.
# PTBTokenizer tokenized 511 tokens at 7224.51 tokens per second.
# PTBTokenizer tokenized 519 tokens at 7396.48 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1511.76 tokens per second.
# PTBTokenizer tokenized 2599 tokens at 24814.99 tokens per second.
# PTBTokenizer tokenized 603 tokens at 7415.28 tokens per second.
# PTBTokenizer tokenized 557 tokens at 6293.73 tokens per second.
# PTBTokenizer tokenized 202 tokens at 2504.71 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 30996.64 tokens per second.
# PTBTokenizer tokenized 994 tokens at 11246.91 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7061.61 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2478.08 tokens per second.
# PTBTokenizer tokenized 2674 tokens at 25598.42 tokens per second.
# PTBTokenizer tokenized 811 tokens at 8635.06 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6517.62 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1435.21 tokens per second.
# PTBTokenizer tokenized 2639 tokens at 29808.81 tokens per second.
# PTBTokenizer tokenized 592 tokens at 7206.55 tokens per second.
# PTBTokenizer tokenized 622 tokens at 6926.67 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1814.73 tokens per second.
# PTBTokenizer tokenized 3114 tokens at 28734.99 tokens per second.
# PTBTokenizer tokenized 695 tokens at 8170.62 tokens per second.
# PTBTokenizer tokenized 585 tokens at 7734.96 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1474.16 tokens per second.
# PTBTokenizer tokenized 2929 tokens at 29882.51 tokens per second.
# PTBTokenizer tokenized 573 tokens at 7041.18 tokens per second.
# PTBTokenizer tokenized 592 tokens at 7063.45 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1725.06 tokens per second.
# PTBTokenizer tokenized 2964 tokens at 26085.24 tokens per second.
# PTBTokenizer tokenized 727 tokens at 8892.83 tokens per second.
# PTBTokenizer tokenized 556 tokens at 6661.99 tokens per second.
# PTBTokenizer tokenized 205 tokens at 2829.34 tokens per second.
# PTBTokenizer tokenized 2784 tokens at 28481.29 tokens per second.
# PTBTokenizer tokenized 1029 tokens at 11659.93 tokens per second.
# PTBTokenizer tokenized 552 tokens at 7580.66 tokens per second.
# PTBTokenizer tokenized 149 tokens at 2230.61 tokens per second.
# PTBTokenizer tokenized 2764 tokens at 26084.30 tokens per second.
# PTBTokenizer tokenized 720 tokens at 8517.52 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6087.15 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1696.33 tokens per second.
# PTBTokenizer tokenized 2519 tokens at 26805.02 tokens per second.
# PTBTokenizer tokenized 657 tokens at 7901.88 tokens per second.
# PTBTokenizer tokenized 569 tokens at 7809.10 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1516.77 tokens per second.
# PTBTokenizer tokenized 2849 tokens at 29509.59 tokens per second.
# PTBTokenizer tokenized 615 tokens at 8588.82 tokens per second.
# PTBTokenizer tokenized 570 tokens at 5682.01 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2522.87 tokens per second.
# PTBTokenizer tokenized 2854 tokens at 27565.88 tokens per second.
# PTBTokenizer tokenized 855 tokens at 11629.08 tokens per second.
# PTBTokenizer tokenized 644 tokens at 8915.31 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1588.14 tokens per second.
# PTBTokenizer tokenized 3224 tokens at 28430.85 tokens per second.
# PTBTokenizer tokenized 689 tokens at 8185.13 tokens per second.
# PTBTokenizer tokenized 548 tokens at 6879.87 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1890.15 tokens per second.
# PTBTokenizer tokenized 2744 tokens at 31467.17 tokens per second.
# PTBTokenizer tokenized 636 tokens at 7499.37 tokens per second.
# PTBTokenizer tokenized 536 tokens at 6472.50 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2231.11 tokens per second.
# PTBTokenizer tokenized 2684 tokens at 25259.51 tokens per second.
# PTBTokenizer tokenized 955 tokens at 13043.95 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6718.67 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1285.03 tokens per second.
# PTBTokenizer tokenized 2489 tokens at 25261.13 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6507.42 tokens per second.
# PTBTokenizer tokenized 612 tokens at 8590.97 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1927.82 tokens per second.
# PTBTokenizer tokenized 3064 tokens at 28012.92 tokens per second.
# PTBTokenizer tokenized 768 tokens at 9048.96 tokens per second.
# PTBTokenizer tokenized 580 tokens at 6703.28 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2331.07 tokens per second.
# PTBTokenizer tokenized 2904 tokens at 29732.00 tokens per second.
# PTBTokenizer tokenized 784 tokens at 9329.73 tokens per second.
# PTBTokenizer tokenized 557 tokens at 6779.49 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2113.77 tokens per second.
# PTBTokenizer tokenized 2789 tokens at 26094.14 tokens per second.
# PTBTokenizer tokenized 798 tokens at 9179.49 tokens per second.
# PTBTokenizer tokenized 601 tokens at 7306.52 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1464.07 tokens per second.
# PTBTokenizer tokenized 3009 tokens at 30513.38 tokens per second.
# PTBTokenizer tokenized 630 tokens at 7739.66 tokens per second.
# PTBTokenizer tokenized 571 tokens at 5959.49 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1628.75 tokens per second.
# PTBTokenizer tokenized 2859 tokens at 32120.23 tokens per second.
# PTBTokenizer tokenized 637 tokens at 8489.24 tokens per second.
# Evaluating CIDEr on Validation set...
# PTBTokenizer tokenized 572 tokens at 6777.93 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1987.96 tokens per second.
# PTBTokenizer tokenized 655 tokens at 9121.77 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1811.29 tokens per second.
# PTBTokenizer tokenized 584 tokens at 7168.66 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1665.99 tokens per second.
# PTBTokenizer tokenized 664 tokens at 7331.78 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1550.51 tokens per second.
# PTBTokenizer tokenized 662 tokens at 8598.00 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1740.19 tokens per second.
# PTBTokenizer tokenized 551 tokens at 7248.92 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1947.05 tokens per second.
# PTBTokenizer tokenized 577 tokens at 7228.53 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1707.89 tokens per second.
# PTBTokenizer tokenized 583 tokens at 7346.50 tokens per second.
# PTBTokenizer tokenized 157 tokens at 1986.33 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6911.62 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1528.95 tokens per second.
# PTBTokenizer tokenized 528 tokens at 5664.77 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1914.69 tokens per second.
# PTBTokenizer tokenized 546 tokens at 6562.54 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1251.96 tokens per second.
# PTBTokenizer tokenized 525 tokens at 6441.09 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1602.63 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6380.19 tokens per second.
# PTBTokenizer tokenized 144 tokens at 2111.14 tokens per second.
# PTBTokenizer tokenized 533 tokens at 6875.23 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2478.29 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7088.37 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1815.92 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6703.35 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1201.30 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5992.92 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1886.28 tokens per second.
# PTBTokenizer tokenized 511 tokens at 6946.11 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1706.08 tokens per second.
# PTBTokenizer tokenized 529 tokens at 6111.88 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1170.14 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6423.61 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1556.26 tokens per second.
# PTBTokenizer tokenized 491 tokens at 5706.00 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1500.79 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6048.76 tokens per second.
# PTBTokenizer tokenized 85 tokens at 1120.84 tokens per second.
# PTBTokenizer tokenized 487 tokens at 6022.88 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1325.10 tokens per second.
# PTBTokenizer tokenized 485 tokens at 6960.55 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1198.49 tokens per second.
# PTBTokenizer tokenized 502 tokens at 7182.73 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1142.81 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6063.87 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1323.84 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6114.71 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1299.29 tokens per second.
# PTBTokenizer tokenized 489 tokens at 6119.82 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1262.87 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5945.47 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1420.04 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6262.34 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1430.40 tokens per second.
# PTBTokenizer tokenized 527 tokens at 7276.75 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1496.10 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6084.45 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1362.91 tokens per second.
# PTBTokenizer tokenized 517 tokens at 6262.26 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1124.03 tokens per second.
# PTBTokenizer tokenized 524 tokens at 6191.65 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1955.18 tokens per second.
# PTBTokenizer tokenized 501 tokens at 6384.04 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1333.74 tokens per second.
# PTBTokenizer tokenized 531 tokens at 6423.16 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1842.22 tokens per second.
# PTBTokenizer tokenized 517 tokens at 7096.72 tokens per second.
# PTBTokenizer tokenized 86 tokens at 1099.14 tokens per second.
# PTBTokenizer tokenized 476 tokens at 5794.36 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1648.88 tokens per second.
# PTBTokenizer tokenized 489 tokens at 5941.15 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1254.16 tokens per second.
# PTBTokenizer tokenized 527 tokens at 6268.76 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1761.30 tokens per second.
# PTBTokenizer tokenized 666 tokens at 7927.23 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1563.49 tokens per second.
# PTBTokenizer tokenized 626 tokens at 6605.94 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1748.89 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6690.32 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1653.09 tokens per second.
# PTBTokenizer tokenized 653 tokens at 8560.48 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1454.61 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7440.83 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1569.49 tokens per second.
# PTBTokenizer tokenized 653 tokens at 7837.06 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1765.91 tokens per second.
# PTBTokenizer tokenized 590 tokens at 7309.80 tokens per second.
# PTBTokenizer tokenized 159 tokens at 1940.09 tokens per second.
# PTBTokenizer tokenized 562 tokens at 6712.86 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1740.65 tokens per second.
# PTBTokenizer tokenized 551 tokens at 6048.15 tokens per second.
# PTBTokenizer tokenized 179 tokens at 2209.09 tokens per second.
# PTBTokenizer tokenized 543 tokens at 6306.20 tokens per second.
# PTBTokenizer tokenized 168 tokens at 2185.52 tokens per second.
# PTBTokenizer tokenized 579 tokens at 6906.69 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1905.97 tokens per second.
# PTBTokenizer tokenized 610 tokens at 7271.06 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2346.30 tokens per second.
# PTBTokenizer tokenized 615 tokens at 7085.39 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2398.14 tokens per second.
# PTBTokenizer tokenized 530 tokens at 7458.11 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1377.63 tokens per second.
# PTBTokenizer tokenized 542 tokens at 6303.79 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1698.36 tokens per second.
# Epoch 15 | Loss: -1.6898 | Val CIDEr: 0.6117
