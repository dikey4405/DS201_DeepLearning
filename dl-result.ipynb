# %%
# !git clone https://github.com/dikey4405/DS201_DeepLearning.git
# Out:
# Cloning into 'DS201_DeepLearning'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 157 (delta 76), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (157/157), 61.46 KiB | 4.73 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# %cd DS201_DeepLearning/Extractor
# Out:
# /kaggle/working/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/Extractor

# %%
# !python feature_extractor.py
# Out:
# Bắt đầu quá trình trích xuất đặc trưng...
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|█████████████████████████████████████████| 171M/171M [00:00<00:00, 233MB/s]
# Đã khởi tạo model ResNet-101 thành công.
#
# --- Đang xử lý tập: train ---
# Số lượng ảnh cần xử lý: 3512
# Extracting train: 100%|█████████████████| 3512/3512 [00:00<00:00, 170488.72it/s]
#
# --- Đang xử lý tập: dev ---
# Số lượng ảnh cần xử lý: 439
# Extracting dev: 100%|█████████████████████| 439/439 [00:00<00:00, 179954.99it/s]
#
# --- Đang xử lý tập: test ---
# Số lượng ảnh cần xử lý: 439
# Extracting test: 100%|████████████████████| 439/439 [00:00<00:00, 142614.78it/s]
#
# Hoàn thành! File lưu tại: /kaggle/working/coco_features_2048d/

# %%
# %cd ..
# Out:
# /kaggle/working/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning

# %%
# !python train.py
# Out:
# Loading vocab from: /kaggle/input/data-dl/Captions/train.json
# Found 12332 valid captions out of 17563 items.
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 2): 2290
# Vocab size: 2290
# Loading Train data from: /kaggle/input/data-dl/Images/Images/train
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 2466 images.
# Loading Val data from: /kaggle/input/data-dl/Images/Images/dev
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 321 images.
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# === Starting Phase 1: XE Training (20 epochs) ===
# PTBTokenizer tokenized 532 tokens at 5980.85 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1592.48 tokens per second.
# PTBTokenizer tokenized 488 tokens at 5734.06 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1490.45 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7006.05 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1471.39 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6544.77 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1907.95 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5064.73 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1904.10 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6667.76 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1934.64 tokens per second.
# PTBTokenizer tokenized 490 tokens at 6052.77 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1921.96 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6317.98 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1688.85 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6919.42 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1477.79 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6257.61 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1857.03 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6190.39 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1802.21 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5775.35 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1660.51 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5615.67 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1602.15 tokens per second.
# PTBTokenizer tokenized 503 tokens at 7268.21 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1569.49 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6213.13 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1860.49 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6504.37 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1595.05 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6137.12 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1929.39 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6306.77 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1579.90 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6123.19 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1692.24 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6999.09 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1906.94 tokens per second.
# PTBTokenizer tokenized 519 tokens at 5590.80 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1624.00 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5689.79 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1556.26 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6151.02 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1561.10 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5851.94 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1632.95 tokens per second.
# PTBTokenizer tokenized 504 tokens at 5543.58 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1579.72 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7784.57 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1912.53 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7437.02 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1695.01 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7084.80 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1814.40 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7798.83 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1542.69 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7498.16 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1843.39 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7639.48 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1622.26 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7569.36 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1479.23 tokens per second.
# PTBTokenizer tokenized 597 tokens at 8102.56 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1338.01 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6717.08 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1612.08 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6432.32 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1530.24 tokens per second.
# PTBTokenizer tokenized 573 tokens at 8103.43 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1602.69 tokens per second.
# PTBTokenizer tokenized 602 tokens at 8211.29 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1589.80 tokens per second.
# PTBTokenizer tokenized 602 tokens at 6916.43 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1829.54 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6089.53 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1636.01 tokens per second.
# PTBTokenizer tokenized 582 tokens at 8171.76 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1653.51 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1143.05 tokens per second.
# PTBTokenizer tokenized 15 tokens at 197.73 tokens per second.
# Epoch 1 | Loss: 4.8884 | Val CIDEr: 0.1515 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.1515)
# PTBTokenizer tokenized 532 tokens at 6312.85 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1114.82 tokens per second.
# PTBTokenizer tokenized 488 tokens at 5933.39 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1135.26 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6184.48 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1226.23 tokens per second.
# PTBTokenizer tokenized 567 tokens at 8002.47 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1062.17 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5574.07 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1037.66 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6072.45 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1331.42 tokens per second.
# PTBTokenizer tokenized 490 tokens at 6169.75 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1204.01 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6168.48 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1095.18 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6120.60 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1310.34 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6797.51 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1098.09 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6712.86 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1317.10 tokens per second.
# PTBTokenizer tokenized 492 tokens at 6038.01 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1203.39 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6718.96 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1120.50 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5942.86 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1164.42 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6234.42 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1340.49 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7096.06 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1178.30 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6032.13 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1274.33 tokens per second.
# PTBTokenizer tokenized 520 tokens at 7326.55 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1300.38 tokens per second.
# PTBTokenizer tokenized 508 tokens at 5778.71 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1181.35 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6724.43 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1047.64 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6770.79 tokens per second.
# PTBTokenizer tokenized 88 tokens at 1338.76 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5834.96 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1034.29 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5911.51 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1311.08 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6105.29 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1206.25 tokens per second.
# PTBTokenizer tokenized 504 tokens at 7303.16 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1240.52 tokens per second.
# PTBTokenizer tokenized 656 tokens at 8081.37 tokens per second.
# PTBTokenizer tokenized 88 tokens at 1107.60 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7441.96 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1108.60 tokens per second.
# PTBTokenizer tokenized 589 tokens at 8206.18 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1151.22 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7997.22 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1158.33 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7112.92 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1117.34 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7309.98 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1303.10 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6911.47 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1115.72 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7521.59 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1060.94 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6958.72 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1099.20 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6996.88 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1135.23 tokens per second.
# PTBTokenizer tokenized 573 tokens at 7034.76 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1135.19 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7068.82 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1184.69 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7510.86 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1328.85 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6696.34 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1261.13 tokens per second.
# PTBTokenizer tokenized 582 tokens at 6628.90 tokens per second.
# PTBTokenizer tokenized 87 tokens at 1129.40 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1022.59 tokens per second.
# PTBTokenizer tokenized 10 tokens at 118.35 tokens per second.
# Epoch 2 | Loss: 4.0573 | Val CIDEr: 0.2597 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.2597)
# PTBTokenizer tokenized 532 tokens at 7495.56 tokens per second.
# PTBTokenizer tokenized 196 tokens at 2930.69 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6149.97 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2048.93 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7208.18 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1788.88 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7094.71 tokens per second.
# PTBTokenizer tokenized 180 tokens at 2650.10 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5265.30 tokens per second.
# PTBTokenizer tokenized 197 tokens at 2471.49 tokens per second.
# PTBTokenizer tokenized 494 tokens at 7087.02 tokens per second.
# PTBTokenizer tokenized 196 tokens at 2377.62 tokens per second.
# PTBTokenizer tokenized 490 tokens at 6936.75 tokens per second.
# PTBTokenizer tokenized 135 tokens at 1511.02 tokens per second.
# PTBTokenizer tokenized 500 tokens at 7195.46 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1572.27 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5848.58 tokens per second.
# PTBTokenizer tokenized 172 tokens at 2259.61 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6206.24 tokens per second.
# PTBTokenizer tokenized 191 tokens at 2477.78 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6092.10 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2175.22 tokens per second.
# PTBTokenizer tokenized 492 tokens at 7128.93 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1156.38 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6977.54 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1800.60 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5938.56 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2081.84 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6125.68 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1996.32 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7666.97 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2172.04 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6222.92 tokens per second.
# PTBTokenizer tokenized 166 tokens at 2109.12 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6054.50 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1701.32 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6095.90 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2663.30 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6332.55 tokens per second.
# PTBTokenizer tokenized 206 tokens at 2901.28 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6362.91 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1627.33 tokens per second.
# PTBTokenizer tokenized 507 tokens at 7041.12 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1531.16 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6931.76 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1774.79 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5952.14 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1583.05 tokens per second.
# PTBTokenizer tokenized 504 tokens at 6343.27 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1903.70 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7572.44 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1922.34 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7003.90 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2290.13 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7005.89 tokens per second.
# PTBTokenizer tokenized 192 tokens at 2838.57 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7704.61 tokens per second.
# PTBTokenizer tokenized 138 tokens at 1853.46 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7415.31 tokens per second.
# PTBTokenizer tokenized 173 tokens at 2423.07 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7011.99 tokens per second.
# PTBTokenizer tokenized 212 tokens at 2541.11 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7886.15 tokens per second.
# PTBTokenizer tokenized 179 tokens at 2381.19 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7653.00 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2291.31 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6032.34 tokens per second.
# PTBTokenizer tokenized 214 tokens at 2719.63 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6434.76 tokens per second.
# PTBTokenizer tokenized 238 tokens at 3159.86 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6847.85 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2131.38 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7316.08 tokens per second.
# PTBTokenizer tokenized 198 tokens at 2497.71 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7295.00 tokens per second.
# PTBTokenizer tokenized 197 tokens at 2866.08 tokens per second.
# PTBTokenizer tokenized 554 tokens at 7063.30 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1740.79 tokens per second.
# PTBTokenizer tokenized 582 tokens at 7169.03 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1492.24 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1167.37 tokens per second.
# PTBTokenizer tokenized 19 tokens at 231.24 tokens per second.
# Epoch 3 | Loss: 3.7829 | Val CIDEr: 0.2010 | LR: 3.00e-04
# PTBTokenizer tokenized 532 tokens at 7349.01 tokens per second.
# PTBTokenizer tokenized 195 tokens at 2358.43 tokens per second.
# PTBTokenizer tokenized 488 tokens at 5981.03 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2166.18 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7399.09 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1586.49 tokens per second.
# PTBTokenizer tokenized 567 tokens at 8123.22 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1606.75 tokens per second.
# PTBTokenizer tokenized 464 tokens at 6120.30 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2374.62 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5676.49 tokens per second.
# PTBTokenizer tokenized 136 tokens at 2044.23 tokens per second.
# PTBTokenizer tokenized 490 tokens at 5754.09 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1679.41 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6326.98 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1553.70 tokens per second.
# PTBTokenizer tokenized 497 tokens at 7005.00 tokens per second.
# PTBTokenizer tokenized 179 tokens at 2038.33 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6416.47 tokens per second.
# PTBTokenizer tokenized 198 tokens at 2321.63 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5910.40 tokens per second.
# PTBTokenizer tokenized 194 tokens at 2496.67 tokens per second.
# PTBTokenizer tokenized 492 tokens at 7076.16 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1457.98 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5964.71 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2124.32 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6078.97 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2383.79 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6499.94 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1649.14 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6410.42 tokens per second.
# PTBTokenizer tokenized 181 tokens at 2721.65 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6248.14 tokens per second.
# PTBTokenizer tokenized 169 tokens at 2123.67 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6518.15 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2470.96 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6294.19 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2354.86 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6153.55 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1998.92 tokens per second.
# PTBTokenizer tokenized 519 tokens at 5711.24 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1605.60 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5744.22 tokens per second.
# PTBTokenizer tokenized 158 tokens at 1944.64 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5912.37 tokens per second.
# PTBTokenizer tokenized 193 tokens at 2480.63 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6675.68 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1664.83 tokens per second.
# PTBTokenizer tokenized 504 tokens at 6110.84 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2087.02 tokens per second.
# PTBTokenizer tokenized 656 tokens at 8719.63 tokens per second.
# PTBTokenizer tokenized 199 tokens at 2566.70 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7382.18 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2380.99 tokens per second.
# PTBTokenizer tokenized 589 tokens at 6760.65 tokens per second.
# PTBTokenizer tokenized 230 tokens at 2852.51 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7812.17 tokens per second.
# PTBTokenizer tokenized 168 tokens at 2328.11 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7436.31 tokens per second.
# PTBTokenizer tokenized 208 tokens at 2646.57 tokens per second.
# PTBTokenizer tokenized 598 tokens at 8331.20 tokens per second.
# PTBTokenizer tokenized 212 tokens at 3095.29 tokens per second.
# PTBTokenizer tokenized 609 tokens at 8174.61 tokens per second.
# PTBTokenizer tokenized 217 tokens at 2526.78 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7197.37 tokens per second.
# PTBTokenizer tokenized 207 tokens at 3020.58 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6841.85 tokens per second.
# PTBTokenizer tokenized 161 tokens at 2063.69 tokens per second.
# PTBTokenizer tokenized 521 tokens at 7199.51 tokens per second.
# PTBTokenizer tokenized 204 tokens at 2557.88 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6187.85 tokens per second.
# PTBTokenizer tokenized 224 tokens at 3083.48 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7270.85 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2148.58 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7084.69 tokens per second.
# PTBTokenizer tokenized 202 tokens at 2592.14 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6627.70 tokens per second.
# PTBTokenizer tokenized 273 tokens at 3085.60 tokens per second.
# PTBTokenizer tokenized 582 tokens at 7007.49 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1680.77 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1405.79 tokens per second.
# PTBTokenizer tokenized 17 tokens at 222.80 tokens per second.
# Epoch 4 | Loss: 3.5710 | Val CIDEr: 0.2579 | LR: 3.00e-04
# PTBTokenizer tokenized 532 tokens at 5725.72 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1737.75 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6013.28 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1161.83 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5944.64 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1582.90 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6904.79 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1987.87 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5691.43 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1524.30 tokens per second.
# PTBTokenizer tokenized 494 tokens at 7009.25 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1542.15 tokens per second.
# PTBTokenizer tokenized 490 tokens at 6019.08 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1405.09 tokens per second.
# PTBTokenizer tokenized 500 tokens at 5298.38 tokens per second.
# PTBTokenizer tokenized 84 tokens at 1079.05 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5999.59 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1429.91 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6732.26 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1684.25 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6330.30 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1619.92 tokens per second.
# PTBTokenizer tokenized 492 tokens at 6763.70 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1387.00 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5906.56 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1509.49 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6279.42 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1320.33 tokens per second.
# PTBTokenizer tokenized 532 tokens at 7422.95 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1391.64 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6456.15 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1646.07 tokens per second.
# PTBTokenizer tokenized 503 tokens at 7104.86 tokens per second.
# PTBTokenizer tokenized 122 tokens at 1793.53 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6151.18 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1387.55 tokens per second.
# PTBTokenizer tokenized 508 tokens at 7126.59 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1588.22 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6293.51 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1388.99 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6293.55 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1274.00 tokens per second.
# PTBTokenizer tokenized 507 tokens at 7079.23 tokens per second.
# PTBTokenizer tokenized 81 tokens at 1043.77 tokens per second.
# PTBTokenizer tokenized 497 tokens at 7139.08 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1194.73 tokens per second.
# PTBTokenizer tokenized 494 tokens at 7069.15 tokens per second.
# PTBTokenizer tokenized 82 tokens at 1246.29 tokens per second.
# PTBTokenizer tokenized 504 tokens at 5789.55 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1276.78 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7344.71 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1867.41 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8468.72 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1620.09 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7086.63 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1574.18 tokens per second.
# PTBTokenizer tokenized 634 tokens at 8311.47 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1917.09 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7407.59 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1445.63 tokens per second.
# PTBTokenizer tokenized 598 tokens at 8109.08 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1969.93 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6607.69 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1649.06 tokens per second.
# PTBTokenizer tokenized 597 tokens at 8483.15 tokens per second.
# PTBTokenizer tokenized 150 tokens at 2267.61 tokens per second.
# PTBTokenizer tokenized 575 tokens at 7225.29 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1660.20 tokens per second.
# PTBTokenizer tokenized 521 tokens at 7162.37 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1790.27 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6805.01 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1792.26 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7135.57 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1725.34 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7193.76 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1667.45 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6265.01 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1606.65 tokens per second.
# PTBTokenizer tokenized 582 tokens at 7073.54 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1588.83 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1050.38 tokens per second.
# PTBTokenizer tokenized 17 tokens at 222.30 tokens per second.
# Epoch 5 | Loss: 3.3946 | Val CIDEr: 0.3505 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.3505)
# PTBTokenizer tokenized 532 tokens at 7664.69 tokens per second.
# PTBTokenizer tokenized 150 tokens at 2161.89 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6074.61 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1827.16 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5833.88 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1546.44 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6734.75 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1536.03 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5710.49 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1649.86 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6635.13 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1853.72 tokens per second.
# PTBTokenizer tokenized 490 tokens at 6645.43 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1533.94 tokens per second.
# PTBTokenizer tokenized 500 tokens at 7083.57 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1667.02 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5499.21 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1599.95 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6037.54 tokens per second.
# PTBTokenizer tokenized 181 tokens at 2220.53 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6240.31 tokens per second.
# PTBTokenizer tokenized 148 tokens at 1859.63 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5650.14 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1395.82 tokens per second.
# PTBTokenizer tokenized 486 tokens at 6686.14 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1617.35 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6039.08 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1944.19 tokens per second.
# PTBTokenizer tokenized 532 tokens at 7316.10 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1553.13 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6607.97 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1749.71 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6151.93 tokens per second.
# PTBTokenizer tokenized 155 tokens at 1708.34 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6180.62 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1569.02 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6574.12 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1593.14 tokens per second.
# PTBTokenizer tokenized 518 tokens at 7382.58 tokens per second.
# PTBTokenizer tokenized 141 tokens at 2058.72 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6370.58 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1374.80 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6606.33 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1275.60 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6000.01 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1521.76 tokens per second.
# PTBTokenizer tokenized 494 tokens at 7045.07 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1621.00 tokens per second.
# PTBTokenizer tokenized 504 tokens at 6997.67 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1949.01 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7732.28 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2482.03 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7463.46 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1839.80 tokens per second.
# PTBTokenizer tokenized 589 tokens at 6244.81 tokens per second.
# PTBTokenizer tokenized 154 tokens at 2247.86 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7383.32 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2054.75 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7667.89 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1821.73 tokens per second.
# PTBTokenizer tokenized 598 tokens at 8279.52 tokens per second.
# PTBTokenizer tokenized 189 tokens at 2314.91 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7448.96 tokens per second.
# PTBTokenizer tokenized 169 tokens at 2357.37 tokens per second.
# PTBTokenizer tokenized 597 tokens at 6662.93 tokens per second.
# PTBTokenizer tokenized 166 tokens at 2472.55 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6890.12 tokens per second.
# PTBTokenizer tokenized 178 tokens at 2223.93 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6216.56 tokens per second.
# PTBTokenizer tokenized 192 tokens at 2775.53 tokens per second.
# PTBTokenizer tokenized 573 tokens at 8005.32 tokens per second.
# PTBTokenizer tokenized 171 tokens at 1975.09 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7260.76 tokens per second.
# PTBTokenizer tokenized 176 tokens at 2200.69 tokens per second.
# PTBTokenizer tokenized 602 tokens at 8408.94 tokens per second.
# PTBTokenizer tokenized 148 tokens at 2217.46 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6478.24 tokens per second.
# PTBTokenizer tokenized 172 tokens at 1648.52 tokens per second.
# PTBTokenizer tokenized 582 tokens at 5830.16 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1628.37 tokens per second.
# PTBTokenizer tokenized 93 tokens at 953.52 tokens per second.
# PTBTokenizer tokenized 19 tokens at 183.43 tokens per second.
# Epoch 6 | Loss: 3.2383 | Val CIDEr: 0.3371 | LR: 3.00e-04
# PTBTokenizer tokenized 532 tokens at 6508.39 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2016.92 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6028.78 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1966.63 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6253.57 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1630.95 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6982.94 tokens per second.
# PTBTokenizer tokenized 162 tokens at 2038.17 tokens per second.
# PTBTokenizer tokenized 464 tokens at 6345.72 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1580.83 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6725.66 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1935.01 tokens per second.
# PTBTokenizer tokenized 490 tokens at 4932.82 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1902.73 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6048.02 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1691.82 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6111.71 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1501.32 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5773.21 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2563.20 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5487.15 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2454.83 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5449.22 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1299.22 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5858.57 tokens per second.
# PTBTokenizer tokenized 158 tokens at 2032.63 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6081.73 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1552.41 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6436.32 tokens per second.
# PTBTokenizer tokenized 156 tokens at 1982.57 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7573.98 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1618.89 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5901.16 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2325.11 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6448.02 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1588.43 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6000.26 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2134.21 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6548.07 tokens per second.
# PTBTokenizer tokenized 161 tokens at 1975.02 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6294.78 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1673.25 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6069.03 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1278.85 tokens per second.
# PTBTokenizer tokenized 497 tokens at 7131.57 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1589.27 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5511.45 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1402.66 tokens per second.
# PTBTokenizer tokenized 504 tokens at 5485.55 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1806.20 tokens per second.
# PTBTokenizer tokenized 656 tokens at 9121.56 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2131.43 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7808.64 tokens per second.
# PTBTokenizer tokenized 157 tokens at 2332.12 tokens per second.
# PTBTokenizer tokenized 589 tokens at 6293.71 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2353.79 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7955.81 tokens per second.
# PTBTokenizer tokenized 219 tokens at 2648.89 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7461.84 tokens per second.
# PTBTokenizer tokenized 156 tokens at 1955.34 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7361.14 tokens per second.
# PTBTokenizer tokenized 198 tokens at 2470.71 tokens per second.
# PTBTokenizer tokenized 609 tokens at 8631.62 tokens per second.
# PTBTokenizer tokenized 181 tokens at 2712.39 tokens per second.
# PTBTokenizer tokenized 597 tokens at 6585.49 tokens per second.
# PTBTokenizer tokenized 160 tokens at 1928.06 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6952.19 tokens per second.
# PTBTokenizer tokenized 191 tokens at 2275.30 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6334.55 tokens per second.
# PTBTokenizer tokenized 243 tokens at 3495.81 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6937.40 tokens per second.
# PTBTokenizer tokenized 189 tokens at 2443.76 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7078.79 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1959.94 tokens per second.
# PTBTokenizer tokenized 602 tokens at 6874.84 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2228.86 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6477.15 tokens per second.
# PTBTokenizer tokenized 241 tokens at 2997.93 tokens per second.
# PTBTokenizer tokenized 582 tokens at 7506.68 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2465.76 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1093.12 tokens per second.
# PTBTokenizer tokenized 23 tokens at 339.21 tokens per second.
# Epoch 7 | Loss: 3.0892 | Val CIDEr: 0.3877 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.3877)
# PTBTokenizer tokenized 532 tokens at 6810.60 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1470.90 tokens per second.
# PTBTokenizer tokenized 488 tokens at 5814.44 tokens per second.
# PTBTokenizer tokenized 146 tokens at 1899.29 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7147.16 tokens per second.
# PTBTokenizer tokenized 139 tokens at 1786.26 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7843.34 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1451.49 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5429.69 tokens per second.
# PTBTokenizer tokenized 149 tokens at 1698.78 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6569.57 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1769.90 tokens per second.
# PTBTokenizer tokenized 490 tokens at 5767.18 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1864.54 tokens per second.
# PTBTokenizer tokenized 500 tokens at 7149.14 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1550.02 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5440.12 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1127.36 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5851.66 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1790.21 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6293.32 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1499.93 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5993.88 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1441.98 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5745.07 tokens per second.
# PTBTokenizer tokenized 147 tokens at 1868.62 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6076.27 tokens per second.
# PTBTokenizer tokenized 147 tokens at 2115.10 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6344.57 tokens per second.
# PTBTokenizer tokenized 165 tokens at 2145.85 tokens per second.
# PTBTokenizer tokenized 534 tokens at 5866.99 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1667.59 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5354.47 tokens per second.
# PTBTokenizer tokenized 155 tokens at 2285.17 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6412.96 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1644.68 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6021.53 tokens per second.
# PTBTokenizer tokenized 124 tokens at 1551.82 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6448.40 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2055.82 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6136.56 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1761.43 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5707.57 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1284.58 tokens per second.
# PTBTokenizer tokenized 497 tokens at 7140.71 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1653.32 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6751.23 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1454.35 tokens per second.
# PTBTokenizer tokenized 504 tokens at 6090.87 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1569.55 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7722.90 tokens per second.
# PTBTokenizer tokenized 187 tokens at 2654.12 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7682.12 tokens per second.
# PTBTokenizer tokenized 154 tokens at 1909.26 tokens per second.
# PTBTokenizer tokenized 589 tokens at 8124.38 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1951.13 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7318.00 tokens per second.
# PTBTokenizer tokenized 192 tokens at 2418.95 tokens per second.
# PTBTokenizer tokenized 617 tokens at 8682.42 tokens per second.
# PTBTokenizer tokenized 158 tokens at 1982.01 tokens per second.
# PTBTokenizer tokenized 598 tokens at 6465.88 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2220.54 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6640.88 tokens per second.
# PTBTokenizer tokenized 152 tokens at 2023.83 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7101.51 tokens per second.
# PTBTokenizer tokenized 184 tokens at 2465.13 tokens per second.
# PTBTokenizer tokenized 575 tokens at 7371.14 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1805.41 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6097.25 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1988.37 tokens per second.
# PTBTokenizer tokenized 573 tokens at 8045.10 tokens per second.
# PTBTokenizer tokenized 186 tokens at 2368.71 tokens per second.
# PTBTokenizer tokenized 602 tokens at 8304.16 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1645.18 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7214.31 tokens per second.
# PTBTokenizer tokenized 217 tokens at 3040.98 tokens per second.
# PTBTokenizer tokenized 554 tokens at 7579.73 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1912.06 tokens per second.
# PTBTokenizer tokenized 582 tokens at 7534.30 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1935.31 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1358.65 tokens per second.
# PTBTokenizer tokenized 21 tokens at 260.47 tokens per second.
# Epoch 8 | Loss: 2.9318 | Val CIDEr: 0.4753 | LR: 3.00e-04
# --> Saved Best XE Model (CIDEr: 0.4753)
# PTBTokenizer tokenized 532 tokens at 6377.16 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1961.06 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6740.69 tokens per second.
# PTBTokenizer tokenized 130 tokens at 1708.05 tokens per second.
# PTBTokenizer tokenized 513 tokens at 5651.89 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1389.28 tokens per second.
# PTBTokenizer tokenized 567 tokens at 6797.47 tokens per second.
# PTBTokenizer tokenized 123 tokens at 1568.89 tokens per second.
# PTBTokenizer tokenized 464 tokens at 4758.89 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1354.37 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6853.12 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1618.41 tokens per second.
# PTBTokenizer tokenized 490 tokens at 5352.97 tokens per second.
# PTBTokenizer tokenized 125 tokens at 1764.26 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6003.79 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1456.56 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5387.89 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1566.46 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6038.84 tokens per second.
# PTBTokenizer tokenized 148 tokens at 2111.96 tokens per second.
# PTBTokenizer tokenized 507 tokens at 5643.67 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1656.16 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5523.32 tokens per second.
# PTBTokenizer tokenized 91 tokens at 1018.48 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5584.18 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1464.76 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6807.16 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1685.43 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6496.93 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1711.12 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6211.75 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1914.23 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6004.70 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1766.48 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6721.44 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1478.01 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6140.53 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1535.44 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6962.14 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1541.19 tokens per second.
# PTBTokenizer tokenized 519 tokens at 7362.67 tokens per second.
# PTBTokenizer tokenized 115 tokens at 1432.18 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6924.75 tokens per second.
# PTBTokenizer tokenized 100 tokens at 1298.44 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6107.13 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1711.89 tokens per second.
# PTBTokenizer tokenized 494 tokens at 4804.46 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1220.17 tokens per second.
# PTBTokenizer tokenized 504 tokens at 7165.35 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1208.48 tokens per second.
# PTBTokenizer tokenized 656 tokens at 8018.43 tokens per second.
# PTBTokenizer tokenized 170 tokens at 2342.91 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8349.42 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1671.87 tokens per second.
# PTBTokenizer tokenized 589 tokens at 6607.61 tokens per second.
# PTBTokenizer tokenized 167 tokens at 2000.26 tokens per second.
# PTBTokenizer tokenized 634 tokens at 6564.67 tokens per second.
# PTBTokenizer tokenized 154 tokens at 1912.46 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7547.28 tokens per second.
# PTBTokenizer tokenized 154 tokens at 2017.05 tokens per second.
# PTBTokenizer tokenized 598 tokens at 8133.82 tokens per second.
# PTBTokenizer tokenized 169 tokens at 1890.98 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6499.35 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2065.01 tokens per second.
# PTBTokenizer tokenized 597 tokens at 8435.89 tokens per second.
# PTBTokenizer tokenized 146 tokens at 2190.77 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6850.29 tokens per second.
# PTBTokenizer tokenized 146 tokens at 2163.54 tokens per second.
# PTBTokenizer tokenized 521 tokens at 7401.10 tokens per second.
# PTBTokenizer tokenized 200 tokens at 2483.99 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6792.03 tokens per second.
# PTBTokenizer tokenized 169 tokens at 1959.71 tokens per second.
# PTBTokenizer tokenized 602 tokens at 8053.31 tokens per second.
# ...
# Epoch 17 | Loss: 1.5681 | Val CIDEr: 0.5479 | LR: 7.50e-05
# --> Saved Best XE Model (CIDEr: 0.5479)
# PTBTokenizer tokenized 532 tokens at 6145.27 tokens per second.
# PTBTokenizer tokenized 106 tokens at 1381.14 tokens per second.
# PTBTokenizer tokenized 488 tokens at 6059.18 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1704.95 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6393.07 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1314.49 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7103.00 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1468.86 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5843.51 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1704.84 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6107.96 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1710.92 tokens per second.
# PTBTokenizer tokenized 490 tokens at 7056.72 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1445.36 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6321.52 tokens per second.
# PTBTokenizer tokenized 101 tokens at 1287.09 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5804.31 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1043.43 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5932.05 tokens per second.
# PTBTokenizer tokenized 114 tokens at 1496.39 tokens per second.
# PTBTokenizer tokenized 507 tokens at 7086.41 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1472.70 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5835.74 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1371.28 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5991.54 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1885.82 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5912.32 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1446.57 tokens per second.
# PTBTokenizer tokenized 532 tokens at 7620.28 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1496.38 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7492.15 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1765.02 tokens per second.
# PTBTokenizer tokenized 503 tokens at 7032.65 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1804.40 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6264.70 tokens per second.
# PTBTokenizer tokenized 118 tokens at 1486.49 tokens per second.
# PTBTokenizer tokenized 508 tokens at 7299.11 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1311.31 tokens per second.
# PTBTokenizer tokenized 518 tokens at 6229.95 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2248.20 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6455.89 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1467.83 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6094.77 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1349.56 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6590.71 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1501.97 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5971.94 tokens per second.
# PTBTokenizer tokenized 92 tokens at 1207.94 tokens per second.
# PTBTokenizer tokenized 504 tokens at 6222.01 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1288.91 tokens per second.
# PTBTokenizer tokenized 656 tokens at 7442.87 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1656.79 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7522.71 tokens per second.
# PTBTokenizer tokenized 141 tokens at 1810.05 tokens per second.
# PTBTokenizer tokenized 589 tokens at 6644.94 tokens per second.
# PTBTokenizer tokenized 142 tokens at 1842.29 tokens per second.
# PTBTokenizer tokenized 634 tokens at 8354.11 tokens per second.
# PTBTokenizer tokenized 173 tokens at 2035.95 tokens per second.
# PTBTokenizer tokenized 617 tokens at 7467.73 tokens per second.
# PTBTokenizer tokenized 133 tokens at 1722.93 tokens per second.
# PTBTokenizer tokenized 598 tokens at 7170.05 tokens per second.
# PTBTokenizer tokenized 175 tokens at 2220.34 tokens per second.
# PTBTokenizer tokenized 609 tokens at 6077.60 tokens per second.
# PTBTokenizer tokenized 182 tokens at 2609.68 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7007.76 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1835.80 tokens per second.
# PTBTokenizer tokenized 575 tokens at 7821.93 tokens per second.
# PTBTokenizer tokenized 151 tokens at 1839.60 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6344.21 tokens per second.
# PTBTokenizer tokenized 164 tokens at 2012.24 tokens per second.
# PTBTokenizer tokenized 573 tokens at 7770.02 tokens per second.
# PTBTokenizer tokenized 196 tokens at 2612.05 tokens per second.
# PTBTokenizer tokenized 602 tokens at 6621.85 tokens per second.
# PTBTokenizer tokenized 160 tokens at 1950.55 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7315.33 tokens per second.
# PTBTokenizer tokenized 162 tokens at 1998.82 tokens per second.
# PTBTokenizer tokenized 554 tokens at 7851.54 tokens per second.
# PTBTokenizer tokenized 160 tokens at 2112.66 tokens per second.
# PTBTokenizer tokenized 582 tokens at 8210.52 tokens per second.
# PTBTokenizer tokenized 153 tokens at 2298.42 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1179.52 tokens per second.
# PTBTokenizer tokenized 23 tokens at 300.82 tokens per second.
# Epoch 18 | Loss: 1.5248 | Val CIDEr: 0.4878 | LR: 7.50e-05
# PTBTokenizer tokenized 532 tokens at 7249.93 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1558.85 tokens per second.
# PTBTokenizer tokenized 488 tokens at 5882.81 tokens per second.
# PTBTokenizer tokenized 162 tokens at 1832.09 tokens per second.
# PTBTokenizer tokenized 513 tokens at 7138.22 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1252.92 tokens per second.
# PTBTokenizer tokenized 567 tokens at 8001.12 tokens per second.
# PTBTokenizer tokenized 127 tokens at 1553.24 tokens per second.
# PTBTokenizer tokenized 464 tokens at 5802.82 tokens per second.
# PTBTokenizer tokenized 110 tokens at 1320.82 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5908.33 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1658.83 tokens per second.
# PTBTokenizer tokenized 490 tokens at 6740.40 tokens per second.
# PTBTokenizer tokenized 92 tokens at 1195.94 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6858.97 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1340.37 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6628.65 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1477.78 tokens per second.
# PTBTokenizer tokenized 493 tokens at 5690.77 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1405.43 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6278.93 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1308.26 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5763.85 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1177.22 tokens per second.
# PTBTokenizer tokenized 486 tokens at 7019.88 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1694.36 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6309.28 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1523.50 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6440.82 tokens per second.
# PTBTokenizer tokenized 111 tokens at 1430.29 tokens per second.
# PTBTokenizer tokenized 534 tokens at 7077.04 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1427.41 tokens per second.
# PTBTokenizer tokenized 503 tokens at 5630.58 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1717.07 tokens per second.
# PTBTokenizer tokenized 520 tokens at 7281.70 tokens per second.
# PTBTokenizer tokenized 103 tokens at 1209.44 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6607.67 tokens per second.
# PTBTokenizer tokenized 108 tokens at 1376.17 tokens per second.
# PTBTokenizer tokenized 518 tokens at 5822.29 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1571.84 tokens per second.
# PTBTokenizer tokenized 519 tokens at 6423.85 tokens per second.
# PTBTokenizer tokenized 97 tokens at 1257.07 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6855.92 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1417.24 tokens per second.
# PTBTokenizer tokenized 497 tokens at 5785.29 tokens per second.
# PTBTokenizer tokenized 109 tokens at 1312.58 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5815.71 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1284.59 tokens per second.
# PTBTokenizer tokenized 504 tokens at 5530.97 tokens per second.
# PTBTokenizer tokenized 99 tokens at 1293.53 tokens per second.
# PTBTokenizer tokenized 656 tokens at 6573.76 tokens per second.
# PTBTokenizer tokenized 126 tokens at 1575.99 tokens per second.
# PTBTokenizer tokenized 611 tokens at 8514.57 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1953.00 tokens per second.
# PTBTokenizer tokenized 589 tokens at 6826.94 tokens per second.
# PTBTokenizer tokenized 161 tokens at 2233.49 tokens per second.
# PTBTokenizer tokenized 634 tokens at 8909.32 tokens per second.
# PTBTokenizer tokenized 171 tokens at 2474.10 tokens per second.
# PTBTokenizer tokenized 617 tokens at 8670.40 tokens per second.
# PTBTokenizer tokenized 159 tokens at 2290.09 tokens per second.
# PTBTokenizer tokenized 598 tokens at 6835.45 tokens per second.
# PTBTokenizer tokenized 179 tokens at 2649.23 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7213.43 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1859.93 tokens per second.
# PTBTokenizer tokenized 597 tokens at 7340.42 tokens per second.
# PTBTokenizer tokenized 158 tokens at 1752.01 tokens per second.
# PTBTokenizer tokenized 575 tokens at 6647.53 tokens per second.
# PTBTokenizer tokenized 159 tokens at 2085.37 tokens per second.
# PTBTokenizer tokenized 521 tokens at 6474.33 tokens per second.
# PTBTokenizer tokenized 149 tokens at 1847.14 tokens per second.
# PTBTokenizer tokenized 573 tokens at 7988.49 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2002.06 tokens per second.
# PTBTokenizer tokenized 602 tokens at 6756.48 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1868.21 tokens per second.
# PTBTokenizer tokenized 602 tokens at 5607.14 tokens per second.
# PTBTokenizer tokenized 150 tokens at 1790.27 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6732.70 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1856.84 tokens per second.
# PTBTokenizer tokenized 582 tokens at 6331.50 tokens per second.
# PTBTokenizer tokenized 137 tokens at 1781.92 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1227.71 tokens per second.
# PTBTokenizer tokenized 23 tokens at 293.53 tokens per second.
# Epoch 19 | Loss: 1.4809 | Val CIDEr: 0.5475 | LR: 7.50e-05
# PTBTokenizer tokenized 532 tokens at 6499.33 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1432.69 tokens per second.
# PTBTokenizer tokenized 488 tokens at 5788.34 tokens per second.
# PTBTokenizer tokenized 129 tokens at 1640.16 tokens per second.
# PTBTokenizer tokenized 513 tokens at 6254.74 tokens per second.
# PTBTokenizer tokenized 95 tokens at 1113.80 tokens per second.
# PTBTokenizer tokenized 567 tokens at 7993.85 tokens per second.
# PTBTokenizer tokenized 119 tokens at 1784.95 tokens per second.
# PTBTokenizer tokenized 464 tokens at 6315.82 tokens per second.
# PTBTokenizer tokenized 128 tokens at 1723.83 tokens per second.
# PTBTokenizer tokenized 494 tokens at 6047.76 tokens per second.
# PTBTokenizer tokenized 104 tokens at 1488.95 tokens per second.
# PTBTokenizer tokenized 490 tokens at 5681.09 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1466.62 tokens per second.
# PTBTokenizer tokenized 500 tokens at 6144.89 tokens per second.
# PTBTokenizer tokenized 86 tokens at 1270.58 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6070.40 tokens per second.
# PTBTokenizer tokenized 107 tokens at 1370.54 tokens per second.
# PTBTokenizer tokenized 493 tokens at 6175.05 tokens per second.
# PTBTokenizer tokenized 112 tokens at 1232.78 tokens per second.
# PTBTokenizer tokenized 507 tokens at 7146.73 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1617.05 tokens per second.
# PTBTokenizer tokenized 492 tokens at 5895.65 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1216.87 tokens per second.
# PTBTokenizer tokenized 486 tokens at 5857.04 tokens per second.
# PTBTokenizer tokenized 102 tokens at 1319.92 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6344.20 tokens per second.
# PTBTokenizer tokenized 98 tokens at 1230.59 tokens per second.
# PTBTokenizer tokenized 532 tokens at 6134.33 tokens per second.
# PTBTokenizer tokenized 117 tokens at 1512.18 tokens per second.
# PTBTokenizer tokenized 534 tokens at 6493.10 tokens per second.
# PTBTokenizer tokenized 120 tokens at 1553.21 tokens per second.
# PTBTokenizer tokenized 503 tokens at 6167.73 tokens per second.
# PTBTokenizer tokenized 156 tokens at 2255.52 tokens per second.
# PTBTokenizer tokenized 520 tokens at 6491.67 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1299.11 tokens per second.
# PTBTokenizer tokenized 508 tokens at 6056.36 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1673.91 tokens per second.
# PTBTokenizer tokenized 518 tokens at 7421.30 tokens per second.
# PTBTokenizer tokenized 140 tokens at 1834.19 tokens per second.
# PTBTokenizer tokenized 519 tokens at 7357.46 tokens per second.
# PTBTokenizer tokenized 116 tokens at 1480.52 tokens per second.
# PTBTokenizer tokenized 507 tokens at 6164.86 tokens per second.
# PTBTokenizer tokenized 105 tokens at 1367.11 tokens per second.
# PTBTokenizer tokenized 497 tokens at 6029.10 tokens per second.
# PTBTokenizer tokenized 143 tokens at 1737.57 tokens per second.
# PTBTokenizer tokenized 494 tokens at 5876.03 tokens per second.
# PTBTokenizer tokenized 113 tokens at 1235.53 tokens per second.
# PTBTokenizer tokenized 504 tokens at 6248.80 tokens per second.
# PTBTokenizer tokenized 96 tokens at 1252.79 tokens per second.
# PTBTokenizer tokenized 656 tokens at 8206.77 tokens per second.
# PTBTokenizer tokenized 134 tokens at 1691.65 tokens per second.
# PTBTokenizer tokenized 611 tokens at 7392.66 tokens per second.
# PTBTokenizer tokenized 176 tokens at 2170.00 tokens per second.
# PTBTokenizer tokenized 589 tokens at 7105.82 tokens per second.
# PTBTokenizer tokenized 152 tokens at 1934.02 tokens per second.
# PTBTokenizer tokenized 634 tokens at 7614.09 tokens per second.
# PTBTokenizer tokenized 149 tokens at 1718.13 tokens per second.
# PTBTokenizer tokenized 617 tokens at 6877.80 tokens per second.
# PTBTokenizer tokenized 144 tokens at 1706.94 tokens per second.
# PTBTokenizer tokenized 598 tokens at 6522.24 tokens per second.
# PTBTokenizer tokenized 163 tokens at 2080.90 tokens per second.
# PTBTokenizer tokenized 609 tokens at 7467.35 tokens per second.
# PTBTokenizer tokenized 149 tokens at 2236.48 tokens per second.
# PTBTokenizer tokenized 597 tokens at 6501.11 tokens per second.
# PTBTokenizer tokenized 131 tokens at 1535.66 tokens per second.
# PTBTokenizer tokenized 575 tokens at 7957.53 tokens per second.
# PTBTokenizer tokenized 145 tokens at 1973.73 tokens per second.
# PTBTokenizer tokenized 521 tokens at 7409.57 tokens per second.
# PTBTokenizer tokenized 155 tokens at 1940.65 tokens per second.
# PTBTokenizer tokenized 573 tokens at 6808.17 tokens per second.
# PTBTokenizer tokenized 185 tokens at 2729.85 tokens per second.
# PTBTokenizer tokenized 602 tokens at 7085.98 tokens per second.
# PTBTokenizer tokenized 164 tokens at 1895.79 tokens per second.
# PTBTokenizer tokenized 602 tokens at 8049.83 tokens per second.
# PTBTokenizer tokenized 137 tokens at 2048.34 tokens per second.
# PTBTokenizer tokenized 554 tokens at 6276.55 tokens per second.
# PTBTokenizer tokenized 136 tokens at 1754.90 tokens per second.
# PTBTokenizer tokenized 582 tokens at 6869.67 tokens per second.
# PTBTokenizer tokenized 155 tokens at 2340.04 tokens per second.
# PTBTokenizer tokenized 93 tokens at 1187.61 tokens per second.
# PTBTokenizer tokenized 6 tokens at 79.46 tokens per second.
# Epoch 20 | Loss: 1.4473 | Val CIDEr: 0.5014 | LR: 3.75e-05
