# %%
# Cài đặt Detectron2
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-vr9kf3d2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-vr9kf3d2
#   Resolved https://github.com/facebookresearch/detectron2.git to commit fd27788985af0f4ca800bca563acdb700bb890e2
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.4 MB/s eta 0:00:00
# ...
#   Created wheel for detectron2: filename=detectron2-0.6-cp311-cp311-linux_x86_64.whl size=6434745 sha256=2a3f41b84a28d924307853b48249904fdca24c142536f3bd38e9423b1181a928
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9eqx1ntv/wheels/17/d9/40/60db98e485aa9455d653e29d1046601ce96fe23647f60c1c5a
# ...

# %%
# !git clone https://github.com/dikey4405/DS201_DeepLearning.git
# Out:
# Cloning into 'DS201_DeepLearning'...
# remote: Enumerating objects: 360, done.
# remote: Total 360 (delta 0), reused 0 (delta 0), pack-reused 360 (from 2)
# Receiving objects: 100% (360/360), 541.77 KiB | 9.34 MiB/s, done.
# Resolving deltas: 100% (184/184), done.

# %%
# %cd DS201_DeepLearning/Extractor
# Out:
# /kaggle/working/DS201_DeepLearning/Extractor

# %%
# !python feature_extractor.py
# Out:
# Bắt đầu quá trình trích xuất đặc trưng...
# Đang khởi tạo Detectron2 Faster R-CNN (R101-C4)...
# model_final_298dad.pkl: 212MB [00:00, 236MB/s]
# Model loaded successfully.
#
# --- Đang xử lý tập: train ---
# Số lượng ảnh cần xử lý: 3512
# Extracting train:   0%|                                | 0/3512 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Extracting train: 100%|█████████████████████| 3512/3512 [37:49<00:00,  1.55it/s]
#
# --- Đang xử lý tập: dev ---
# Số lượng ảnh cần xử lý: 439
# Extracting dev: 100%|█████████████████████████| 439/439 [04:47<00:00,  1.53it/s]
#
# --- Đang xử lý tập: test ---
# Số lượng ảnh cần xử lý: 439
# ...

# %%
# !pip install pyvi pycocoevalcap pycocotools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.5 MB/s eta 0:00:00
# ...

# %%
# %cd ..
# Out:
# /kaggle/working/DS201_DeepLearning

# %%
# !python train.py
# Out:
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 1): 3975
# Vocab size: 3975
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 3512 images.
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 439 images.
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# === Starting Phase 1: XE Training (Corpus Eval) ===
# Generating captions for Evaluation (Greedy)...
#
# [DEBUG Sample 0]
#   GT: một nhóm người đi bộ đường dài dẫn_đầu bởi một con chó đen trắng leo lên một con đường_mòn trên sườn đồi phủ đầy dương_xỉ .
#   Pred: một người đàn_ông mặc áo sơ_mi xanh lá cây và một người đàn_ông mặc áo sơ_mi xanh lá cây và
#
# [DEBUG Sample 1]
#   GT: một nhóm người đi quanh một người đàn_ông đang ôm một đứa bé trên đầu và những người khác đi xuống cầu_thang .
# ...

# %%
# !python train_scst.py
# Out:
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 1): 3975
# Loading annotations from: /kaggle/input/data-dl/Captions/train.json
# Loaded 3512 images.
# Loading annotations from: /kaggle/input/data-dl/Captions/dev.json
# Loaded 439 images.
# --> Loading BEST XE Model from: /kaggle/working/get_model_best_xe.pth
# Freezing Encoder for SCST stability...
# Checking initial CIDEr...
# Evaluating CIDEr on Validation set...
# PTBTokenizer tokenized 572 tokens at 7908.84 tokens per second.
# PTBTokenizer tokenized 138 tokens at 2031.10 tokens per second.
# PTBTokenizer tokenized 655 tokens at 6856.47 tokens per second.
# PTBTokenizer tokenized 132 tokens at 1695.93 tokens per second.
# PTBTokenizer tokenized 584 tokens at 8118.43 tokens per second.
# PTBTokenizer tokenized 121 tokens at 1601.69 tokens per second.
# PTBTokenizer tokenized 664 tokens at 9154.53 tokens per second.
# PTBTokenizer tokenized 153 tokens at 1772.93 tokens per second.
# ...

# %%
# !python generate.py
# Out:
# Running Inference on: cuda
# Loading vocab from /kaggle/input/data-dl/Captions/train.json...
# Building vocabulary using ViTokenizer...
# Total words in vocab (freq >= 1): 3975
# Vocab size: 3975
# Initializing Test Dataloader...
# Loading annotations from: /kaggle/input/data-dl/Captions/test.json
# Loaded 439 images.
# Loading Model...
# Loading weights from: /kaggle/working/get_model_best_scst.pth
# Bắt đầu sinh caption với Beam Size = 3...
#   0%|                                                   | 0/439 [00:00<?, ?it/s]
# [Img 2054125670.jpg]: một người đang đứng trên một bar đại_dương .
#   0%|                                           | 1/439 [00:00<04:45,  1.53it/s]
# [Img 2065300784.jpg]: hai đứa trẻ đang cười nơi một người đàn_ông đội sống trước một chiếc vali .
#   0%|▏                                          | 2/439 [00:00<02:26,  2.99it/s]
# [Img 2088120475.jpg]: một thanh_niên đeo cừu và đội mũ trùm đầu và lông đang ôm nhau .
# ...

# %%
# !python Evaluate.py
# Out:
# Đang tạo file Ground Truth chuẩn COCO từ: /kaggle/input/data-dl/Captions/test.json
# Formatting GT: 100%|██████████████████████| 439/439 [00:00<00:00, 451409.53it/s]
# Đang định dạng file dự đoán: caption_readable.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 34453 tokens at 168306.11 tokens per second.
# PTBTokenizer tokenized 6332 tokens at 48829.42 tokens per second.
# setting up scorers...
# ...
#
# Extracting stanford-corenlp-3.6.0 ...
# Done.
# computing Bleu score...
# {'testlen': 5492, 'reflen': 5484, 'guess': [5492, 5053, 4614, 4175], 'correct': [2287, 757, 201, 44]}
# ratio: 1.0014587892047773
# Bleu_1: 0.416
# Bleu_2: 0.250
# Bleu_3: 0.140
# Bleu_4: 0.073
# computing METEOR score...
# METEOR: 0.251
# computing Rouge score...
# ROUGE_L: 0.308
# computing CIDEr score...
# CIDEr: 0.180
# ...
