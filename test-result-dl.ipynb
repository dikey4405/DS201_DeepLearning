# %%
# Cài đặt Detectron2
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# %%
# !git clone https://github.com/dikey4405/DS201_DeepLearning.git
# Out:
# Cloning into 'DS201_DeepLearning'...
# remote: Enumerating objects: 376, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 376 (delta 6), reused 0 (delta 0), pack-reused 360 (from 2)
# Receiving objects: 100% (376/376), 697.96 KiB | 5.86 MiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %%
# %cd DS201_DeepLearning/Extractor

# %%
# !python feature_extractor.py

# %%
# %cd DS201_DeepLearning
# Out:
# /kaggle/working/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning/DS201_DeepLearning

# %%
# !pip install pyvi pycocoevalcap pycocotools

# %%
# !python generate.py

# %%
# !python Evaluate.py
# Out:
# Đang tạo file Ground Truth chuẩn COCO từ: /kaggle/input/data-dl/Captions/test.json
# Formatting GT: 100%|██████████████████████| 439/439 [00:00<00:00, 404859.16it/s]
# Đang định dạng file dự đoán: /kaggle/working/caption_results.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 34453 tokens at 188950.64 tokens per second.
# PTBTokenizer tokenized 7247 tokens at 58498.30 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 6409, 'reflen': 6082, 'guess': [6409, 5970, 5531, 5092], 'correct': [2654, 1048, 465, 175]}
# ratio: 1.0537652088127172
# Bleu_1: 0.414
# Bleu_2: 0.270
# Bleu_3: 0.183
# Bleu_4: 0.120
# computing METEOR score...
# METEOR: 0.256
# computing Rouge score...
# ROUGE_L: 0.329
# computing CIDEr score...
# CIDEr: 0.285
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/usr/local/lib/python3.11/dist-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 2.548 s
# SPICE: 0.031
#
# ========================================
#    KẾT QUẢ ĐÁNH GIÁ CUỐI CÙNG
# ========================================
# | Bleu_1     |  41.41% |
# | Bleu_2     |  26.96% |
# | Bleu_3     |  18.28% |
# | Bleu_4     |  12.04% |
# | METEOR     |  25.56% |
# | ROUGE_L    |  32.88% |
# | CIDEr      |  28.46% |
# | SPICE      |   3.05% |
# ========================================
